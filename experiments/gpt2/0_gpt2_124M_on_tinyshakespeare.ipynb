# %% [markdown]
# # Training GPT2 124M on Tiny shakespeare dataset on my laptop
#
# In this notebook, we train a GPT2 124M model on the Tiny Shakespeare dataset on my laptop without any optimizations.

# %%
from pathlib import Path

import torch
from matplotlib import pyplot as plt

from gollem.data import load_dataset
from gollem.models.gpt2.config import GPT2Config
from gollem.models.gpt2.config import get_gpt2_model_config
from gollem.train.config import TrainConfig
from gollem.train.core import run
from gollem.utils import get_base_dir_path
from gollem.models.model import load_model

device = "cpu"
# Out:
# /Users/jonathon/code/gollem/gollem/models/gpt2/model.py:18: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import ZeroRedundancyOptimizer

# %%
# Create configs

model_cfg = get_gpt2_model_config("gpt2")
# remove optimizations
model_cfg = GPT2Config.override(
    model_cfg,
    **{
        "fused_adamw": False,
        "zero_optimizer": False,
        "flash": False,
        "activation_checkpointing": False,
        "compile": False,
        "from_pretrained": False,
        "use_kv_caching": False,
    },
)

dataset = load_dataset("tinyshakespeare", model_cfg.get_tokenizer())

train_config = TrainConfig(
    output_dir=str(
        get_base_dir_path()
        / "results"
        / "experiments"
        / "gpt2"
        / "0_gpt2_124M_on_tinyshakespeare"
    ),
    batch_size=1,
    seq_len=1024,
    total_batch_size=1024,
    num_iterations=1000,
    val_loss_every=100,
    sample_every=100,
    save_every=100,
    snapshot_every=100,
    device=device,
    dtype="float32",
    tensorcores=False,
    use_wandb=True,
)
# Out:
# /Users/jonathon/code/gollem/gollem/data/datasets/tinyshakespeare/tiny_shakespeare.txt already exists, skipping download...
# Tokenized data already exists, skipping tokenization...

# %%
if True:
    run(dataset, model_cfg, train_config)
# Out:
# /Users/jonathon/code/gollem/gollem/logger.py:35: UserWarning: Log file /Users/jonathon/code/gollem/results/experiments/gpt2/0_gpt2_124M_on_tinyshakespeare/main.log already exists, overwriting
#   warn(f"Log file {self.logfile} already exists, overwriting")
# Launching GPU0|0 in process group 1 using device cpu
# total desired batch size: 1024
# => calculated gradient accumulation steps: 1
# Starting new run 17e73a8f6a5a415f97c9c1ec797814d3
# wandb: Currently logged in as: jjschwartz. Use `wandb login --relogin` to force relogin
# wandb: WARNING Tried to auto resume run with id 66261a0df4a646f6a95dfd8bbbfd5522 but id 17e73a8f6a5a415f97c9c1ec797814d3 is set.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Tracking run with wandb version 0.19.2
# Run data is saved locally in <code>/Users/jonathon/code/gollem/experiments/gpt2/wandb/run-20250412_171150-17e73a8f6a5a415f97c9c1ec797814d3</code>
# Syncing run <strong><a href='https://wandb.ai/jjschwartz/gollem/runs/17e73a8f6a5a415f97c9c1ec797814d3' target="_blank">gpt2_tinyshakespeare</a></strong> to <a href='https://wandb.ai/jjschwartz/gollem' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/jjschwartz/gollem' target="_blank">https://wandb.ai/jjschwartz/gollem</a>
#  View run at <a href='https://wandb.ai/jjschwartz/gollem/runs/17e73a8f6a5a415f97c9c1ec797814d3' target="_blank">https://wandb.ai/jjschwartz/gollem/runs/17e73a8f6a5a415f97c9c1ec797814d3</a>
# Config:
# {'dataset_config': {'name': 'tinyshakespeare',
#                     'train_data': [PosixPath('/Users/jonathon/code/gollem/gollem/data/datasets/tinyshakespeare/gpt2/tiny_shakespeare_val.bin')],
#                     'val_data': [PosixPath('/Users/jonathon/code/gollem/gollem/data/datasets/tinyshakespeare/gpt2/tiny_shakespeare_train.bin')]},
#  'device': 'cpu',
#  'device_type': 'cpu',
#  'model_config': {'activation_checkpointing': False,
#                   'betas': (0.9, 0.95),
#                   'compile': False,
#                   'd_mlp': 3072,
#                   'd_model': 768,
#                   'flash': False,
#                   'from_pretrained': False,
#                   'fused_adamw': False,
#                   'grad_clip': 1.0,
#                   'learning_rate': 0.0006,
#                   'learning_rate_decay_frac': 0.0,
#                   'ln_bias': True,
#                   'max_sample_batch_size': 1,
#                   'mlp_bias': True,
#                   'model_name': 'gpt2',
#                   'n_ctx': 1024,
#                   'n_head': 12,
#                   'n_layer': 12,
#                   'share_embd_params': True,
#                   'use_kv_caching': False,
#                   'vocab_size': 50257,
#                   'warmup_iters': 700,
#                   'weight_decay': 0.1,
#                   'zero_optimizer': False},
#  'pytorch_version': '2.5.1',
#  'train_config': {'batch_size': 1,
#                   'device': 'cpu',
#                   'dtype': 'float32',
#                   'grad_accum_steps': 1,
#                   'num_iterations': 1000,
#                   'output_dir': '/Users/jonathon/code/gollem/results/experiments/gpt2/0_gpt2_124M_on_tinyshakespeare',
#                   'sample_every': 100,
#                   'save_every': 100,
#                   'seed': 42,
#                   'seq_len': 1024,
#                   'snapshot_every': 100,
#                   'tensorcores': False,
#                   'total_batch_size': 1024,
#                   'use_wandb': True,
#                   'val_loss_every': 100,
#                   'val_max_steps': 20}}
# num decayed parameter tensors: 50, with 124,318,464 parameters
# num non-decayed parameter tensors: 98, with 121,344 parameters
# Using regular AdamW with fused=False
# DataLoader: total number of tokens: 298,039 across 1 files
# DataLoader: total number of tokens: 32,768 across 1 files
# Starting training for 1000 iterations
# Step 0: val_loss: 11.0214, val_time: 11143.4247
# ---------------
# <|endoftext|>ria courage163163163 Dougpsons impart harbour Snyderophonflation define HawTagTagMobileworks lust interested unintetermin Kremlin Latinos Ragefire Schemeの�cedovan arenas drains
# ---------------
# Step 0: train_loss: 11.0052, norm: 25.3902, lr: 0.0000, tokens_per_second: 488.8708, time_per_step: 2094.6231
# Step 1: train_loss: 10.9326, norm: 24.2774, lr: 0.0000, tokens_per_second: 413.0564, time_per_step: 2479.0804
# Step 2: train_loss: 10.8366, norm: 26.1564, lr: 0.0000, tokens_per_second: 527.6721, time_per_step: 1940.5992
# Step 3: train_loss: 10.7297, norm: 22.9834, lr: 0.0000, tokens_per_second: 419.1676, time_per_step: 2442.9368
# Step 4: train_loss: 10.4854, norm: 20.5771, lr: 0.0000, tokens_per_second: 547.9769, time_per_step: 1868.6920
# Step 5: train_loss: 10.2162, norm: 17.6469, lr: 0.0000, tokens_per_second: 378.0232, time_per_step: 2708.8288
# Step 6: train_loss: 10.0158, norm: 15.1039, lr: 0.0000, tokens_per_second: 554.0488, time_per_step: 1848.2126
# Step 7: train_loss: 9.9201, norm: 11.6462, lr: 0.0000, tokens_per_second: 526.7728, time_per_step: 1943.9121
# Step 8: train_loss: 9.7919, norm: 10.1811, lr: 0.0000, tokens_per_second: 518.0478, time_per_step: 1976.6515
# Step 9: train_loss: 9.6718, norm: 9.4286, lr: 0.0000, tokens_per_second: 548.4748, time_per_step: 1866.9956
# Step 10: train_loss: 9.5652, norm: 8.2503, lr: 0.0000, tokens_per_second: 625.8864, time_per_step: 1636.0797
# Step 11: train_loss: 9.4614, norm: 7.1798, lr: 0.0000, tokens_per_second: 532.3860, time_per_step: 1923.4166
# Step 12: train_loss: 9.4482, norm: 6.7142, lr: 0.0000, tokens_per_second: 426.7930, time_per_step: 2399.2895
# Step 13: train_loss: 9.4690, norm: 7.0298, lr: 0.0000, tokens_per_second: 602.5934, time_per_step: 1699.3215
# Step 14: train_loss: 9.4448, norm: 6.1383, lr: 0.0000, tokens_per_second: 609.3838, time_per_step: 1680.3860
# Step 15: train_loss: 9.3474, norm: 5.9929, lr: 0.0000, tokens_per_second: 625.4434, time_per_step: 1637.2384
# Step 16: train_loss: 9.4279, norm: 8.5391, lr: 0.0000, tokens_per_second: 514.9612, time_per_step: 1988.4993
# Step 17: train_loss: 9.3318, norm: 5.8655, lr: 0.0000, tokens_per_second: 577.6199, time_per_step: 1772.7922
# Step 18: train_loss: 9.1948, norm: 5.6287, lr: 0.0000, tokens_per_second: 581.4197, time_per_step: 1761.2061
# Step 19: train_loss: 9.2319, norm: 5.3770, lr: 0.0000, tokens_per_second: 596.0172, time_per_step: 1718.0713
# Step 20: train_loss: 9.1983, norm: 4.8010, lr: 0.0000, tokens_per_second: 540.9884, time_per_step: 1892.8318
# Step 21: train_loss: 9.2826, norm: 4.9272, lr: 0.0000, tokens_per_second: 579.5655, time_per_step: 1766.8407
# Step 22: train_loss: 9.0855, norm: 4.6748, lr: 0.0000, tokens_per_second: 578.2866, time_per_step: 1770.7481
# Step 23: train_loss: 9.0622, norm: 5.5613, lr: 0.0000, tokens_per_second: 544.0291, time_per_step: 1882.2524
# Step 24: train_loss: 9.0586, norm: 5.4552, lr: 0.0000, tokens_per_second: 551.2581, time_per_step: 1857.5689
# Step 25: train_loss: 9.0314, norm: 5.6641, lr: 0.0000, tokens_per_second: 596.0294, time_per_step: 1718.0360
# Step 26: train_loss: 8.7336, norm: 5.1633, lr: 0.0000, tokens_per_second: 584.1011, time_per_step: 1753.1211
# Step 27: train_loss: 8.8378, norm: 5.0815, lr: 0.0000, tokens_per_second: 622.3992, time_per_step: 1645.2462
# Step 28: train_loss: 8.8847, norm: 4.5523, lr: 0.0000, tokens_per_second: 567.6670, time_per_step: 1803.8744
# Step 29: train_loss: 8.9516, norm: 4.2964, lr: 0.0000, tokens_per_second: 548.8991, time_per_step: 1865.5522
# Step 30: train_loss: 8.6307, norm: 5.0211, lr: 0.0000, tokens_per_second: 569.1708, time_per_step: 1799.1084
# Step 31: train_loss: 8.7101, norm: 4.3123, lr: 0.0000, tokens_per_second: 596.3623, time_per_step: 1717.0771
# Step 32: train_loss: 8.6331, norm: 6.0274, lr: 0.0000, tokens_per_second: 611.8485, time_per_step: 1673.6170
# Step 33: train_loss: 8.5274, norm: 5.9892, lr: 0.0000, tokens_per_second: 580.5568, time_per_step: 1763.8238
# Step 34: train_loss: 8.3200, norm: 4.7357, lr: 0.0000, tokens_per_second: 595.1345, time_per_step: 1720.6193
# Step 35: train_loss: 8.5380, norm: 6.0627, lr: 0.0000, tokens_per_second: 584.8315, time_per_step: 1750.9316
# Step 36: train_loss: 8.4479, norm: 5.7868, lr: 0.0000, tokens_per_second: 583.6410, time_per_step: 1754.5032
# Step 37: train_loss: 8.2568, norm: 4.6055, lr: 0.0000, tokens_per_second: 613.6233, time_per_step: 1668.7763
# Step 38: train_loss: 8.3984, norm: 5.3873, lr: 0.0000, tokens_per_second: 582.8611, time_per_step: 1756.8508
# Step 39: train_loss: 8.4004, norm: 4.2405, lr: 0.0000, tokens_per_second: 588.8000, time_per_step: 1739.1303
# Step 40: train_loss: 8.3051, norm: 7.2283, lr: 0.0000, tokens_per_second: 578.1776, time_per_step: 1771.0820
# Step 41: train_loss: 8.2447, norm: 6.6808, lr: 0.0000, tokens_per_second: 587.8527, time_per_step: 1741.9331
# Step 42: train_loss: 8.1275, norm: 4.8365, lr: 0.0000, tokens_per_second: 640.2744, time_per_step: 1599.3142
# Step 43: train_loss: 8.2057, norm: 3.7415, lr: 0.0000, tokens_per_second: 642.7311, time_per_step: 1593.2012
# Step 44: train_loss: 8.3638, norm: 3.7592, lr: 0.0000, tokens_per_second: 640.6441, time_per_step: 1598.3914
# Step 45: train_loss: 8.1040, norm: 3.9711, lr: 0.0000, tokens_per_second: 616.4812, time_per_step: 1661.0401
# Step 46: train_loss: 8.2701, norm: 3.6152, lr: 0.0000, tokens_per_second: 584.8149, time_per_step: 1750.9814
# Step 47: train_loss: 8.4328, norm: 4.0753, lr: 0.0000, tokens_per_second: 584.3330, time_per_step: 1752.4254
# Step 48: train_loss: 8.2665, norm: 3.7664, lr: 0.0000, tokens_per_second: 575.4191, time_per_step: 1779.5725
# Step 49: train_loss: 7.9509, norm: 3.8371, lr: 0.0000, tokens_per_second: 606.8274, time_per_step: 1687.4650
# Step 50: train_loss: 7.9158, norm: 4.5626, lr: 0.0000, tokens_per_second: 602.2429, time_per_step: 1700.3105
# Step 51: train_loss: 7.9171, norm: 11.6077, lr: 0.0000, tokens_per_second: 614.3036, time_per_step: 1666.9283
# Step 52: train_loss: 7.7270, norm: 10.8621, lr: 0.0000, tokens_per_second: 574.2265, time_per_step: 1783.2686
# Step 53: train_loss: 7.7031, norm: 4.1408, lr: 0.0000, tokens_per_second: 579.3702, time_per_step: 1767.4366
# Step 54: train_loss: 8.1086, norm: 3.3339, lr: 0.0000, tokens_per_second: 576.9562, time_per_step: 1774.8315
# Step 55: train_loss: 7.9621, norm: 3.2109, lr: 0.0000, tokens_per_second: 611.6698, time_per_step: 1674.1059
# Step 56: train_loss: 7.9035, norm: 3.6373, lr: 0.0000, tokens_per_second: 573.8601, time_per_step: 1784.4070
# Step 57: train_loss: 7.8890, norm: 3.0793, lr: 0.0000, tokens_per_second: 609.2220, time_per_step: 1680.8323
# Step 58: train_loss: 7.6429, norm: 3.6223, lr: 0.0001, tokens_per_second: 587.1905, time_per_step: 1743.8975
# Step 59: train_loss: 7.9714, norm: 3.5618, lr: 0.0001, tokens_per_second: 640.1372, time_per_step: 1599.6571
# Step 60: train_loss: 7.9698, norm: 3.1999, lr: 0.0001, tokens_per_second: 656.6833, time_per_step: 1559.3513
# Step 61: train_loss: 8.0236, norm: 3.2416, lr: 0.0001, tokens_per_second: 556.1716, time_per_step: 1841.1583
# Step 62: train_loss: 7.9292, norm: 3.4436, lr: 0.0001, tokens_per_second: 574.4565, time_per_step: 1782.5545
# Step 63: train_loss: 7.7538, norm: 2.9239, lr: 0.0001, tokens_per_second: 576.8216, time_per_step: 1775.2457
# Step 64: train_loss: 7.8351, norm: 3.1134, lr: 0.0001, tokens_per_second: 622.7968, time_per_step: 1644.1960
# Step 65: train_loss: 7.6974, norm: 3.5261, lr: 0.0001, tokens_per_second: 577.0691, time_per_step: 1774.4841
# Step 66: train_loss: 7.7590, norm: 2.7286, lr: 0.0001, tokens_per_second: 544.9703, time_per_step: 1879.0013
# Step 67: train_loss: 7.7474, norm: 3.0786, lr: 0.0001, tokens_per_second: 578.1400, time_per_step: 1771.1974
# Step 68: train_loss: 7.5479, norm: 2.9442, lr: 0.0001, tokens_per_second: 604.9851, time_per_step: 1692.6038
# Step 69: train_loss: 7.5142, norm: 3.9983, lr: 0.0001, tokens_per_second: 566.0732, time_per_step: 1808.9532
# Step 70: train_loss: 7.5710, norm: 3.3184, lr: 0.0001, tokens_per_second: 600.5836, time_per_step: 1705.0083
# Step 71: train_loss: 7.5582, norm: 3.0687, lr: 0.0001, tokens_per_second: 602.4997, time_per_step: 1699.5860
# Step 72: train_loss: 7.2568, norm: 2.6912, lr: 0.0001, tokens_per_second: 581.6235, time_per_step: 1760.5892
# Step 73: train_loss: 7.3493, norm: 3.5034, lr: 0.0001, tokens_per_second: 616.0062, time_per_step: 1662.3209
# Step 74: train_loss: 7.2797, norm: 3.2661, lr: 0.0001, tokens_per_second: 575.2566, time_per_step: 1780.0752
# Step 75: train_loss: 7.3010, norm: 2.3713, lr: 0.0001, tokens_per_second: 607.7063, time_per_step: 1685.0246
# Step 76: train_loss: 7.3392, norm: 3.0248, lr: 0.0001, tokens_per_second: 596.1545, time_per_step: 1717.6755
# Step 77: train_loss: 7.3269, norm: 2.9156, lr: 0.0001, tokens_per_second: 569.6991, time_per_step: 1797.4400
# Step 78: train_loss: 7.1889, norm: 2.6201, lr: 0.0001, tokens_per_second: 615.4500, time_per_step: 1663.8233
# Step 79: train_loss: 7.1031, norm: 2.3745, lr: 0.0001, tokens_per_second: 604.8653, time_per_step: 1692.9389
# Step 80: train_loss: 7.1226, norm: 2.3263, lr: 0.0001, tokens_per_second: 600.1004, time_per_step: 1706.3810
# Step 81: train_loss: 6.5658, norm: 3.8621, lr: 0.0001, tokens_per_second: 513.4796, time_per_step: 1994.2369
# Step 82: train_loss: 7.0692, norm: 2.0065, lr: 0.0001, tokens_per_second: 561.2541, time_per_step: 1824.4856
# Step 83: train_loss: 6.9567, norm: 2.9577, lr: 0.0001, tokens_per_second: 599.2017, time_per_step: 1708.9405
# Step 84: train_loss: 6.8640, norm: 2.4672, lr: 0.0001, tokens_per_second: 591.7535, time_per_step: 1730.4501
# Step 85: train_loss: 6.6074, norm: 3.1198, lr: 0.0001, tokens_per_second: 570.3752, time_per_step: 1795.3093
# Step 86: train_loss: 6.1329, norm: 2.4077, lr: 0.0001, tokens_per_second: 603.0759, time_per_step: 1697.9620
# Step 87: train_loss: 6.7985, norm: 4.9664, lr: 0.0001, tokens_per_second: 600.5523, time_per_step: 1705.0973
# Step 88: train_loss: 6.5451, norm: 2.7319, lr: 0.0001, tokens_per_second: 556.9672, time_per_step: 1838.5282
# Step 89: train_loss: 6.0411, norm: 4.6010, lr: 0.0001, tokens_per_second: 564.9279, time_per_step: 1812.6205
# Step 90: train_loss: 6.0182, norm: 5.6253, lr: 0.0001, tokens_per_second: 615.8139, time_per_step: 1662.8400
# Step 91: train_loss: 6.4077, norm: 3.3209, lr: 0.0001, tokens_per_second: 608.4697, time_per_step: 1682.9103
# Step 92: train_loss: 6.4942, norm: 3.2487, lr: 0.0001, tokens_per_second: 582.3234, time_per_step: 1758.4731
# Step 93: train_loss: 6.4797, norm: 2.8646, lr: 0.0001, tokens_per_second: 597.2718, time_per_step: 1714.4623
# Step 94: train_loss: 6.5420, norm: 2.6768, lr: 0.0001, tokens_per_second: 582.0607, time_per_step: 1759.2667
# Step 95: train_loss: 6.7364, norm: 2.9053, lr: 0.0001, tokens_per_second: 637.7602, time_per_step: 1605.6192
# Step 96: train_loss: 6.7897, norm: 2.5191, lr: 0.0001, tokens_per_second: 626.9566, time_per_step: 1633.2870
# Step 97: train_loss: 6.6705, norm: 2.4933, lr: 0.0001, tokens_per_second: 619.8112, time_per_step: 1652.1160
# Step 98: train_loss: 6.7925, norm: 2.1675, lr: 0.0001, tokens_per_second: 590.1738, time_per_step: 1735.0821
# Step 99: train_loss: 6.6793, norm: 2.0303, lr: 0.0001, tokens_per_second: 577.3969, time_per_step: 1773.4768
# Step 100: val_loss: 6.7497, val_time: 10839.5726
# ---------------
# <|endoftext|>.<|endoftext|>, him;
# And to,
# And, as of:
#  the,
#  me! me:
# That a with of,?<|endoftext|>H
# ---------------
# Step 100: train_loss: 6.6271, norm: 1.9474, lr: 0.0001, tokens_per_second: 515.0052, time_per_step: 1988.3295
# saving model to /Users/jonathon/code/gollem/results/experiments/gpt2/0_gpt2_124M_on_tinyshakespeare/model_s100.pt
# model saved in 0.49070112500339746 seconds
# saving snapshot to /Users/jonathon/code/gollem/results/snapshots/snapshot.pt
# snapshot saved in 1.6941025420092046 seconds
# Step 101: train_loss: 6.9184, norm: 2.4279, lr: 0.0001, tokens_per_second: 573.2631, time_per_step: 1786.2655
# Step 102: train_loss: 6.4556, norm: 2.5298, lr: 0.0001, tokens_per_second: 543.5562, time_per_step: 1883.8897
# Step 103: train_loss: 6.2853, norm: 2.7955, lr: 0.0001, tokens_per_second: 587.6273, time_per_step: 1742.6010
# Step 104: train_loss: 6.5314, norm: 2.4475, lr: 0.0001, tokens_per_second: 677.3589, time_per_step: 1511.7540
# Step 105: train_loss: 6.2840, norm: 2.2731, lr: 0.0001, tokens_per_second: 673.7348, time_per_step: 1519.8859
# Step 106: train_loss: 6.0418, norm: 2.6463, lr: 0.0001, tokens_per_second: 638.5956, time_per_step: 1603.5186
# Step 107: train_loss: 6.7287, norm: 2.3163, lr: 0.0001, tokens_per_second: 659.8866, time_per_step: 1551.7817
# Step 108: train_loss: 6.5930, norm: 2.1998, lr: 0.0001, tokens_per_second: 587.1717, time_per_step: 1743.9532
# Step 109: train_loss: 6.1013, norm: 3.1950, lr: 0.0001, tokens_per_second: 612.8426, time_per_step: 1670.9022
# Step 110: train_loss: 6.1628, norm: 2.1347, lr: 0.0001, tokens_per_second: 602.6320, time_per_step: 1699.2129
# Step 111: train_loss: 6.0723, norm: 2.5900, lr: 0.0001, tokens_per_second: 593.9030, time_per_step: 1724.1874
# Step 112: train_loss: 6.3349, norm: 2.2227, lr: 0.0001, tokens_per_second: 485.5001, time_per_step: 2109.1655
# Step 113: train_loss: 6.1735, norm: 2.3500, lr: 0.0001, tokens_per_second: 609.9467, time_per_step: 1678.8352
# Step 114: train_loss: 6.2749, norm: 2.4479, lr: 0.0001, tokens_per_second: 577.3573, time_per_step: 1773.5985
# Step 115: train_loss: 6.2744, norm: 1.8654, lr: 0.0001, tokens_per_second: 243.9478, time_per_step: 4197.6194
# Step 116: train_loss: 6.3290, norm: 2.0380, lr: 0.0001, tokens_per_second: 459.7310, time_per_step: 2227.3896
# Step 117: train_loss: 6.1508, norm: 2.3100, lr: 0.0001, tokens_per_second: 519.5604, time_per_step: 1970.8968
# Step 118: train_loss: 6.0662, norm: 3.8378, lr: 0.0001, tokens_per_second: 568.9716, time_per_step: 1799.7383
# Step 119: train_loss: 5.9728, norm: 1.7689, lr: 0.0001, tokens_per_second: 636.6162, time_per_step: 1608.5044
# Step 120: train_loss: 5.7112, norm: 2.5881, lr: 0.0001, tokens_per_second: 687.8704, time_per_step: 1488.6525
# Step 121: train_loss: 5.7937, norm: 2.3514, lr: 0.0001, tokens_per_second: 609.9263, time_per_step: 1678.8915
# Step 122: train_loss: 5.7751, norm: 2.2681, lr: 0.0001, tokens_per_second: 684.6735, time_per_step: 1495.6034
# Step 123: train_loss: 5.5128, norm: 2.1658, lr: 0.0001, tokens_per_second: 693.3217, time_per_step: 1476.9478
# Step 124: train_loss: 6.1367, norm: 2.2652, lr: 0.0001, tokens_per_second: 688.0950, time_per_step: 1488.1666
# Step 125: train_loss: 5.6986, norm: 1.9116, lr: 0.0001, tokens_per_second: 692.8799, time_per_step: 1477.8897
# Step 126: train_loss: 5.9153, norm: 2.4628, lr: 0.0001, tokens_per_second: 680.8208, time_per_step: 1504.0669
# Step 127: train_loss: 5.8653, norm: 2.3597, lr: 0.0001, tokens_per_second: 686.3876, time_per_step: 1491.8685
# Step 128: train_loss: 6.2726, norm: 2.6767, lr: 0.0001, tokens_per_second: 588.0542, time_per_step: 1741.3360
# Step 129: train_loss: 6.2547, norm: 1.9694, lr: 0.0001, tokens_per_second: 657.7432, time_per_step: 1556.8387
# Step 130: train_loss: 5.9418, norm: 1.7709, lr: 0.0001, tokens_per_second: 661.6660, time_per_step: 1547.6087
# Step 131: train_loss: 5.9734, norm: 2.0386, lr: 0.0001, tokens_per_second: 673.8717, time_per_step: 1519.5770
# Step 132: train_loss: 5.9480, norm: 2.0311, lr: 0.0001, tokens_per_second: 679.6904, time_per_step: 1506.5682
# Step 133: train_loss: 5.9348, norm: 3.4362, lr: 0.0001, tokens_per_second: 682.1891, time_per_step: 1501.0500
# Step 134: train_loss: 6.2358, norm: 2.2393, lr: 0.0001, tokens_per_second: 675.9287, time_per_step: 1514.9527
# Step 135: train_loss: 6.0622, norm: 2.1971, lr: 0.0001, tokens_per_second: 664.8557, time_per_step: 1540.1839
# Step 136: train_loss: 6.0280, norm: 2.2641, lr: 0.0001, tokens_per_second: 680.2165, time_per_step: 1505.4030
# Step 137: train_loss: 5.9972, norm: 2.5594, lr: 0.0001, tokens_per_second: 682.6707, time_per_step: 1499.9910
# Step 138: train_loss: 5.8945, norm: 2.0148, lr: 0.0001, tokens_per_second: 674.3111, time_per_step: 1518.5868
# Step 139: train_loss: 6.1795, norm: 1.9919, lr: 0.0001, tokens_per_second: 686.4888, time_per_step: 1491.6484
# Step 140: train_loss: 5.9942, norm: 1.6158, lr: 0.0001, tokens_per_second: 684.2355, time_per_step: 1496.5608
# Step 141: train_loss: 6.0303, norm: 1.6164, lr: 0.0001, tokens_per_second: 615.6767, time_per_step: 1663.2105
# Step 142: train_loss: 6.1866, norm: 1.8516, lr: 0.0001, tokens_per_second: 681.5869, time_per_step: 1502.3764
# Step 143: train_loss: 6.1681, norm: 1.8366, lr: 0.0001, tokens_per_second: 665.9427, time_per_step: 1537.6699
# Step 144: train_loss: 6.0374, norm: 1.9053, lr: 0.0001, tokens_per_second: 674.9150, time_per_step: 1517.2281
# Step 145: train_loss: 5.4977, norm: 2.5382, lr: 0.0001, tokens_per_second: 689.2651, time_per_step: 1485.6402
# Step 146: train_loss: 6.0261, norm: 1.9702, lr: 0.0001, tokens_per_second: 670.8646, time_per_step: 1526.3885
# Step 147: train_loss: 5.9137, norm: 2.0525, lr: 0.0001, tokens_per_second: 673.2583, time_per_step: 1520.9616
# Step 148: train_loss: 5.7741, norm: 2.1713, lr: 0.0001, tokens_per_second: 640.3968, time_per_step: 1599.0087
# Step 149: train_loss: 5.9427, norm: 1.6398, lr: 0.0001, tokens_per_second: 678.2617, time_per_step: 1509.7417
# Step 150: train_loss: 5.7368, norm: 2.1803, lr: 0.0001, tokens_per_second: 674.2455, time_per_step: 1518.7346
# Step 151: train_loss: 5.3666, norm: 2.2367, lr: 0.0001, tokens_per_second: 663.3073, time_per_step: 1543.7792
# Step 152: train_loss: 5.7653, norm: 4.7812, lr: 0.0001, tokens_per_second: 691.1153, time_per_step: 1481.6631
# Step 153: train_loss: 5.7352, norm: 2.1113, lr: 0.0001, tokens_per_second: 688.6608, time_per_step: 1486.9440
# Step 154: train_loss: 5.9593, norm: 2.0988, lr: 0.0001, tokens_per_second: 651.1290, time_per_step: 1572.6531
# Step 155: train_loss: 5.9621, norm: 2.0215, lr: 0.0001, tokens_per_second: 658.8771, time_per_step: 1554.1594
# Step 156: train_loss: 5.8042, norm: 1.8670, lr: 0.0001, tokens_per_second: 698.3456, time_per_step: 1466.3226
# Step 157: train_loss: 5.5186, norm: 1.8265, lr: 0.0001, tokens_per_second: 693.8490, time_per_step: 1475.8254
# Step 158: train_loss: 5.7720, norm: 2.2020, lr: 0.0001, tokens_per_second: 682.9725, time_per_step: 1499.3283
# Step 159: train_loss: 5.7535, norm: 1.7333, lr: 0.0001, tokens_per_second: 694.2862, time_per_step: 1474.8960
# Step 160: train_loss: 5.5084, norm: 1.9408, lr: 0.0001, tokens_per_second: 694.7809, time_per_step: 1473.8460
# Step 161: train_loss: 5.6763, norm: 2.0067, lr: 0.0001, tokens_per_second: 656.2131, time_per_step: 1560.4688
# Step 162: train_loss: 5.5456, norm: 1.9274, lr: 0.0001, tokens_per_second: 674.6276, time_per_step: 1517.8745
# Step 163: train_loss: 5.4290, norm: 2.2358, lr: 0.0001, tokens_per_second: 680.6925, time_per_step: 1504.3505
# Step 164: train_loss: 5.7452, norm: 1.8634, lr: 0.0001, tokens_per_second: 663.4692, time_per_step: 1543.4025
# Step 165: train_loss: 5.1469, norm: 2.0093, lr: 0.0001, tokens_per_second: 669.9831, time_per_step: 1528.3969
# Step 166: train_loss: 5.5354, norm: 1.9336, lr: 0.0001, tokens_per_second: 688.8351, time_per_step: 1486.5676
# Step 167: train_loss: 5.9657, norm: 2.0279, lr: 0.0001, tokens_per_second: 672.3927, time_per_step: 1522.9196
# Step 168: train_loss: 5.2336, norm: 2.4612, lr: 0.0001, tokens_per_second: 638.5621, time_per_step: 1603.6028
# Step 169: train_loss: 4.9439, norm: 1.9912, lr: 0.0001, tokens_per_second: 660.4446, time_per_step: 1550.4707
# Step 170: train_loss: 5.5423, norm: 2.0559, lr: 0.0001, tokens_per_second: 640.2740, time_per_step: 1599.3154
# Step 171: train_loss: 6.4663, norm: 1.9172, lr: 0.0001, tokens_per_second: 657.0156, time_per_step: 1558.5627
# Step 172: train_loss: 6.2355, norm: 2.1595, lr: 0.0001, tokens_per_second: 590.6150, time_per_step: 1733.7860
# Step 173: train_loss: 6.3538, norm: 1.8982, lr: 0.0001, tokens_per_second: 637.0261, time_per_step: 1607.4694
# Step 174: train_loss: 6.2644, norm: 2.3186, lr: 0.0001, tokens_per_second: 677.1236, time_per_step: 1512.2793
# Step 175: train_loss: 6.4157, norm: 2.1507, lr: 0.0002, tokens_per_second: 671.0668, time_per_step: 1525.9285
# Step 176: train_loss: 6.1556, norm: 1.9613, lr: 0.0002, tokens_per_second: 674.3290, time_per_step: 1518.5467
# Step 177: train_loss: 6.0070, norm: 2.4250, lr: 0.0002, tokens_per_second: 657.8661, time_per_step: 1556.5477
# Step 178: train_loss: 6.0078, norm: 2.6896, lr: 0.0002, tokens_per_second: 676.8557, time_per_step: 1512.8779
# Step 179: train_loss: 6.0214, norm: 1.9923, lr: 0.0002, tokens_per_second: 685.9723, time_per_step: 1492.7717
# Step 180: train_loss: 5.9478, norm: 1.8642, lr: 0.0002, tokens_per_second: 667.7103, time_per_step: 1533.5992
# Step 181: train_loss: 6.0463, norm: 1.7529, lr: 0.0002, tokens_per_second: 637.9419, time_per_step: 1605.1619
# Step 182: train_loss: 5.7454, norm: 1.9762, lr: 0.0002, tokens_per_second: 671.8826, time_per_step: 1524.0758
# Step 183: train_loss: 5.6517, norm: 1.8321, lr: 0.0002, tokens_per_second: 634.8702, time_per_step: 1612.9281
# Step 184: train_loss: 6.0840, norm: 2.1940, lr: 0.0002, tokens_per_second: 671.9194, time_per_step: 1523.9922
# Step 185: train_loss: 5.8390, norm: 2.1657, lr: 0.0002, tokens_per_second: 694.2518, time_per_step: 1474.9692
# Step 186: train_loss: 6.0126, norm: 2.5224, lr: 0.0002, tokens_per_second: 699.6054, time_per_step: 1463.6822
# Step 187: train_loss: 5.7958, norm: 1.7095, lr: 0.0002, tokens_per_second: 672.3044, time_per_step: 1523.1195
# Step 188: train_loss: 6.5213, norm: 2.0812, lr: 0.0002, tokens_per_second: 644.1200, time_per_step: 1589.7659
# Step 189: train_loss: 6.1942, norm: 1.7816, lr: 0.0002, tokens_per_second: 665.9720, time_per_step: 1537.6021
# Step 190: train_loss: 6.5840, norm: 2.0293, lr: 0.0002, tokens_per_second: 671.3475, time_per_step: 1525.2907
# Step 191: train_loss: 6.2288, norm: 2.5369, lr: 0.0002, tokens_per_second: 689.1883, time_per_step: 1485.8058
# Step 192: train_loss: 6.2339, norm: 2.0187, lr: 0.0002, tokens_per_second: 681.7004, time_per_step: 1502.1262
# Step 193: train_loss: 6.2351, norm: 2.6291, lr: 0.0002, tokens_per_second: 681.9407, time_per_step: 1501.5968
# Step 194: train_loss: 6.3248, norm: 1.7670, lr: 0.0002, tokens_per_second: 627.6016, time_per_step: 1631.6084
# Step 195: train_loss: 6.2063, norm: 2.3038, lr: 0.0002, tokens_per_second: 656.6269, time_per_step: 1559.4854
# Step 196: train_loss: 5.9269, norm: 1.6689, lr: 0.0002, tokens_per_second: 684.7905, time_per_step: 1495.3479
# Step 197: train_loss: 5.6098, norm: 1.7733, lr: 0.0002, tokens_per_second: 682.7567, time_per_step: 1499.8023
# Step 198: train_loss: 5.7012, norm: 2.0392, lr: 0.0002, tokens_per_second: 694.1954, time_per_step: 1475.0891
# Step 199: train_loss: 5.8418, norm: 1.7966, lr: 0.0002, tokens_per_second: 684.0048, time_per_step: 1497.0655
# Step 200: val_loss: 6.1469, val_time: 10594.8530
# ---------------
# <|endoftext|>:
# But,,, is see
# But have<|endoftext|>I shall
# WithThat'll be you are, but you,
# To are thee?<|endoftext|>KING
# ---------------
# Step 200: train_loss: 5.9232, norm: 3.5021, lr: 0.0002, tokens_per_second: 557.7024, time_per_step: 1836.1046
# saving model to /Users/jonathon/code/gollem/results/experiments/gpt2/0_gpt2_124M_on_tinyshakespeare/model_s200.pt
# model saved in 0.45675966699491255 seconds
# saving snapshot to /Users/jonathon/code/gollem/results/snapshots/snapshot.pt
# snapshot saved in 1.2362115410069237 seconds
# Step 201: train_loss: 5.7580, norm: 3.1271, lr: 0.0002, tokens_per_second: 597.9973, time_per_step: 1712.3822
# Step 202: train_loss: 5.8553, norm: 2.0619, lr: 0.0002, tokens_per_second: 664.0366, time_per_step: 1542.0836
# Step 203: train_loss: 5.5976, norm: 2.2508, lr: 0.0002, tokens_per_second: 703.5752, time_per_step: 1455.4236
# Step 204: train_loss: 5.5948, norm: 1.7566, lr: 0.0002, tokens_per_second: 694.0275, time_per_step: 1475.4458
# Step 205: train_loss: 5.5550, norm: 1.7791, lr: 0.0002, tokens_per_second: 637.4534, time_per_step: 1606.3920
# Step 206: train_loss: 6.3200, norm: 1.9940, lr: 0.0002, tokens_per_second: 663.6835, time_per_step: 1542.9041
# Step 207: train_loss: 6.0222, norm: 1.9868, lr: 0.0002, tokens_per_second: 676.5378, time_per_step: 1513.5888
# Step 208: train_loss: 5.3787, norm: 2.1577, lr: 0.0002, tokens_per_second: 685.8857, time_per_step: 1492.9601
# Step 209: train_loss: 5.3847, norm: 1.7844, lr: 0.0002, tokens_per_second: 690.9780, time_per_step: 1481.9575
# Step 210: train_loss: 6.0585, norm: 1.8802, lr: 0.0002, tokens_per_second: 692.2494, time_per_step: 1479.2356
# Step 211: train_loss: 5.9284, norm: 2.5222, lr: 0.0002, tokens_per_second: 646.3992, time_per_step: 1584.1605
# Step 212: train_loss: 6.3494, norm: 2.8271, lr: 0.0002, tokens_per_second: 637.6168, time_per_step: 1605.9803
# Step 213: train_loss: 6.1576, norm: 2.6258, lr: 0.0002, tokens_per_second: 665.8378, time_per_step: 1537.9121
# Step 214: train_loss: 6.1086, norm: 2.3499, lr: 0.0002, tokens_per_second: 669.9809, time_per_step: 1528.4018
# Step 215: train_loss: 5.8750, norm: 1.8723, lr: 0.0002, tokens_per_second: 683.0004, time_per_step: 1499.2670
# Step 216: train_loss: 5.9273, norm: 2.9275, lr: 0.0002, tokens_per_second: 697.2623, time_per_step: 1468.6009
# Step 217: train_loss: 5.7209, norm: 2.7559, lr: 0.0002, tokens_per_second: 635.7640, time_per_step: 1610.6605
# Step 218: train_loss: 5.9740, norm: 2.5104, lr: 0.0002, tokens_per_second: 660.1397, time_per_step: 1551.1867
# Step 219: train_loss: 5.3386, norm: 2.4517, lr: 0.0002, tokens_per_second: 662.1362, time_per_step: 1546.5095
# Step 220: train_loss: 5.6161, norm: 3.2602, lr: 0.0002, tokens_per_second: 663.9140, time_per_step: 1542.3685
# Step 221: train_loss: 5.6734, norm: 2.0778, lr: 0.0002, tokens_per_second: 680.3485, time_per_step: 1505.1110
# Step 222: train_loss: 5.6029, norm: 1.7403, lr: 0.0002, tokens_per_second: 654.3290, time_per_step: 1564.9620
# Step 223: train_loss: 5.3271, norm: 2.3610, lr: 0.0002, tokens_per_second: 697.9844, time_per_step: 1467.0815
# Step 224: train_loss: 5.6698, norm: 1.7971, lr: 0.0002, tokens_per_second: 635.5734, time_per_step: 1611.1436
# Step 225: train_loss: 5.6585, norm: 2.0481, lr: 0.0002, tokens_per_second: 597.6406, time_per_step: 1713.4043
# Step 226: train_loss: 5.6860, norm: 2.0238, lr: 0.0002, tokens_per_second: 665.8943, time_per_step: 1537.7817
# Step 227: train_loss: 6.1731, norm: 2.3721, lr: 0.0002, tokens_per_second: 655.2122, time_per_step: 1562.8524
# Step 228: train_loss: 5.8575, norm: 1.7678, lr: 0.0002, tokens_per_second: 679.3667, time_per_step: 1507.2860
# Step 229: train_loss: 5.5678, norm: 2.2008, lr: 0.0002, tokens_per_second: 686.1292, time_per_step: 1492.4304
# Step 230: train_loss: 5.6214, norm: 1.7888, lr: 0.0002, tokens_per_second: 692.9503, time_per_step: 1477.7395
# Step 231: train_loss: 5.8125, norm: 2.1767, lr: 0.0002, tokens_per_second: 677.3868, time_per_step: 1511.6917
# Step 232: train_loss: 5.2753, norm: 1.8420, lr: 0.0002, tokens_per_second: 678.8631, time_per_step: 1508.4042
# Step 233: train_loss: 5.4906, norm: 2.3679, lr: 0.0002, tokens_per_second: 686.5803, time_per_step: 1491.4497
# Step 234: train_loss: 5.3915, norm: 2.0277, lr: 0.0002, tokens_per_second: 677.7232, time_per_step: 1510.9414
# Step 235: train_loss: 5.8378, norm: 1.7418, lr: 0.0002, tokens_per_second: 684.2321, time_per_step: 1496.5682
# Step 236: train_loss: 4.9528, norm: 1.9360, lr: 0.0002, tokens_per_second: 670.1335, time_per_step: 1528.0537
# Step 237: train_loss: 5.2534, norm: 1.7949, lr: 0.0002, tokens_per_second: 687.8703, time_per_step: 1488.6526
# Step 238: train_loss: 5.5257, norm: 1.6156, lr: 0.0002, tokens_per_second: 587.1058, time_per_step: 1744.1490
# Step 239: train_loss: 4.7655, norm: 2.3971, lr: 0.0002, tokens_per_second: 635.3528, time_per_step: 1611.7029
# Step 240: train_loss: 5.4448, norm: 1.6996, lr: 0.0002, tokens_per_second: 650.8924, time_per_step: 1573.2246
# Step 241: train_loss: 4.9744, norm: 1.9508, lr: 0.0002, tokens_per_second: 654.0396, time_per_step: 1565.6545
# Step 242: train_loss: 5.0332, norm: 2.2829, lr: 0.0002, tokens_per_second: 672.5518, time_per_step: 1522.5593
# Step 243: train_loss: 4.7955, norm: 1.7497, lr: 0.0002, tokens_per_second: 694.6336, time_per_step: 1474.1584
# Step 244: train_loss: 4.9549, norm: 1.9597, lr: 0.0002, tokens_per_second: 685.2033, time_per_step: 1494.4469
# Step 245: train_loss: 5.4183, norm: 1.5465, lr: 0.0002, tokens_per_second: 657.9135, time_per_step: 1556.4355
# Step 246: train_loss: 5.6802, norm: 1.8567, lr: 0.0002, tokens_per_second: 676.7189, time_per_step: 1513.1838
# Step 247: train_loss: 6.4075, norm: 1.7089, lr: 0.0002, tokens_per_second: 682.5584, time_per_step: 1500.2380
# Step 248: train_loss: 5.5717, norm: 2.1349, lr: 0.0002, tokens_per_second: 671.9132, time_per_step: 1524.0065
# Step 249: train_loss: 6.1863, norm: 1.9187, lr: 0.0002, tokens_per_second: 666.0017, time_per_step: 1537.5335
# Step 250: train_loss: 6.0958, norm: 2.0090, lr: 0.0002, tokens_per_second: 682.1541, time_per_step: 1501.1270
# Step 251: train_loss: 5.6103, norm: 1.7005, lr: 0.0002, tokens_per_second: 634.8025, time_per_step: 1613.1001
# Step 252: train_loss: 5.8721, norm: 1.8957, lr: 0.0002, tokens_per_second: 639.1661, time_per_step: 1602.0875
# Step 253: train_loss: 6.0660, norm: 2.6429, lr: 0.0002, tokens_per_second: 624.8400, time_per_step: 1638.8194
# Step 254: train_loss: 5.8728, norm: 2.0299, lr: 0.0002, tokens_per_second: 678.6496, time_per_step: 1508.8787
# Step 255: train_loss: 5.4254, norm: 2.6629, lr: 0.0002, tokens_per_second: 683.0093, time_per_step: 1499.2475
# Step 256: train_loss: 5.7403, norm: 1.5951, lr: 0.0002, tokens_per_second: 694.9969, time_per_step: 1473.3879
# Step 257: train_loss: 5.6179, norm: 2.2481, lr: 0.0002, tokens_per_second: 678.3942, time_per_step: 1509.4468
# Step 258: train_loss: 5.5000, norm: 1.8773, lr: 0.0002, tokens_per_second: 630.9423, time_per_step: 1622.9693
# Step 259: train_loss: 5.1707, norm: 2.6820, lr: 0.0002, tokens_per_second: 666.8540, time_per_step: 1535.5686
# Step 260: train_loss: 5.3914, norm: 1.6185, lr: 0.0002, tokens_per_second: 672.5234, time_per_step: 1522.6236
# Step 261: train_loss: 5.7637, norm: 1.6590, lr: 0.0002, tokens_per_second: 654.6444, time_per_step: 1564.2080
# Step 262: train_loss: 5.8218, norm: 2.0040, lr: 0.0002, tokens_per_second: 651.8947, time_per_step: 1570.8058
# Step 263: train_loss: 5.9715, norm: 1.9256, lr: 0.0002, tokens_per_second: 694.1096, time_per_step: 1475.2712
# Step 264: train_loss: 5.1179, norm: 1.9028, lr: 0.0002, tokens_per_second: 652.1522, time_per_step: 1570.1855
# Step 265: train_loss: 5.0130, norm: 1.8202, lr: 0.0002, tokens_per_second: 655.7581, time_per_step: 1561.5515
# Step 266: train_loss: 5.5795, norm: 1.8481, lr: 0.0002, tokens_per_second: 680.9943, time_per_step: 1503.6837
# Step 267: train_loss: 5.8858, norm: 2.5980, lr: 0.0002, tokens_per_second: 684.7522, time_per_step: 1495.4315
# Step 268: train_loss: 5.3718, norm: 3.3393, lr: 0.0002, tokens_per_second: 674.4123, time_per_step: 1518.3591
# Step 269: train_loss: 5.1824, norm: 1.6760, lr: 0.0002, tokens_per_second: 697.0133, time_per_step: 1469.1255
# Step 270: train_loss: 5.1243, norm: 1.6842, lr: 0.0002, tokens_per_second: 678.7596, time_per_step: 1508.6342
# Step 271: train_loss: 4.8580, norm: 1.7249, lr: 0.0002, tokens_per_second: 656.4679, time_per_step: 1559.8630
# Step 272: train_loss: 5.1009, norm: 2.1601, lr: 0.0002, tokens_per_second: 689.2122, time_per_step: 1485.7543
# Step 273: train_loss: 5.1067, norm: 1.6396, lr: 0.0002, tokens_per_second: 689.3557, time_per_step: 1485.4451
# Step 274: train_loss: 4.9847, norm: 1.6045, lr: 0.0002, tokens_per_second: 693.8566, time_per_step: 1475.8092
# Step 275: train_loss: 4.9497, norm: 1.6615, lr: 0.0002, tokens_per_second: 656.3564, time_per_step: 1560.1280
# Step 276: train_loss: 4.9733, norm: 2.2015, lr: 0.0002, tokens_per_second: 689.2006, time_per_step: 1485.7794
# Step 277: train_loss: 4.6882, norm: 1.6940, lr: 0.0002, tokens_per_second: 637.1113, time_per_step: 1607.2546
# Step 278: train_loss: 4.4107, norm: 1.8281, lr: 0.0002, tokens_per_second: 629.4680, time_per_step: 1626.7704
# Step 279: train_loss: 4.5884, norm: 1.6967, lr: 0.0002, tokens_per_second: 670.2408, time_per_step: 1527.8092
# Step 280: train_loss: 5.6690, norm: 2.0367, lr: 0.0002, tokens_per_second: 674.7129, time_per_step: 1517.6826
# Step 281: train_loss: 6.1607, norm: 1.9267, lr: 0.0002, tokens_per_second: 651.3464, time_per_step: 1572.1281
# Step 282: train_loss: 6.0942, norm: 2.5232, lr: 0.0002, tokens_per_second: 691.8389, time_per_step: 1480.1135
# Step 283: train_loss: 6.1358, norm: 2.0033, lr: 0.0002, tokens_per_second: 686.9228, time_per_step: 1490.7060
# Step 284: train_loss: 5.9261, norm: 2.2479, lr: 0.0002, tokens_per_second: 620.6475, time_per_step: 1649.8898
# Step 285: train_loss: 6.0192, norm: 2.2397, lr: 0.0002, tokens_per_second: 663.1006, time_per_step: 1544.2603
# Step 286: train_loss: 5.9601, norm: 1.8559, lr: 0.0002, tokens_per_second: 663.6218, time_per_step: 1543.0476
# Step 287: train_loss: 5.5448, norm: 1.8751, lr: 0.0002, tokens_per_second: 666.6971, time_per_step: 1535.9299
# Step 288: train_loss: 5.7255, norm: 2.7508, lr: 0.0002, tokens_per_second: 675.5673, time_per_step: 1515.7631
# Step 289: train_loss: 5.7582, norm: 2.0924, lr: 0.0002, tokens_per_second: 683.4816, time_per_step: 1498.2116
# Step 290: train_loss: 5.5934, norm: 2.4150, lr: 0.0002, tokens_per_second: 689.7415, time_per_step: 1484.6143
# Step 291: train_loss: 5.8558, norm: 2.2545, lr: 0.0003, tokens_per_second: 610.4238, time_per_step: 1677.5232
# Step 292: train_loss: 6.0984, norm: 4.8077, lr: 0.0003, tokens_per_second: 651.2973, time_per_step: 1572.2467
# Step 293: train_loss: 6.1114, norm: 5.0993, lr: 0.0003, tokens_per_second: 682.3379, time_per_step: 1500.7227
# Step 294: train_loss: 5.9525, norm: 2.4007, lr: 0.0003, tokens_per_second: 683.6408, time_per_step: 1497.8626
# Step 295: train_loss: 5.6997, norm: 2.1868, lr: 0.0003, tokens_per_second: 669.3000, time_per_step: 1529.9567
# Step 296: train_loss: 5.5147, norm: 1.7812, lr: 0.0003, tokens_per_second: 671.2735, time_per_step: 1525.4587
# Step 297: train_loss: 5.9249, norm: 2.2252, lr: 0.0003, tokens_per_second: 653.8606, time_per_step: 1566.0830
# Step 298: train_loss: 5.8042, norm: 1.9183, lr: 0.0003, tokens_per_second: 644.8251, time_per_step: 1588.0275
# Step 299: train_loss: 5.8587, norm: 1.7739, lr: 0.0003, tokens_per_second: 683.2202, time_per_step: 1498.7847
# Step 300: val_loss: 5.7811, val_time: 10792.4602
# ---------------
# <|endoftext|>First;
# But that you to all;
# And I had he is this time-What?
# And she with one;
# What doth I have
# ---------------
# Step 300: train_loss: 5.5808, norm: 1.7591, lr: 0.0003, tokens_per_second: 542.2117, time_per_step: 1888.5611
# saving model to /Users/jonathon/code/gollem/results/experiments/gpt2/0_gpt2_124M_on_tinyshakespeare/model_s300.pt
# model saved in 0.46699020800588187 seconds
# saving snapshot to /Users/jonathon/code/gollem/results/snapshots/snapshot.pt
# snapshot saved in 1.265574082994135 seconds
# Step 301: train_loss: 5.7133, norm: 1.6570, lr: 0.0003, tokens_per_second: 580.3189, time_per_step: 1764.5471
# Step 302: train_loss: 5.5964, norm: 2.2341, lr: 0.0003, tokens_per_second: 610.3684, time_per_step: 1677.6754
# Step 303: train_loss: 5.7519, norm: 2.3572, lr: 0.0003, tokens_per_second: 631.9960, time_per_step: 1620.2635
# Step 304: train_loss: 6.0076, norm: 1.8368, lr: 0.0003, tokens_per_second: 662.9017, time_per_step: 1544.7238
# Step 305: train_loss: 5.6762, norm: 2.7004, lr: 0.0003, tokens_per_second: 629.3765, time_per_step: 1627.0070
# Step 306: train_loss: 5.9872, norm: 1.9780, lr: 0.0003, tokens_per_second: 636.8851, time_per_step: 1607.8254
# Step 307: train_loss: 5.4925, norm: 2.9392, lr: 0.0003, tokens_per_second: 605.5991, time_per_step: 1690.8877
# Step 308: train_loss: 5.5203, norm: 2.5021, lr: 0.0003, tokens_per_second: 598.4851, time_per_step: 1710.9866
# Step 309: train_loss: 5.6242, norm: 2.2126, lr: 0.0003, tokens_per_second: 624.5137, time_per_step: 1639.6759
# Step 310: train_loss: 5.7444, norm: 1.8343, lr: 0.0003, tokens_per_second: 688.9488, time_per_step: 1486.3225
# Step 311: train_loss: 5.1898, norm: 2.3070, lr: 0.0003, tokens_per_second: 677.9754, time_per_step: 1510.3793
# Step 312: train_loss: 5.5258, norm: 2.2930, lr: 0.0003, tokens_per_second: 657.4291, time_per_step: 1557.5824
# Step 313: train_loss: 5.1243, norm: 1.5086, lr: 0.0003, tokens_per_second: 670.5316, time_per_step: 1527.1464
# Step 314: train_loss: 5.6470, norm: 1.7692, lr: 0.0003, tokens_per_second: 575.2226, time_per_step: 1780.1803
# Step 315: train_loss: 5.6877, norm: 2.1416, lr: 0.0003, tokens_per_second: 637.4619, time_per_step: 1606.3705
# Step 316: train_loss: 5.4335, norm: 2.4293, lr: 0.0003, tokens_per_second: 655.3342, time_per_step: 1562.5615
# Step 317: train_loss: 5.0444, norm: 2.2263, lr: 0.0003, tokens_per_second: 687.6679, time_per_step: 1489.0909
# Step 318: train_loss: 5.3244, norm: 1.8333, lr: 0.0003, tokens_per_second: 640.9644, time_per_step: 1597.5927
# Step 319: train_loss: 5.3004, norm: 1.8804, lr: 0.0003, tokens_per_second: 686.2489, time_per_step: 1492.1699
# Step 320: train_loss: 5.4963, norm: 1.9146, lr: 0.0003, tokens_per_second: 629.5758, time_per_step: 1626.4920
# Step 321: train_loss: 5.2077, norm: 2.9060, lr: 0.0003, tokens_per_second: 591.0389, time_per_step: 1732.5424
# Step 322: train_loss: 5.3018, norm: 2.0036, lr: 0.0003, tokens_per_second: 653.4921, time_per_step: 1566.9662
# Step 323: train_loss: 5.1602, norm: 1.7163, lr: 0.0003, tokens_per_second: 695.2865, time_per_step: 1472.7741
# Step 324: train_loss: 4.9754, norm: 1.9079, lr: 0.0003, tokens_per_second: 667.0539, time_per_step: 1535.1083
# Step 325: train_loss: 4.8435, norm: 1.6848, lr: 0.0003, tokens_per_second: 571.6477, time_per_step: 1791.3131
# Step 326: train_loss: 5.0576, norm: 1.7664, lr: 0.0003, tokens_per_second: 635.1868, time_per_step: 1612.1241
# Step 327: train_loss: 5.1587, norm: 1.5920, lr: 0.0003, tokens_per_second: 596.8320, time_per_step: 1715.7256
# Step 328: train_loss: 4.8085, norm: 1.6248, lr: 0.0003, tokens_per_second: 648.1226, time_per_step: 1579.9480
# Step 329: train_loss: 5.2075, norm: 1.4110, lr: 0.0003, tokens_per_second: 677.5935, time_per_step: 1511.2305
# Step 330: train_loss: 5.3624, norm: 1.4648, lr: 0.0003, tokens_per_second: 689.5895, time_per_step: 1484.9414
# Step 331: train_loss: 5.2007, norm: 1.4894, lr: 0.0003, tokens_per_second: 640.5558, time_per_step: 1598.6117
# Step 332: train_loss: 5.3657, norm: 1.4567, lr: 0.0003, tokens_per_second: 692.4304, time_per_step: 1478.8491
# Step 333: train_loss: 5.2281, norm: 2.0763, lr: 0.0003, tokens_per_second: 616.7669, time_per_step: 1660.2706
# Step 334: train_loss: 4.9974, norm: 2.3351, lr: 0.0003, tokens_per_second: 629.9903, time_per_step: 1625.4218
# Step 335: train_loss: 5.3572, norm: 2.4873, lr: 0.0003, tokens_per_second: 674.1816, time_per_step: 1518.8786
# Step 336: train_loss: 5.2184, norm: 2.4032, lr: 0.0003, tokens_per_second: 696.0719, time_per_step: 1471.1123
# Step 337: train_loss: 5.6521, norm: 2.6392, lr: 0.0003, tokens_per_second: 679.9190, time_per_step: 1506.0618
# Step 338: train_loss: 5.4016, norm: 2.5868, lr: 0.0003, tokens_per_second: 659.0060, time_per_step: 1553.8554
# Step 339: train_loss: 5.2968, norm: 1.8048, lr: 0.0003, tokens_per_second: 648.2054, time_per_step: 1579.7461
# Step 340: train_loss: 4.8301, norm: 2.0687, lr: 0.0003, tokens_per_second: 637.7196, time_per_step: 1605.7214
# Step 341: train_loss: 4.6447, norm: 2.0670, lr: 0.0003, tokens_per_second: 688.1998, time_per_step: 1487.9400
# Step 342: train_loss: 4.8529, norm: 1.7900, lr: 0.0003, tokens_per_second: 694.8133, time_per_step: 1473.7772
# Step 343: train_loss: 4.6812, norm: 1.6023, lr: 0.0003, tokens_per_second: 701.4903, time_per_step: 1459.7493
# Step 344: train_loss: 4.8689, norm: 2.1694, lr: 0.0003, tokens_per_second: 686.2625, time_per_step: 1492.1403
# Step 345: train_loss: 5.6057, norm: 1.3317, lr: 0.0003, tokens_per_second: 644.2144, time_per_step: 1589.5330
# Step 346: train_loss: 5.5326, norm: 1.6594, lr: 0.0003, tokens_per_second: 638.3700, time_per_step: 1604.0854
# Step 347: train_loss: 5.5135, norm: 2.8489, lr: 0.0003, tokens_per_second: 575.9921, time_per_step: 1777.8023
# Step 348: train_loss: 5.3450, norm: 1.7094, lr: 0.0003, tokens_per_second: 668.6523, time_per_step: 1531.4386
# Step 349: train_loss: 5.1167, norm: 1.4299, lr: 0.0003, tokens_per_second: 632.1898, time_per_step: 1619.7668
# Step 350: train_loss: 5.7666, norm: 1.6793, lr: 0.0003, tokens_per_second: 679.0306, time_per_step: 1508.0321
# Step 351: train_loss: 5.7482, norm: 1.5928, lr: 0.0003, tokens_per_second: 662.2413, time_per_step: 1546.2643
# Step 352: train_loss: 5.7724, norm: 1.7354, lr: 0.0003, tokens_per_second: 671.8008, time_per_step: 1524.2613
# Step 353: train_loss: 5.7131, norm: 1.7396, lr: 0.0003, tokens_per_second: 629.3830, time_per_step: 1626.9903
# Step 354: train_loss: 5.6603, norm: 1.6960, lr: 0.0003, tokens_per_second: 633.4441, time_per_step: 1616.5595
# Step 355: train_loss: 5.7491, norm: 1.9782, lr: 0.0003, tokens_per_second: 687.0495, time_per_step: 1490.4311
# Step 356: train_loss: 5.3598, norm: 1.8979, lr: 0.0003, tokens_per_second: 677.8430, time_per_step: 1510.6744
# Step 357: train_loss: 5.5807, norm: 1.6129, lr: 0.0003, tokens_per_second: 667.9441, time_per_step: 1533.0623
# Step 358: train_loss: 5.8708, norm: 1.9001, lr: 0.0003, tokens_per_second: 645.3131, time_per_step: 1586.8265
# Step 359: train_loss: 5.5785, norm: 2.1521, lr: 0.0003, tokens_per_second: 589.9903, time_per_step: 1735.6219
# Step 360: train_loss: 5.3838, norm: 1.5743, lr: 0.0003, tokens_per_second: 688.1690, time_per_step: 1488.0065
# Step 361: train_loss: 5.6844, norm: 2.7040, lr: 0.0003, tokens_per_second: 674.5254, time_per_step: 1518.1043
# Step 362: train_loss: 5.7507, norm: 1.9878, lr: 0.0003, tokens_per_second: 651.8279, time_per_step: 1570.9668
# Step 363: train_loss: 5.3914, norm: 1.9422, lr: 0.0003, tokens_per_second: 680.4324, time_per_step: 1504.9254
# Step 364: train_loss: 5.4351, norm: 3.0440, lr: 0.0003, tokens_per_second: 656.2057, time_per_step: 1560.4863
# Step 365: train_loss: 5.1738, norm: 2.0219, lr: 0.0003, tokens_per_second: 598.5891, time_per_step: 1710.6893
# Step 366: train_loss: 5.4230, norm: 1.7736, lr: 0.0003, tokens_per_second: 624.5513, time_per_step: 1639.5770
# Step 367: train_loss: 5.6190, norm: 1.6061, lr: 0.0003, tokens_per_second: 649.8366, time_per_step: 1575.7808
# Step 368: train_loss: 5.6189, norm: 1.7026, lr: 0.0003, tokens_per_second: 672.7340, time_per_step: 1522.1469
# Step 369: train_loss: 5.4167, norm: 2.0491, lr: 0.0003, tokens_per_second: 674.3802, time_per_step: 1518.4312
# Step 370: train_loss: 5.4041, norm: 1.8930, lr: 0.0003, tokens_per_second: 645.0492, time_per_step: 1587.4758
# Step 371: train_loss: 5.4073, norm: 1.4575, lr: 0.0003, tokens_per_second: 589.2788, time_per_step: 1737.7175
# Step 372: train_loss: 4.9701, norm: 2.1955, lr: 0.0003, tokens_per_second: 537.2130, time_per_step: 1906.1341
# Step 373: train_loss: 5.5216, norm: 1.9157, lr: 0.0003, tokens_per_second: 653.3119, time_per_step: 1567.3983
# Step 374: train_loss: 5.1387, norm: 1.8807, lr: 0.0003, tokens_per_second: 682.3800, time_per_step: 1500.6301
# Step 375: train_loss: 5.2692, norm: 2.0332, lr: 0.0003, tokens_per_second: 675.2973, time_per_step: 1516.3693
# Step 376: train_loss: 5.1515, norm: 1.6794, lr: 0.0003, tokens_per_second: 665.3535, time_per_step: 1539.0316
# Step 377: train_loss: 4.5079, norm: 1.3488, lr: 0.0003, tokens_per_second: 643.3468, time_per_step: 1591.6765
# Step 378: train_loss: 5.4081, norm: 1.5448, lr: 0.0003, tokens_per_second: 652.3168, time_per_step: 1569.7895
# Step 379: train_loss: 5.1298, norm: 1.6034, lr: 0.0003, tokens_per_second: 641.9137, time_per_step: 1595.2300
# Step 380: train_loss: 4.1025, norm: 3.0666, lr: 0.0003, tokens_per_second: 636.3102, time_per_step: 1609.2781
# Step 381: train_loss: 4.3380, norm: 1.5917, lr: 0.0003, tokens_per_second: 665.0358, time_per_step: 1539.7667
# Step 382: train_loss: 4.9882, norm: 1.8140, lr: 0.0003, tokens_per_second: 695.4203, time_per_step: 1472.4908
# Step 383: train_loss: 5.2826, norm: 1.9060, lr: 0.0003, tokens_per_second: 677.7115, time_per_step: 1510.9674
# Step 384: train_loss: 5.2969, norm: 1.6891, lr: 0.0003, tokens_per_second: 630.7727, time_per_step: 1623.4056
# Step 385: train_loss: 5.4843, norm: 2.1861, lr: 0.0003, tokens_per_second: 598.6514, time_per_step: 1710.5113
# ...
# Step 864: train_loss: 5.3873, norm: 2.1666, lr: 0.0003, tokens_per_second: 695.2999, time_per_step: 1472.7458
# Step 865: train_loss: 5.3765, norm: 2.1235, lr: 0.0003, tokens_per_second: 694.9828, time_per_step: 1473.4177
# Step 866: train_loss: 5.2599, norm: 2.6401, lr: 0.0002, tokens_per_second: 693.6138, time_per_step: 1476.3259
# Step 867: train_loss: 5.2582, norm: 2.1442, lr: 0.0002, tokens_per_second: 689.0523, time_per_step: 1486.0991
# Step 868: train_loss: 5.2250, norm: 1.4691, lr: 0.0002, tokens_per_second: 675.3924, time_per_step: 1516.1556
# Step 869: train_loss: 4.8091, norm: 2.0068, lr: 0.0002, tokens_per_second: 698.6372, time_per_step: 1465.7107
# Step 870: train_loss: 4.7115, norm: 3.4878, lr: 0.0002, tokens_per_second: 692.1734, time_per_step: 1479.3982
# Step 871: train_loss: 4.9043, norm: 2.4973, lr: 0.0002, tokens_per_second: 698.4872, time_per_step: 1466.0254
# Step 872: train_loss: 4.7836, norm: 2.2313, lr: 0.0002, tokens_per_second: 670.8266, time_per_step: 1526.4750
# Step 873: train_loss: 5.0706, norm: 1.7983, lr: 0.0002, tokens_per_second: 671.9167, time_per_step: 1523.9984
# Step 874: train_loss: 5.2666, norm: 2.6361, lr: 0.0002, tokens_per_second: 688.1416, time_per_step: 1488.0658
# Step 875: train_loss: 5.1402, norm: 2.9021, lr: 0.0002, tokens_per_second: 643.8725, time_per_step: 1590.3771
# Step 876: train_loss: 5.0153, norm: 2.0397, lr: 0.0002, tokens_per_second: 671.2160, time_per_step: 1525.5893
# Step 877: train_loss: 4.8447, norm: 1.4919, lr: 0.0002, tokens_per_second: 660.7781, time_per_step: 1549.6882
# Step 878: train_loss: 4.6785, norm: 1.7179, lr: 0.0002, tokens_per_second: 671.2482, time_per_step: 1525.5163
# Step 879: train_loss: 5.1084, norm: 1.7990, lr: 0.0002, tokens_per_second: 664.9925, time_per_step: 1539.8671
# Step 880: train_loss: 5.0632, norm: 1.5410, lr: 0.0002, tokens_per_second: 678.3216, time_per_step: 1509.6083
# Step 881: train_loss: 5.0563, norm: 1.5699, lr: 0.0002, tokens_per_second: 687.7670, time_per_step: 1488.8763
# Step 882: train_loss: 4.7918, norm: 1.5408, lr: 0.0002, tokens_per_second: 680.4069, time_per_step: 1504.9818
# Step 883: train_loss: 4.8917, norm: 1.5980, lr: 0.0002, tokens_per_second: 688.6013, time_per_step: 1487.0724
# Step 884: train_loss: 4.7131, norm: 1.4591, lr: 0.0002, tokens_per_second: 651.4614, time_per_step: 1571.8505
# Step 885: train_loss: 4.7726, norm: 1.4612, lr: 0.0002, tokens_per_second: 687.4921, time_per_step: 1489.4716
# Step 886: train_loss: 5.2219, norm: 1.5043, lr: 0.0002, tokens_per_second: 693.9367, time_per_step: 1475.6388
# Step 887: train_loss: 4.7174, norm: 1.6492, lr: 0.0002, tokens_per_second: 689.6419, time_per_step: 1484.8286
# Step 888: train_loss: 5.0162, norm: 1.8805, lr: 0.0002, tokens_per_second: 610.8277, time_per_step: 1676.4138
# Step 889: train_loss: 4.2607, norm: 2.5313, lr: 0.0002, tokens_per_second: 690.3584, time_per_step: 1483.2875
# Step 890: train_loss: 4.4898, norm: 1.9043, lr: 0.0002, tokens_per_second: 677.4697, time_per_step: 1511.5068
# Step 891: train_loss: 4.6771, norm: 1.5081, lr: 0.0002, tokens_per_second: 662.3797, time_per_step: 1545.9411
# Step 892: train_loss: 4.7434, norm: 1.5837, lr: 0.0002, tokens_per_second: 673.8536, time_per_step: 1519.6179
# Step 893: train_loss: 4.3124, norm: 1.5869, lr: 0.0002, tokens_per_second: 688.6302, time_per_step: 1487.0100
# Step 894: train_loss: 4.5937, norm: 1.8560, lr: 0.0002, tokens_per_second: 675.2941, time_per_step: 1516.3764
# Step 895: train_loss: 4.3343, norm: 1.4577, lr: 0.0002, tokens_per_second: 681.2417, time_per_step: 1503.1375
# Step 896: train_loss: 4.8130, norm: 1.5792, lr: 0.0002, tokens_per_second: 649.1233, time_per_step: 1577.5124
# Step 897: train_loss: 4.8043, norm: 2.3928, lr: 0.0002, tokens_per_second: 685.9990, time_per_step: 1492.7135
# Step 898: train_loss: 4.5929, norm: 1.9723, lr: 0.0002, tokens_per_second: 686.4114, time_per_step: 1491.8167
# Step 899: train_loss: 4.3136, norm: 1.7153, lr: 0.0002, tokens_per_second: 701.0023, time_per_step: 1460.7656
# Step 900: val_loss: 5.4662, val_time: 10383.8952
# ---------------
# <|endoftext|>QUE ANHAM, to
# To him in the world
# So shallst!<|endoftext|>ThirdUCKETH:
# That you, his son, that I may
# ---------------
# Step 900: train_loss: 4.5376, norm: 1.5405, lr: 0.0002, tokens_per_second: 666.1766, time_per_step: 1537.1300
# saving model to /Users/jonathon/code/gollem/results/experiments/gpt2/0_gpt2_124M_on_tinyshakespeare/model_s900.pt
# model saved in 0.4484257090080064 seconds
# saving snapshot to /Users/jonathon/code/gollem/results/snapshots/snapshot.pt
# snapshot saved in 1.1622573330096202 seconds
# Step 901: train_loss: 4.5514, norm: 1.5032, lr: 0.0001, tokens_per_second: 665.7717, time_per_step: 1538.0648
# Step 902: train_loss: 4.6835, norm: 1.5241, lr: 0.0001, tokens_per_second: 697.6122, time_per_step: 1467.8642
# Step 903: train_loss: 4.4925, norm: 1.4554, lr: 0.0001, tokens_per_second: 704.2407, time_per_step: 1454.0482
# Step 904: train_loss: 4.4229, norm: 1.5533, lr: 0.0001, tokens_per_second: 689.6508, time_per_step: 1484.8095
# Step 905: train_loss: 4.2200, norm: 1.4204, lr: 0.0001, tokens_per_second: 680.5463, time_per_step: 1504.6735
# Step 906: train_loss: 4.1257, norm: 1.6603, lr: 0.0001, tokens_per_second: 696.3832, time_per_step: 1470.4548
# Step 907: train_loss: 4.0491, norm: 1.3282, lr: 0.0001, tokens_per_second: 672.7872, time_per_step: 1522.0266
# Step 908: train_loss: 4.2488, norm: 1.5823, lr: 0.0001, tokens_per_second: 684.8213, time_per_step: 1495.2806
# Step 909: train_loss: 4.4100, norm: 1.4895, lr: 0.0001, tokens_per_second: 627.5327, time_per_step: 1631.7875
# Step 910: train_loss: 4.0816, norm: 1.5454, lr: 0.0001, tokens_per_second: 633.5766, time_per_step: 1616.2213
# Step 911: train_loss: 4.5553, norm: 1.3550, lr: 0.0001, tokens_per_second: 673.5841, time_per_step: 1520.2260
# Step 912: train_loss: 4.7076, norm: 1.4408, lr: 0.0001, tokens_per_second: 667.8644, time_per_step: 1533.2454
# Step 913: train_loss: 4.5456, norm: 1.3568, lr: 0.0001, tokens_per_second: 646.7770, time_per_step: 1583.2350
# Step 914: train_loss: 4.7149, norm: 1.6803, lr: 0.0001, tokens_per_second: 697.0808, time_per_step: 1468.9832
# Step 915: train_loss: 4.6004, norm: 1.5079, lr: 0.0001, tokens_per_second: 689.4669, time_per_step: 1485.2055
# Step 916: train_loss: 4.1279, norm: 1.3790, lr: 0.0001, tokens_per_second: 692.7706, time_per_step: 1478.1228
# Step 917: train_loss: 4.4668, norm: 1.6488, lr: 0.0001, tokens_per_second: 683.2981, time_per_step: 1498.6137
# Step 918: train_loss: 4.3506, norm: 2.0058, lr: 0.0001, tokens_per_second: 673.8722, time_per_step: 1519.5760
# Step 919: train_loss: 4.8226, norm: 1.6438, lr: 0.0001, tokens_per_second: 664.3992, time_per_step: 1541.2421
# Step 920: train_loss: 4.6108, norm: 1.4966, lr: 0.0001, tokens_per_second: 678.0916, time_per_step: 1510.1205
# Step 921: train_loss: 4.5071, norm: 1.4826, lr: 0.0001, tokens_per_second: 671.7149, time_per_step: 1524.4562
# Step 922: train_loss: 4.0747, norm: 1.6033, lr: 0.0001, tokens_per_second: 682.5054, time_per_step: 1500.3545
# Step 923: train_loss: 3.9916, norm: 1.5980, lr: 0.0001, tokens_per_second: 686.2177, time_per_step: 1492.2379
# Step 924: train_loss: 4.2472, norm: 1.5044, lr: 0.0001, tokens_per_second: 678.2592, time_per_step: 1509.7474
# Step 925: train_loss: 4.1287, norm: 1.4736, lr: 0.0001, tokens_per_second: 683.3548, time_per_step: 1498.4895
# Step 926: train_loss: 4.2086, norm: 1.6011, lr: 0.0001, tokens_per_second: 674.2949, time_per_step: 1518.6235
# Step 927: train_loss: 4.9042, norm: 1.5186, lr: 0.0001, tokens_per_second: 694.0551, time_per_step: 1475.3872
# Step 928: train_loss: 4.8006, norm: 1.4537, lr: 0.0001, tokens_per_second: 688.8053, time_per_step: 1486.6320
# Step 929: train_loss: 4.8594, norm: 1.5077, lr: 0.0001, tokens_per_second: 691.7273, time_per_step: 1480.3521
# Step 930: train_loss: 4.7092, norm: 1.3052, lr: 0.0001, tokens_per_second: 679.4318, time_per_step: 1507.1417
# Step 931: train_loss: 4.4997, norm: 1.4422, lr: 0.0001, tokens_per_second: 678.6018, time_per_step: 1508.9850
# Step 932: train_loss: 4.9877, norm: 1.5560, lr: 0.0001, tokens_per_second: 702.1882, time_per_step: 1458.2986
# Step 933: train_loss: 4.9840, norm: 1.7192, lr: 0.0001, tokens_per_second: 694.6379, time_per_step: 1474.1494
# Step 934: train_loss: 5.0157, norm: 1.4048, lr: 0.0001, tokens_per_second: 694.5910, time_per_step: 1474.2490
# Step 935: train_loss: 4.9803, norm: 1.5030, lr: 0.0001, tokens_per_second: 676.8361, time_per_step: 1512.9217
# Step 936: train_loss: 4.8957, norm: 1.5792, lr: 0.0001, tokens_per_second: 693.5200, time_per_step: 1476.5256
# Step 937: train_loss: 5.0293, norm: 1.5674, lr: 0.0001, tokens_per_second: 704.9171, time_per_step: 1452.6532
# Step 938: train_loss: 4.5763, norm: 1.5431, lr: 0.0001, tokens_per_second: 695.2423, time_per_step: 1472.8678
# Step 939: train_loss: 4.8634, norm: 1.6703, lr: 0.0001, tokens_per_second: 703.2494, time_per_step: 1456.0980
# Step 940: train_loss: 5.1625, norm: 1.5095, lr: 0.0001, tokens_per_second: 703.5509, time_per_step: 1455.4740
# Step 941: train_loss: 4.9140, norm: 1.9118, lr: 0.0001, tokens_per_second: 691.9929, time_per_step: 1479.7840
# Step 942: train_loss: 4.7769, norm: 1.4914, lr: 0.0001, tokens_per_second: 687.1154, time_per_step: 1490.2883
# Step 943: train_loss: 4.7658, norm: 2.0246, lr: 0.0001, tokens_per_second: 682.0049, time_per_step: 1501.4556
# Step 944: train_loss: 5.0000, norm: 1.5348, lr: 0.0001, tokens_per_second: 680.4577, time_per_step: 1504.8695
# Step 945: train_loss: 4.7494, norm: 1.4610, lr: 0.0000, tokens_per_second: 683.8268, time_per_step: 1497.4553
# Step 946: train_loss: 4.5920, norm: 1.8730, lr: 0.0000, tokens_per_second: 697.5017, time_per_step: 1468.0968
# Step 947: train_loss: 4.4751, norm: 1.4718, lr: 0.0000, tokens_per_second: 700.4757, time_per_step: 1461.8637
# Step 948: train_loss: 4.7809, norm: 1.4352, lr: 0.0000, tokens_per_second: 677.9687, time_per_step: 1510.3942
# Step 949: train_loss: 4.9286, norm: 1.3485, lr: 0.0000, tokens_per_second: 700.3759, time_per_step: 1462.0720
# Step 950: train_loss: 4.8898, norm: 1.5602, lr: 0.0000, tokens_per_second: 695.2390, time_per_step: 1472.8747
# Step 951: train_loss: 4.7448, norm: 1.3477, lr: 0.0000, tokens_per_second: 694.1263, time_per_step: 1475.2358
# Step 952: train_loss: 4.7644, norm: 1.4466, lr: 0.0000, tokens_per_second: 702.1107, time_per_step: 1458.4595
# Step 953: train_loss: 4.7917, norm: 1.3478, lr: 0.0000, tokens_per_second: 703.4386, time_per_step: 1455.7064
# Step 954: train_loss: 4.4305, norm: 1.4526, lr: 0.0000, tokens_per_second: 690.2694, time_per_step: 1483.4787
# Step 955: train_loss: 4.8791, norm: 1.4976, lr: 0.0000, tokens_per_second: 693.5525, time_per_step: 1476.4565
# Step 956: train_loss: 4.4713, norm: 1.6825, lr: 0.0000, tokens_per_second: 698.8361, time_per_step: 1465.2936
# Step 957: train_loss: 4.7273, norm: 1.3671, lr: 0.0000, tokens_per_second: 672.9482, time_per_step: 1521.6624
# Step 958: train_loss: 4.6411, norm: 1.4215, lr: 0.0000, tokens_per_second: 687.2349, time_per_step: 1490.0290
# Step 959: train_loss: 4.0839, norm: 1.3910, lr: 0.0000, tokens_per_second: 671.8505, time_per_step: 1524.1485
# Step 960: train_loss: 4.8434, norm: 1.2776, lr: 0.0000, tokens_per_second: 679.5717, time_per_step: 1506.8315
# Step 961: train_loss: 4.5307, norm: 1.3345, lr: 0.0000, tokens_per_second: 700.5220, time_per_step: 1461.7670
# Step 962: train_loss: 3.5582, norm: 1.9251, lr: 0.0000, tokens_per_second: 690.6730, time_per_step: 1482.6119
# Step 963: train_loss: 3.9537, norm: 1.4826, lr: 0.0000, tokens_per_second: 704.8250, time_per_step: 1452.8430
# Step 964: train_loss: 4.4388, norm: 1.5675, lr: 0.0000, tokens_per_second: 703.8905, time_per_step: 1454.7717
# Step 965: train_loss: 4.7512, norm: 1.3154, lr: 0.0000, tokens_per_second: 685.6897, time_per_step: 1493.3869
# Step 966: train_loss: 4.7384, norm: 1.3250, lr: 0.0000, tokens_per_second: 688.3986, time_per_step: 1487.5104
# Step 967: train_loss: 4.8687, norm: 2.0752, lr: 0.0000, tokens_per_second: 700.5236, time_per_step: 1461.7637
# Step 968: train_loss: 4.9187, norm: 2.2049, lr: 0.0000, tokens_per_second: 696.9070, time_per_step: 1469.3496
# Step 969: train_loss: 4.9243, norm: 1.8318, lr: 0.0000, tokens_per_second: 703.8706, time_per_step: 1454.8129
# Step 970: train_loss: 4.9238, norm: 1.6586, lr: 0.0000, tokens_per_second: 697.7928, time_per_step: 1467.4843
# Step 971: train_loss: 5.0599, norm: 1.9554, lr: 0.0000, tokens_per_second: 688.2572, time_per_step: 1487.8160
# Step 972: train_loss: 4.8500, norm: 1.7310, lr: 0.0000, tokens_per_second: 688.5573, time_per_step: 1487.1675
# Step 973: train_loss: 5.0044, norm: 1.6853, lr: 0.0000, tokens_per_second: 684.1963, time_per_step: 1496.6464
# Step 974: train_loss: 5.4950, norm: 1.9053, lr: 0.0000, tokens_per_second: 665.8698, time_per_step: 1537.8382
# Step 975: train_loss: 4.7959, norm: 1.6825, lr: 0.0000, tokens_per_second: 687.2195, time_per_step: 1490.0625
# Step 976: train_loss: 4.7693, norm: 1.8256, lr: 0.0000, tokens_per_second: 664.8742, time_per_step: 1540.1410
# Step 977: train_loss: 5.0671, norm: 1.6868, lr: 0.0000, tokens_per_second: 692.5544, time_per_step: 1478.5842
# Step 978: train_loss: 4.6475, norm: 1.6070, lr: 0.0000, tokens_per_second: 696.5554, time_per_step: 1470.0912
# Step 979: train_loss: 4.4582, norm: 1.8541, lr: 0.0000, tokens_per_second: 703.8130, time_per_step: 1454.9320
# Step 980: train_loss: 5.2118, norm: 1.5813, lr: 0.0000, tokens_per_second: 693.6497, time_per_step: 1476.2494
# Step 981: train_loss: 5.1216, norm: 2.1508, lr: 0.0000, tokens_per_second: 705.1024, time_per_step: 1452.2713
# Step 982: train_loss: 4.6633, norm: 2.4823, lr: 0.0000, tokens_per_second: 699.9084, time_per_step: 1463.0486
# Step 983: train_loss: 4.7782, norm: 2.0094, lr: 0.0000, tokens_per_second: 698.5182, time_per_step: 1465.9604
# Step 984: train_loss: 4.7792, norm: 1.7816, lr: 0.0000, tokens_per_second: 697.0197, time_per_step: 1469.1119
# Step 985: train_loss: 5.0190, norm: 1.5694, lr: 0.0000, tokens_per_second: 683.9318, time_per_step: 1497.2253
# Step 986: train_loss: 4.9166, norm: 2.1007, lr: 0.0000, tokens_per_second: 697.1262, time_per_step: 1468.8875
# Step 987: train_loss: 4.8974, norm: 1.9671, lr: 0.0000, tokens_per_second: 700.8346, time_per_step: 1461.1151
# Step 988: train_loss: 5.1162, norm: 1.5954, lr: 0.0000, tokens_per_second: 694.3441, time_per_step: 1474.7732
# Step 989: train_loss: 5.0545, norm: 1.9466, lr: 0.0000, tokens_per_second: 687.9368, time_per_step: 1488.5088
# Step 990: train_loss: 4.8189, norm: 1.7302, lr: 0.0000, tokens_per_second: 670.9440, time_per_step: 1526.2080
# Step 991: train_loss: 4.7975, norm: 1.7947, lr: 0.0000, tokens_per_second: 699.0547, time_per_step: 1464.8354
# Step 992: train_loss: 4.6413, norm: 1.5414, lr: 0.0000, tokens_per_second: 684.9509, time_per_step: 1494.9977
# Step 993: train_loss: 4.5246, norm: 1.6094, lr: 0.0000, tokens_per_second: 678.3752, time_per_step: 1509.4893
# Step 994: train_loss: 4.3993, norm: 1.6479, lr: 0.0000, tokens_per_second: 673.1266, time_per_step: 1521.2592
# Step 995: train_loss: 4.6823, norm: 1.6151, lr: 0.0000, tokens_per_second: 696.7432, time_per_step: 1469.6949
# Step 996: train_loss: 4.3681, norm: 1.8597, lr: 0.0000, tokens_per_second: 659.9875, time_per_step: 1551.5445
# Step 997: train_loss: 4.9409, norm: 1.4865, lr: 0.0000, tokens_per_second: 674.4060, time_per_step: 1518.3732
# Step 998: train_loss: 4.5496, norm: 1.6582, lr: 0.0000, tokens_per_second: 655.3392, time_per_step: 1562.5496
# Step 999: train_loss: 4.8110, norm: 1.9853, lr: 0.0000, tokens_per_second: 658.9993, time_per_step: 1553.8711
# Step 1000: val_loss: 5.5273, val_time: 10645.2190
# ---------------
# <|endoftext|>DUARET
# I haveABYORK:
# But then then,
# Hath you do a father-cear of these to be gone to
# ---------------
# final 19 iters avg: 1495.459ms 685 tok/s
# peak mem usage: 0 MiB
# saving final model to /Users/jonathon/code/gollem/results/experiments/gpt2/0_gpt2_124M_on_tinyshakespeare/model_s1000.pt
# saving final snapshot to /Users/jonathon/code/gollem/results/snapshots/snapshot.pt
# Finished training 17e73a8f6a5a415f97c9c1ec797814d3

# %%
# parse the log file for the stats and samples
train_stats = {}
val_stats = {}
samples = {}
current_sample: str | None = None
sample_delimiter = "---------------"
step = 0
with open(Path(train_config.output_dir) / "main.log", "r") as f:
    for line in f.readlines():
        if line.strip() == sample_delimiter:
            if current_sample is not None:
                samples[step] = current_sample
                current_sample = None
            else:
                current_sample = ""
        elif current_sample is not None:
            current_sample += line
        elif line.startswith("Step"):
            # ["Step X", "val_loss", "Y, val_time", Z]
            # or
            # ["Step 1", "train_loss", "10.9326, norm", "24.2774, lr", "0.0000, tokens_per_second", "569.5777, time_per_step", 1797.8232]
            parts = line.split(": ")
            step = int(parts[0].split(" ")[1])
            last_key = parts[1].strip()
            step_stats = {}
            for part in parts[2:-1]:
                value, key = part.split(", ")
                step_stats[last_key] = float(value)
                last_key = key
            step_stats[last_key] = float(parts[-1].strip())
            if "val_loss" in step_stats:
                val_stats[step] = step_stats
            else:
                train_stats[step] = step_stats

train_stat_keys = list(train_stats[0].keys())
print(train_stat_keys)
# Out:
# ['train_loss', 'norm', 'lr', 'tokens_per_second', 'time_per_step']

# %%
# plot the train loss
x = list(train_stats.keys())
x = sorted(x)
y = [train_stats[i]["train_loss"] for i in x]

plt.plot(x, y)
plt.title("Train Loss")
plt.xlabel("Step")
plt.ylabel("Loss")
plt.show()

# %%
# plot the val loss
x = list(val_stats.keys())
x = sorted(x)
y = [val_stats[i]["val_loss"] for i in x]

plt.plot(x, y)
plt.title("Val Loss")
# Out:
# Text(0.5, 1.0, 'Val Loss')

# %%
# plot train norm
x = list(train_stats.keys())
x = sorted(x)
y = [train_stats[i]["norm"] for i in x]
plt.plot(x, y)
plt.title("Train Norm")
plt.xlabel("Step")
plt.ylabel("Norm")
plt.show()

# %%
# plot tokens per second
x = list(train_stats.keys())
x = sorted(x)
y = [train_stats[i]["tokens_per_second"] for i in x]
plt.plot(x, y)
plt.title("Tokens Per Second")
plt.xlabel("Step")

# average TPS (excluding first 100 steps)
y = [train_stats[i]["tokens_per_second"] for i in x if i > 100]
mean_y = sum(y) / len(y)
print(f"Average TPS: {mean_y:.2f}")
# Out:
# Average TPS: 663.26

# %%
# compare samples through time
for step in samples:
    print(f">>>Sample at step {step}:")
    print(samples[step])
# Out:
# >>>Sample at step 0:
# <|endoftext|>ria courage163163163 Dougpsons impart harbour Snyderophonflation define HawTagTagMobileworks lust interested unintetermin Kremlin Latinos Ragefire Schemeの�cedovan arenas drains
#
# >>>Sample at step 100:
# <|endoftext|>.<|endoftext|>, him;
# And to,
# And, as of:
#  the,
#  me! me:
# That a with of,?<|endoftext|>H
#
# >>>Sample at step 200:
# <|endoftext|>:
# But,,, is see
# But have<|endoftext|>I shall
# WithThat'll be you are, but you,
# To are thee?<|endoftext|>KING
#
# >>>Sample at step 300:
# <|endoftext|>First;
# But that you to all;
# And I had he is this time-What?
# And she with one;
# What doth I have
#
# >>>Sample at step 400:
# <|endoftext|> ELNORROMVOL, yet.<|endoftext|>R? I will IET:
# If I, my life.<|endoftext|>ROMER:
# No,
# The soul
#
# >>>Sample at step 500:
# <|endoftext|>FLpherd, to the
# That then I might;
# Where I am the king;
# Where
# My lady is the
# The
# To hold the son
#
# >>>Sample at step 600:
# <|endoftext|>U MARESTERESUS:
# WhIRZESeech it.<|endoftext|>OLIOL:
# A good mother!
# No more
# So cannot
#
# >>>Sample at step 700:
# <|endoftext|>BertUTULIIO:
# Where is to; I am but you do tell
# Now,
# ByIt is, good lord, to him of
#
# >>>Sample at step 800:
# <|endoftext|>C doneO:
# I think your son.<|endoftext|>GELO:
# You're you not:
# Is so man:
# Where my lord-
#
# >>>Sample at step 900:
# <|endoftext|>QUE ANHAM, to
# To him in the world
# So shallst!<|endoftext|>ThirdUCKETH:
# That you, his son, that I may
#
# >>>Sample at step 1000:
# <|endoftext|>DUARET
# I haveABYORK:
# But then then,
# Hath you do a father-cear of these to be gone to

# %%
# Let's load the model and sample from it
model, _ = model_cfg.get_model_and_optimizer(device=device)
model = load_model(str(Path(train_config.output_dir) / "model_s1000.pt"), device=device)
model.eval()
# Out:
# num decayed parameter tensors: 50, with 124,318,464 parameters
# num non-decayed parameter tensors: 98, with 121,344 parameters
# Using regular AdamW with fused=False
# num decayed parameter tensors: 50, with 124,318,464 parameters
# num non-decayed parameter tensors: 98, with 121,344 parameters
# Using regular AdamW with fused=False
# GPT(
#   (transformer): ModuleDict(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (h): ModuleList(
#       (0-11): 12 x TransformerBlock(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Linear(in_features=768, out_features=2304, bias=True)
#           (c_proj): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#           (gelu): GELU(approximate='tanh')
#           (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %%
tokenizer = model_cfg.get_tokenizer()


def sample_from_model(prompt: str) -> str:
    tokens = tokenizer.encode(prompt, add_eot=False)
    tokens = torch.tensor(tokens, dtype=torch.long)
    tokens = tokens.unsqueeze(0).repeat(1, 1)
    tokens = tokens.to(device)
    output = model.generate(tokens, max_new_tokens=100, end_token=tokenizer.eot_token)
    return tokenizer.decode(output[0].tolist())

# %%
print(sample_from_model("Romeo and Juliet"))
# Out:
# Romeo and Juliet you being never appointed, though is man trim; what IImp.
# Why,--<|endoftext|>
