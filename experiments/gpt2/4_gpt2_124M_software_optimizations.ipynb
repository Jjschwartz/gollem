# %% [markdown]
# # Training GPT2 124M on Tiny shakespeare dataset on my laptop using CUDA on H100
#
# In this notebook, we train a GPT2 124M model on the Tiny Shakespeare dataset on my laptop without any optimizations except for using CUDA on H100.

# %%
from pathlib import Path

import torch
from matplotlib import pyplot as plt

from gollem.data import load_dataset
from gollem.models.gpt2.config import GPT2Config
from gollem.models.gpt2.config import get_gpt2_model_config
from gollem.train.config import TrainConfig
from gollem.train.core import run
from gollem.utils import get_base_dir_path
from gollem.models.model import load_model
from gollem.train.utils import get_hardware_info

# get available devices
hardware_info = get_hardware_info()
for key, value in hardware_info.items():
    print(f"{key}: {value}")

device = "cuda"
# Out:
# /home/user/gollem/gollem/models/gpt2/model.py:18: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import ZeroRedundancyOptimizer
# os: {'system': 'Linux', 'release': '5.15.0-112-generic', 'version': '#122-Ubuntu SMP Thu May 23 07:48:21 UTC 2024', 'machine': 'x86_64'}
# cpu: {'brand': 'x86_64', 'cores_physical': 104, 'cores_logical': 104}
# memory: {'total_gb': 1007.38}
# gpu: {'name': 'NVIDIA H100 80GB HBM3', 'count': 1, 'capability': (9, 0), 'memory_total_gb': 79.1, 'memory_allocated_gb': 0.0}

# %%
# Create configs
model_cfg = get_gpt2_model_config("gpt2")
# remove optimizations
model_cfg = GPT2Config.override(
    model_cfg,
    **{
        "fused_adamw": False,
        "zero_optimizer": False,
        "flash": False,
        "activation_checkpointing": False,
        "compile": False,
        "from_pretrained": False,
        "use_kv_caching": False,
    },
)

dataset = load_dataset("tinyshakespeare", model_cfg.get_tokenizer())

train_config = TrainConfig(
    output_dir=str(
        get_base_dir_path()
        / "results"
        / "experiments"
        / "gpt2"
        / "3_gpt2_124M_on_tinyshakespeare_with_cuda_on_H100"
    ),
    batch_size=1,
    seq_len=1024,
    total_batch_size=1024,
    num_iterations=1000,
    val_loss_every=100,
    sample_every=100,
    save_every=100,
    snapshot_every=100,
    device=device,
    dtype="float32",
    tensorcores=False,
    use_wandb=True,
)
# Out:
# /home/user/gollem/gollem/data/datasets/tinyshakespeare/tiny_shakespeare.txt already exists, skipping download...
# Tokenized data already exists, skipping tokenization...

# %%
# change to False to avoid rerunning the training
if True:
    run(dataset, model_cfg, train_config)
# Out:
# Launching GPU0|0 in process group 1 using device cuda
# total desired batch size: 1024
# => calculated gradient accumulation steps: 1
# Starting new run 8697e91913f94221a0f5cd30af8a5eca
# /home/user/gollem/gollem/logger.py:35: UserWarning: Log file /home/user/gollem/results/experiments/gpt2/3_gpt2_124M_on_tinyshakespeare_with_cuda_on_H100/main.log already exists, overwriting
#   warn(f"Log file {self.logfile} already exists, overwriting")
# wandb: Currently logged in as: jjschwartz. Use `wandb login --relogin` to force relogin
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Tracking run with wandb version 0.19.2
# Run data is saved locally in <code>/home/user/gollem/experiments/gpt2/wandb/run-20250412_163323-8697e91913f94221a0f5cd30af8a5eca</code>
# Syncing run <strong><a href='https://wandb.ai/jjschwartz/gollem/runs/8697e91913f94221a0f5cd30af8a5eca' target="_blank">gpt2_tinyshakespeare</a></strong> to <a href='https://wandb.ai/jjschwartz/gollem' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/jjschwartz/gollem' target="_blank">https://wandb.ai/jjschwartz/gollem</a>
#  View run at <a href='https://wandb.ai/jjschwartz/gollem/runs/8697e91913f94221a0f5cd30af8a5eca' target="_blank">https://wandb.ai/jjschwartz/gollem/runs/8697e91913f94221a0f5cd30af8a5eca</a>
# Config:
# {'dataset_config': {'name': 'tinyshakespeare',
#                     'train_data': [PosixPath('/home/user/gollem/gollem/data/datasets/tinyshakespeare/gpt2/tiny_shakespeare_val.bin')],
#                     'val_data': [PosixPath('/home/user/gollem/gollem/data/datasets/tinyshakespeare/gpt2/tiny_shakespeare_train.bin')]},
#  'device': 'cuda',
#  'device_type': 'cuda',
#  'model_config': {'activation_checkpointing': False,
#                   'betas': (0.9, 0.95),
#                   'compile': False,
#                   'd_mlp': 3072,
#                   'd_model': 768,
#                   'flash': False,
#                   'from_pretrained': False,
#                   'fused_adamw': False,
#                   'grad_clip': 1.0,
#                   'learning_rate': 0.0006,
#                   'learning_rate_decay_frac': 0.0,
#                   'ln_bias': True,
#                   'max_sample_batch_size': 1,
#                   'mlp_bias': True,
#                   'model_name': 'gpt2',
#                   'n_ctx': 1024,
#                   'n_head': 12,
#                   'n_layer': 12,
#                   'share_embd_params': True,
#                   'use_kv_caching': False,
#                   'vocab_size': 50257,
#                   'warmup_iters': 700,
#                   'weight_decay': 0.1,
#                   'zero_optimizer': False},
#  'pytorch_version': '2.5.1+cu121',
#  'train_config': {'batch_size': 1,
#                   'device': 'cuda',
#                   'dtype': 'float32',
#                   'grad_accum_steps': 1,
#                   'num_iterations': 1000,
#                   'output_dir': '/home/user/gollem/results/experiments/gpt2/3_gpt2_124M_on_tinyshakespeare_with_cuda_on_H100',
#                   'sample_every': 100,
#                   'save_every': 100,
#                   'seed': 42,
#                   'seq_len': 1024,
#                   'snapshot_every': 100,
#                   'tensorcores': False,
#                   'total_batch_size': 1024,
#                   'use_wandb': True,
#                   'val_loss_every': 100,
#                   'val_max_steps': 20}}
# num decayed parameter tensors: 50, with 124,318,464 parameters
# num non-decayed parameter tensors: 98, with 121,344 parameters
# Using regular AdamW with fused=False
# DataLoader: total number of tokens: 298,039 across 1 files
# DataLoader: total number of tokens: 32,768 across 1 files
# Starting training for 1000 iterations
# Step 0: val_loss: 11.0214, val_time: 223.6423
# ---------------
# <|endoftext|> Trophyemployment stationily Officers dilemma manip rustwp ragedtietiels convLDLDlambda Lovereworks tentseworks Loveroin ripping vm Tel Arcane pressure pressure cope mould
# ---------------
# Step 0: train_loss: 11.0052, norm: 25.3916, lr: 0.0000, tokens_per_second: 26418.3152, time_per_step: 38.7610
# Step 1: train_loss: 10.9326, norm: 24.2788, lr: 0.0000, tokens_per_second: 26690.9562, time_per_step: 38.3651
# Step 2: train_loss: 10.8366, norm: 26.1579, lr: 0.0000, tokens_per_second: 26989.5488, time_per_step: 37.9406
# Step 3: train_loss: 10.7297, norm: 22.9848, lr: 0.0000, tokens_per_second: 27045.0613, time_per_step: 37.8627
# Step 4: train_loss: 10.4854, norm: 20.5783, lr: 0.0000, tokens_per_second: 27063.6152, time_per_step: 37.8368
# Step 5: train_loss: 10.2162, norm: 17.6482, lr: 0.0000, tokens_per_second: 27041.5041, time_per_step: 37.8677
# Step 6: train_loss: 10.0158, norm: 15.1050, lr: 0.0000, tokens_per_second: 27078.0050, time_per_step: 37.8167
# Step 7: train_loss: 9.9201, norm: 11.6474, lr: 0.0000, tokens_per_second: 27040.2811, time_per_step: 37.8694
# Step 8: train_loss: 9.7919, norm: 10.1823, lr: 0.0000, tokens_per_second: 27027.6347, time_per_step: 37.8871
# Step 9: train_loss: 9.6718, norm: 9.4298, lr: 0.0000, tokens_per_second: 27059.4195, time_per_step: 37.8426
# Step 10: train_loss: 9.5652, norm: 8.2516, lr: 0.0000, tokens_per_second: 27064.3117, time_per_step: 37.8358
# Step 11: train_loss: 9.4614, norm: 7.1812, lr: 0.0000, tokens_per_second: 27084.5658, time_per_step: 37.8075
# Step 12: train_loss: 9.4482, norm: 6.7158, lr: 0.0000, tokens_per_second: 27053.7844, time_per_step: 37.8505
# Step 13: train_loss: 9.4690, norm: 7.0312, lr: 0.0000, tokens_per_second: 27047.3653, time_per_step: 37.8595
# Step 14: train_loss: 9.4448, norm: 6.1399, lr: 0.0000, tokens_per_second: 27055.0426, time_per_step: 37.8488
# Step 15: train_loss: 9.3474, norm: 5.9945, lr: 0.0000, tokens_per_second: 27069.4659, time_per_step: 37.8286
# Step 16: train_loss: 9.4279, norm: 8.5404, lr: 0.0000, tokens_per_second: 27035.1446, time_per_step: 37.8766
# Step 17: train_loss: 9.3319, norm: 5.8671, lr: 0.0000, tokens_per_second: 27054.6778, time_per_step: 37.8493
# Step 18: train_loss: 9.1948, norm: 5.6303, lr: 0.0000, tokens_per_second: 27036.2844, time_per_step: 37.8750
# Step 19: train_loss: 9.2319, norm: 5.3787, lr: 0.0000, tokens_per_second: 27048.7230, time_per_step: 37.8576
# Step 20: train_loss: 9.1983, norm: 4.8029, lr: 0.0000, tokens_per_second: 27070.4550, time_per_step: 37.8272
# Step 21: train_loss: 9.2826, norm: 4.9291, lr: 0.0000, tokens_per_second: 27078.5469, time_per_step: 37.8159
# Step 22: train_loss: 9.0855, norm: 4.6767, lr: 0.0000, tokens_per_second: 27070.1501, time_per_step: 37.8276
# Step 23: train_loss: 9.0622, norm: 5.5629, lr: 0.0000, tokens_per_second: 27049.8998, time_per_step: 37.8560
# Step 24: train_loss: 9.0586, norm: 5.4568, lr: 0.0000, tokens_per_second: 27063.8963, time_per_step: 37.8364
# Step 25: train_loss: 9.0314, norm: 5.6657, lr: 0.0000, tokens_per_second: 27056.1527, time_per_step: 37.8472
# Step 26: train_loss: 8.7336, norm: 5.1649, lr: 0.0000, tokens_per_second: 27094.1747, time_per_step: 37.7941
# Step 27: train_loss: 8.8379, norm: 5.0831, lr: 0.0000, tokens_per_second: 27072.9715, time_per_step: 37.8237
# Step 28: train_loss: 8.8847, norm: 4.5540, lr: 0.0000, tokens_per_second: 27050.9134, time_per_step: 37.8545
# Step 29: train_loss: 8.9516, norm: 4.2982, lr: 0.0000, tokens_per_second: 27055.4670, time_per_step: 37.8482
# Step 30: train_loss: 8.6308, norm: 5.0223, lr: 0.0000, tokens_per_second: 27047.6747, time_per_step: 37.8591
# Step 31: train_loss: 8.7101, norm: 4.3139, lr: 0.0000, tokens_per_second: 27073.1838, time_per_step: 37.8234
# Step 32: train_loss: 8.6331, norm: 6.0285, lr: 0.0000, tokens_per_second: 27064.9126, time_per_step: 37.8350
# Step 33: train_loss: 8.5274, norm: 5.9896, lr: 0.0000, tokens_per_second: 27063.6159, time_per_step: 37.8368
# Step 34: train_loss: 8.3200, norm: 4.7374, lr: 0.0000, tokens_per_second: 27042.7898, time_per_step: 37.8659
# Step 35: train_loss: 8.5380, norm: 6.0630, lr: 0.0000, tokens_per_second: 27066.0079, time_per_step: 37.8334
# Step 36: train_loss: 8.4479, norm: 5.7870, lr: 0.0000, tokens_per_second: 27078.5705, time_per_step: 37.8159
# Step 37: train_loss: 8.2568, norm: 4.6073, lr: 0.0000, tokens_per_second: 27077.1448, time_per_step: 37.8179
# Step 38: train_loss: 8.3984, norm: 5.3886, lr: 0.0000, tokens_per_second: 27075.1762, time_per_step: 37.8206
# Step 39: train_loss: 8.4004, norm: 4.2421, lr: 0.0000, tokens_per_second: 27065.6418, time_per_step: 37.8339
# Step 40: train_loss: 8.3051, norm: 7.2299, lr: 0.0000, tokens_per_second: 27039.2720, time_per_step: 37.8708
# Step 41: train_loss: 8.2447, norm: 6.6801, lr: 0.0000, tokens_per_second: 27058.7888, time_per_step: 37.8435
# Step 42: train_loss: 8.1275, norm: 4.8391, lr: 0.0000, tokens_per_second: 26887.3071, time_per_step: 38.0849
# Step 43: train_loss: 8.2058, norm: 3.7431, lr: 0.0000, tokens_per_second: 26971.2743, time_per_step: 37.9663
# Step 44: train_loss: 8.3638, norm: 3.7608, lr: 0.0000, tokens_per_second: 26975.2425, time_per_step: 37.9607
# Step 45: train_loss: 8.1041, norm: 3.9726, lr: 0.0000, tokens_per_second: 26996.0124, time_per_step: 37.9315
# Step 46: train_loss: 8.2701, norm: 3.6168, lr: 0.0000, tokens_per_second: 26984.4041, time_per_step: 37.9478
# Step 47: train_loss: 8.4328, norm: 4.0770, lr: 0.0000, tokens_per_second: 26975.4854, time_per_step: 37.9604
# Step 48: train_loss: 8.2665, norm: 3.7681, lr: 0.0000, tokens_per_second: 27016.9727, time_per_step: 37.9021
# Step 49: train_loss: 7.9509, norm: 3.8385, lr: 0.0000, tokens_per_second: 27025.3266, time_per_step: 37.8904
# Step 50: train_loss: 7.9158, norm: 4.5636, lr: 0.0000, tokens_per_second: 27019.8441, time_per_step: 37.8981
# Step 51: train_loss: 7.9171, norm: 11.6043, lr: 0.0000, tokens_per_second: 27029.2493, time_per_step: 37.8849
# Step 52: train_loss: 7.7271, norm: 10.8596, lr: 0.0000, tokens_per_second: 27096.8175, time_per_step: 37.7904
# Step 53: train_loss: 7.7032, norm: 4.1420, lr: 0.0000, tokens_per_second: 27064.5932, time_per_step: 37.8354
# Step 54: train_loss: 8.1086, norm: 3.3357, lr: 0.0000, tokens_per_second: 27048.1228, time_per_step: 37.8584
# Step 55: train_loss: 7.9621, norm: 3.2128, lr: 0.0000, tokens_per_second: 27035.3707, time_per_step: 37.8763
# Step 56: train_loss: 7.9035, norm: 3.6390, lr: 0.0000, tokens_per_second: 26989.4044, time_per_step: 37.9408
# Step 57: train_loss: 7.8890, norm: 3.0813, lr: 0.0000, tokens_per_second: 27075.9516, time_per_step: 37.8195
# Step 58: train_loss: 7.6429, norm: 3.6238, lr: 0.0001, tokens_per_second: 27063.7804, time_per_step: 37.8365
# Step 59: train_loss: 7.9714, norm: 3.5635, lr: 0.0001, tokens_per_second: 26879.7151, time_per_step: 38.0956
# Step 60: train_loss: 7.9698, norm: 3.2019, lr: 0.0001, tokens_per_second: 27002.2521, time_per_step: 37.9228
# Step 61: train_loss: 8.0236, norm: 3.2435, lr: 0.0001, tokens_per_second: 27027.5092, time_per_step: 37.8873
# Step 62: train_loss: 7.9292, norm: 3.4452, lr: 0.0001, tokens_per_second: 27049.1825, time_per_step: 37.8570
# Step 63: train_loss: 7.7538, norm: 2.9257, lr: 0.0001, tokens_per_second: 27050.9473, time_per_step: 37.8545
# Step 64: train_loss: 7.8351, norm: 3.1155, lr: 0.0001, tokens_per_second: 27066.3200, time_per_step: 37.8330
# Step 65: train_loss: 7.6974, norm: 3.5277, lr: 0.0001, tokens_per_second: 27047.9704, time_per_step: 37.8587
# Step 66: train_loss: 7.7590, norm: 2.7310, lr: 0.0001, tokens_per_second: 27062.5517, time_per_step: 37.8383
# Step 67: train_loss: 7.7474, norm: 3.0801, lr: 0.0001, tokens_per_second: 27069.2284, time_per_step: 37.8289
# Step 68: train_loss: 7.5480, norm: 2.9461, lr: 0.0001, tokens_per_second: 27032.5643, time_per_step: 37.8802
# Step 69: train_loss: 7.5143, norm: 4.0001, lr: 0.0001, tokens_per_second: 27063.1702, time_per_step: 37.8374
# Step 70: train_loss: 7.5710, norm: 3.3200, lr: 0.0001, tokens_per_second: 27044.7417, time_per_step: 37.8632
# Step 71: train_loss: 7.5582, norm: 3.0705, lr: 0.0001, tokens_per_second: 27059.6652, time_per_step: 37.8423
# Step 72: train_loss: 7.2568, norm: 2.6934, lr: 0.0001, tokens_per_second: 27062.2806, time_per_step: 37.8386
# Step 73: train_loss: 7.3493, norm: 3.5047, lr: 0.0001, tokens_per_second: 27090.5321, time_per_step: 37.7992
# Step 74: train_loss: 7.2797, norm: 3.2678, lr: 0.0001, tokens_per_second: 27045.6029, time_per_step: 37.8620
# Step 75: train_loss: 7.3010, norm: 2.3739, lr: 0.0001, tokens_per_second: 27054.9667, time_per_step: 37.8489
# Step 76: train_loss: 7.3392, norm: 3.0262, lr: 0.0001, tokens_per_second: 27057.6811, time_per_step: 37.8451
# Step 77: train_loss: 7.3269, norm: 2.9174, lr: 0.0001, tokens_per_second: 27056.9058, time_per_step: 37.8462
# Step 78: train_loss: 7.1889, norm: 2.6221, lr: 0.0001, tokens_per_second: 27101.4343, time_per_step: 37.7840
# Step 79: train_loss: 7.1031, norm: 2.3766, lr: 0.0001, tokens_per_second: 27054.2720, time_per_step: 37.8498
# Step 80: train_loss: 7.1226, norm: 2.3281, lr: 0.0001, tokens_per_second: 27027.8772, time_per_step: 37.8868
# Step 81: train_loss: 6.5658, norm: 3.8646, lr: 0.0001, tokens_per_second: 27051.6378, time_per_step: 37.8535
# Step 82: train_loss: 7.0693, norm: 2.0088, lr: 0.0001, tokens_per_second: 27050.4622, time_per_step: 37.8552
# Step 83: train_loss: 6.9567, norm: 2.9595, lr: 0.0001, tokens_per_second: 27083.9307, time_per_step: 37.8084
# Step 84: train_loss: 6.8640, norm: 2.4689, lr: 0.0001, tokens_per_second: 27070.7432, time_per_step: 37.8268
# Step 85: train_loss: 6.6074, norm: 3.1198, lr: 0.0001, tokens_per_second: 27094.4988, time_per_step: 37.7936
# Step 86: train_loss: 6.1329, norm: 2.4092, lr: 0.0001, tokens_per_second: 27056.3165, time_per_step: 37.8470
# Step 87: train_loss: 6.7986, norm: 4.9750, lr: 0.0001, tokens_per_second: 27060.6965, time_per_step: 37.8409
# Step 88: train_loss: 6.5451, norm: 2.7333, lr: 0.0001, tokens_per_second: 27057.5236, time_per_step: 37.8453
# Step 89: train_loss: 6.0413, norm: 4.6028, lr: 0.0001, tokens_per_second: 27084.4621, time_per_step: 37.8077
# Step 90: train_loss: 6.0184, norm: 5.6258, lr: 0.0001, tokens_per_second: 27072.5676, time_per_step: 37.8243
# Step 91: train_loss: 6.4078, norm: 3.3222, lr: 0.0001, tokens_per_second: 27055.2679, time_per_step: 37.8485
# Step 92: train_loss: 6.4943, norm: 3.2500, lr: 0.0001, tokens_per_second: 27045.1565, time_per_step: 37.8626
# Step 93: train_loss: 6.4798, norm: 2.8677, lr: 0.0001, tokens_per_second: 27066.1911, time_per_step: 37.8332
# Step 94: train_loss: 6.5421, norm: 2.6782, lr: 0.0001, tokens_per_second: 27024.7543, time_per_step: 37.8912
# Step 95: train_loss: 6.7364, norm: 2.9066, lr: 0.0001, tokens_per_second: 27081.4451, time_per_step: 37.8119
# Step 96: train_loss: 6.7897, norm: 2.5205, lr: 0.0001, tokens_per_second: 27039.4512, time_per_step: 37.8706
# Step 97: train_loss: 6.6706, norm: 2.4949, lr: 0.0001, tokens_per_second: 27046.8037, time_per_step: 37.8603
# Step 98: train_loss: 6.7925, norm: 2.1690, lr: 0.0001, tokens_per_second: 27057.8849, time_per_step: 37.8448
# Step 99: train_loss: 6.6794, norm: 2.0317, lr: 0.0001, tokens_per_second: 27080.6264, time_per_step: 37.8130
# Step 100: val_loss: 6.7497, val_time: 224.0121
# ---------------
# <|endoftext|>H not;
#
# And you' him, my I thy:
# '
# That is'd, my that my.
# I.<|endoftext|>.<|endoftext|> not
# ---------------
# Step 100: train_loss: 6.6271, norm: 1.9485, lr: 0.0001, tokens_per_second: 27066.5702, time_per_step: 37.8326
# saving model to /home/user/gollem/results/experiments/gpt2/3_gpt2_124M_on_tinyshakespeare_with_cuda_on_H100/model_s100.pt
# model saved in 1.5642292769625783 seconds
# saving snapshot to /home/user/gollem/results/snapshots/snapshot.pt
# snapshot saved in 1.5140005210414529 seconds
# Step 101: train_loss: 6.9185, norm: 2.4295, lr: 0.0001, tokens_per_second: 26684.4730, time_per_step: 38.3744
# Step 102: train_loss: 6.4556, norm: 2.5308, lr: 0.0001, tokens_per_second: 27039.5513, time_per_step: 37.8705
# Step 103: train_loss: 6.2853, norm: 2.7964, lr: 0.0001, tokens_per_second: 27066.7428, time_per_step: 37.8324
# Step 104: train_loss: 6.5314, norm: 2.4486, lr: 0.0001, tokens_per_second: 27074.2235, time_per_step: 37.8220
# Step 105: train_loss: 6.2841, norm: 2.2741, lr: 0.0001, tokens_per_second: 27096.8121, time_per_step: 37.7904
# Step 106: train_loss: 6.0418, norm: 2.6476, lr: 0.0001, tokens_per_second: 27055.6394, time_per_step: 37.8479
# Step 107: train_loss: 6.7287, norm: 2.3165, lr: 0.0001, tokens_per_second: 27039.8798, time_per_step: 37.8700
# Step 108: train_loss: 6.5930, norm: 2.2006, lr: 0.0001, tokens_per_second: 27041.5929, time_per_step: 37.8676
# Step 109: train_loss: 6.1013, norm: 3.1957, lr: 0.0001, tokens_per_second: 27054.5283, time_per_step: 37.8495
# Step 110: train_loss: 6.1628, norm: 2.1359, lr: 0.0001, tokens_per_second: 27069.5929, time_per_step: 37.8284
# Step 111: train_loss: 6.0723, norm: 2.5912, lr: 0.0001, tokens_per_second: 27051.4375, time_per_step: 37.8538
# Step 112: train_loss: 6.3349, norm: 2.2234, lr: 0.0001, tokens_per_second: 27047.5775, time_per_step: 37.8592
# Step 113: train_loss: 6.1736, norm: 2.3507, lr: 0.0001, tokens_per_second: 27025.6603, time_per_step: 37.8899
# Step 114: train_loss: 6.2749, norm: 2.4485, lr: 0.0001, tokens_per_second: 27081.3778, time_per_step: 37.8120
# Step 115: train_loss: 6.2744, norm: 1.8662, lr: 0.0001, tokens_per_second: 27075.5669, time_per_step: 37.8201
# Step 116: train_loss: 6.3290, norm: 2.0390, lr: 0.0001, tokens_per_second: 27078.6449, time_per_step: 37.8158
# Step 117: train_loss: 6.1508, norm: 2.3111, lr: 0.0001, tokens_per_second: 27044.1500, time_per_step: 37.8640
# Step 118: train_loss: 6.0662, norm: 3.8384, lr: 0.0001, tokens_per_second: 27039.2963, time_per_step: 37.8708
# Step 119: train_loss: 5.9728, norm: 1.7699, lr: 0.0001, tokens_per_second: 27054.5846, time_per_step: 37.8494
# Step 120: train_loss: 5.7112, norm: 2.5889, lr: 0.0001, tokens_per_second: 27091.6058, time_per_step: 37.7977
# Step 121: train_loss: 5.7937, norm: 2.3524, lr: 0.0001, tokens_per_second: 27111.4141, time_per_step: 37.7701
# Step 122: train_loss: 5.7751, norm: 2.2688, lr: 0.0001, tokens_per_second: 27060.2030, time_per_step: 37.8415
# Step 123: train_loss: 5.5128, norm: 2.1661, lr: 0.0001, tokens_per_second: 27040.7257, time_per_step: 37.8688
# Step 124: train_loss: 6.1367, norm: 2.2657, lr: 0.0001, tokens_per_second: 27078.6552, time_per_step: 37.8158
# Step 125: train_loss: 5.6986, norm: 1.9121, lr: 0.0001, tokens_per_second: 27081.5775, time_per_step: 37.8117
# Step 126: train_loss: 5.9153, norm: 2.4638, lr: 0.0001, tokens_per_second: 27082.5818, time_per_step: 37.8103
# Step 127: train_loss: 5.8652, norm: 2.3596, lr: 0.0001, tokens_per_second: 27045.2167, time_per_step: 37.8625
# Step 128: train_loss: 6.2727, norm: 2.6784, lr: 0.0001, tokens_per_second: 27038.4498, time_per_step: 37.8720
# Step 129: train_loss: 6.2546, norm: 1.9700, lr: 0.0001, tokens_per_second: 27069.4603, time_per_step: 37.8286
# Step 130: train_loss: 5.9418, norm: 1.7716, lr: 0.0001, tokens_per_second: 27075.7962, time_per_step: 37.8198
# Step 131: train_loss: 5.9734, norm: 2.0394, lr: 0.0001, tokens_per_second: 27082.9507, time_per_step: 37.8098
# Step 132: train_loss: 5.9480, norm: 2.0318, lr: 0.0001, tokens_per_second: 27057.5103, time_per_step: 37.8453
# Step 133: train_loss: 5.9348, norm: 3.4376, lr: 0.0001, tokens_per_second: 27040.2446, time_per_step: 37.8695
# Step 134: train_loss: 6.2358, norm: 2.2399, lr: 0.0001, tokens_per_second: 27059.2060, time_per_step: 37.8429
# Step 135: train_loss: 6.0622, norm: 2.1975, lr: 0.0001, tokens_per_second: 27068.9751, time_per_step: 37.8293
# Step 136: train_loss: 6.0280, norm: 2.2645, lr: 0.0001, tokens_per_second: 27071.8313, time_per_step: 37.8253
# Step 137: train_loss: 5.9973, norm: 2.5604, lr: 0.0001, tokens_per_second: 27046.2096, time_per_step: 37.8611
# Step 138: train_loss: 5.8945, norm: 2.0140, lr: 0.0001, tokens_per_second: 27082.1298, time_per_step: 37.8109
# Step 139: train_loss: 6.1795, norm: 1.9930, lr: 0.0001, tokens_per_second: 27059.4334, time_per_step: 37.8426
# Step 140: train_loss: 5.9942, norm: 1.6166, lr: 0.0001, tokens_per_second: 27064.2231, time_per_step: 37.8359
# Step 141: train_loss: 6.0303, norm: 1.6169, lr: 0.0001, tokens_per_second: 27088.6423, time_per_step: 37.8018
# Step 142: train_loss: 6.1866, norm: 1.8521, lr: 0.0001, tokens_per_second: 27067.1693, time_per_step: 37.8318
# Step 143: train_loss: 6.1681, norm: 1.8375, lr: 0.0001, tokens_per_second: 27042.6561, time_per_step: 37.8661
# Step 144: train_loss: 6.0374, norm: 1.9061, lr: 0.0001, tokens_per_second: 27062.1681, time_per_step: 37.8388
# Step 145: train_loss: 5.4977, norm: 2.5392, lr: 0.0001, tokens_per_second: 27055.2263, time_per_step: 37.8485
# Step 146: train_loss: 6.0261, norm: 1.9707, lr: 0.0001, tokens_per_second: 27080.3596, time_per_step: 37.8134
# Step 147: train_loss: 5.9137, norm: 2.0528, lr: 0.0001, tokens_per_second: 27068.7842, time_per_step: 37.8296
# Step 148: train_loss: 5.7742, norm: 2.1723, lr: 0.0001, tokens_per_second: 27046.5615, time_per_step: 37.8606
# Step 149: train_loss: 5.9427, norm: 1.6401, lr: 0.0001, tokens_per_second: 27048.8574, time_per_step: 37.8574
# Step 150: train_loss: 5.7367, norm: 2.1801, lr: 0.0001, tokens_per_second: 27089.4448, time_per_step: 37.8007
# Step 151: train_loss: 5.3666, norm: 2.2373, lr: 0.0001, tokens_per_second: 27080.1805, time_per_step: 37.8136
# Step 152: train_loss: 5.7654, norm: 4.7823, lr: 0.0001, tokens_per_second: 27076.5670, time_per_step: 37.8187
# Step 153: train_loss: 5.7352, norm: 2.1119, lr: 0.0001, tokens_per_second: 27052.5983, time_per_step: 37.8522
# Step 154: train_loss: 5.9593, norm: 2.0996, lr: 0.0001, tokens_per_second: 27065.2410, time_per_step: 37.8345
# Step 155: train_loss: 5.9620, norm: 2.0220, lr: 0.0001, tokens_per_second: 27048.7293, time_per_step: 37.8576
# Step 156: train_loss: 5.8042, norm: 1.8680, lr: 0.0001, tokens_per_second: 27101.3695, time_per_step: 37.7841
# Step 157: train_loss: 5.5186, norm: 1.8273, lr: 0.0001, tokens_per_second: 27082.6955, time_per_step: 37.8101
# Step 158: train_loss: 5.7720, norm: 2.2030, lr: 0.0001, tokens_per_second: 27081.6993, time_per_step: 37.8115
# Step 159: train_loss: 5.7534, norm: 1.7338, lr: 0.0001, tokens_per_second: 27078.4945, time_per_step: 37.8160
# Step 160: train_loss: 5.5084, norm: 1.9413, lr: 0.0001, tokens_per_second: 27044.2781, time_per_step: 37.8638
# Step 161: train_loss: 5.6763, norm: 2.0076, lr: 0.0001, tokens_per_second: 27022.8418, time_per_step: 37.8939
# Step 162: train_loss: 5.5456, norm: 1.9283, lr: 0.0001, tokens_per_second: 27041.9976, time_per_step: 37.8670
# Step 163: train_loss: 5.4290, norm: 2.2365, lr: 0.0001, tokens_per_second: 27050.2169, time_per_step: 37.8555
# Step 164: train_loss: 5.7452, norm: 1.8640, lr: 0.0001, tokens_per_second: 27043.6687, time_per_step: 37.8647
# Step 165: train_loss: 5.1469, norm: 2.0103, lr: 0.0001, tokens_per_second: 27052.6781, time_per_step: 37.8521
# Step 166: train_loss: 5.5354, norm: 1.9343, lr: 0.0001, tokens_per_second: 27086.9325, time_per_step: 37.8042
# Step 167: train_loss: 5.9657, norm: 2.0287, lr: 0.0001, tokens_per_second: 27054.7423, time_per_step: 37.8492
# Step 168: train_loss: 5.2337, norm: 2.4614, lr: 0.0001, tokens_per_second: 27094.8480, time_per_step: 37.7932
# Step 169: train_loss: 4.9439, norm: 1.9921, lr: 0.0001, tokens_per_second: 27039.3392, time_per_step: 37.8707
# Step 170: train_loss: 5.5423, norm: 2.0568, lr: 0.0001, tokens_per_second: 27076.2013, time_per_step: 37.8192
# Step 171: train_loss: 6.4662, norm: 1.9179, lr: 0.0001, tokens_per_second: 27073.6441, time_per_step: 37.8228
# Step 172: train_loss: 6.2354, norm: 2.1598, lr: 0.0001, tokens_per_second: 27081.0156, time_per_step: 37.8125
# Step 173: train_loss: 6.3538, norm: 1.8988, lr: 0.0001, tokens_per_second: 27036.5949, time_per_step: 37.8746
# Step 174: train_loss: 6.2644, norm: 2.3195, lr: 0.0001, tokens_per_second: 27065.8557, time_per_step: 37.8336
# Step 175: train_loss: 6.4157, norm: 2.1518, lr: 0.0002, tokens_per_second: 27001.6443, time_per_step: 37.9236
# Step 176: train_loss: 6.1556, norm: 1.9613, lr: 0.0002, tokens_per_second: 27066.8178, time_per_step: 37.8323
# Step 177: train_loss: 6.0069, norm: 2.4257, lr: 0.0002, tokens_per_second: 27085.0489, time_per_step: 37.8068
# Step 178: train_loss: 6.0078, norm: 2.6908, lr: 0.0002, tokens_per_second: 27053.6450, time_per_step: 37.8507
# Step 179: train_loss: 6.0214, norm: 1.9928, lr: 0.0002, tokens_per_second: 27075.3272, time_per_step: 37.8204
# Step 180: train_loss: 5.9478, norm: 1.8644, lr: 0.0002, tokens_per_second: 27081.3778, time_per_step: 37.8120
# Step 181: train_loss: 6.0463, norm: 1.7536, lr: 0.0002, tokens_per_second: 27075.6952, time_per_step: 37.8199
# Step 182: train_loss: 5.7455, norm: 1.9769, lr: 0.0002, tokens_per_second: 27051.3609, time_per_step: 37.8539
# Step 183: train_loss: 5.6517, norm: 1.8323, lr: 0.0002, tokens_per_second: 27062.5281, time_per_step: 37.8383
# Step 184: train_loss: 6.0840, norm: 2.1944, lr: 0.0002, tokens_per_second: 27029.3264, time_per_step: 37.8848
# Step 185: train_loss: 5.8390, norm: 2.1663, lr: 0.0002, tokens_per_second: 27027.9600, time_per_step: 37.8867
# Step 186: train_loss: 6.0126, norm: 2.5232, lr: 0.0002, tokens_per_second: 27082.1779, time_per_step: 37.8108
# Step 187: train_loss: 5.7957, norm: 1.7099, lr: 0.0002, tokens_per_second: 27061.8141, time_per_step: 37.8393
# Step 188: train_loss: 6.5213, norm: 2.0818, lr: 0.0002, tokens_per_second: 27052.9237, time_per_step: 37.8517
# Step 189: train_loss: 6.1942, norm: 1.7823, lr: 0.0002, tokens_per_second: 27076.2436, time_per_step: 37.8191
# Step 190: train_loss: 6.5841, norm: 2.0304, lr: 0.0002, tokens_per_second: 27076.6804, time_per_step: 37.8185
# Step 191: train_loss: 6.2288, norm: 2.5373, lr: 0.0002, tokens_per_second: 27089.1732, time_per_step: 37.8011
# Step 192: train_loss: 6.2339, norm: 2.0192, lr: 0.0002, tokens_per_second: 27078.8800, time_per_step: 37.8154
# Step 193: train_loss: 6.2351, norm: 2.6298, lr: 0.0002, tokens_per_second: 27075.0258, time_per_step: 37.8208
# Step 194: train_loss: 6.3248, norm: 1.7671, lr: 0.0002, tokens_per_second: 27064.7031, time_per_step: 37.8353
# Step 195: train_loss: 6.2064, norm: 2.3045, lr: 0.0002, tokens_per_second: 27071.5707, time_per_step: 37.8257
# Step 196: train_loss: 5.9270, norm: 1.6690, lr: 0.0002, tokens_per_second: 27095.9280, time_per_step: 37.7917
# Step 197: train_loss: 5.6098, norm: 1.7737, lr: 0.0002, tokens_per_second: 27051.9403, time_per_step: 37.8531
# Step 198: train_loss: 5.7012, norm: 2.0397, lr: 0.0002, tokens_per_second: 27037.9784, time_per_step: 37.8727
# Step 199: train_loss: 5.8418, norm: 1.7972, lr: 0.0002, tokens_per_second: 27063.7281, time_per_step: 37.8366
# Step 200: val_loss: 6.1469, val_time: 223.5851
# ---------------
# <|endoftext|>: come:
# ' the must I did yours:
# Of in his's''er I was some?<|endoftext|>FirstEN.<|endoftext|>L:
#
# ---------------
# Step 200: train_loss: 5.9232, norm: 3.5013, lr: 0.0002, tokens_per_second: 26981.3835, time_per_step: 37.9521
# saving model to /home/user/gollem/results/experiments/gpt2/3_gpt2_124M_on_tinyshakespeare_with_cuda_on_H100/model_s200.pt
# model saved in 1.6052443790249527 seconds
# saving snapshot to /home/user/gollem/results/snapshots/snapshot.pt
# snapshot saved in 4.493375218007714 seconds
# Step 201: train_loss: 5.7579, norm: 3.1255, lr: 0.0002, tokens_per_second: 26655.7052, time_per_step: 38.4158
# Step 202: train_loss: 5.8553, norm: 2.0629, lr: 0.0002, tokens_per_second: 26879.1674, time_per_step: 38.0964
# Step 203: train_loss: 5.5976, norm: 2.2530, lr: 0.0002, tokens_per_second: 26914.0573, time_per_step: 38.0470
# Step 204: train_loss: 5.5948, norm: 1.7578, lr: 0.0002, tokens_per_second: 26965.0390, time_per_step: 37.9751
# Step 205: train_loss: 5.5550, norm: 1.7799, lr: 0.0002, tokens_per_second: 26962.6427, time_per_step: 37.9785
# Step 206: train_loss: 6.3201, norm: 1.9954, lr: 0.0002, tokens_per_second: 26947.5387, time_per_step: 37.9998
# Step 207: train_loss: 6.0222, norm: 1.9868, lr: 0.0002, tokens_per_second: 26981.6904, time_per_step: 37.9517
# Step 208: train_loss: 5.3788, norm: 2.1588, lr: 0.0002, tokens_per_second: 27010.4429, time_per_step: 37.9113
# Step 209: train_loss: 5.3848, norm: 1.7854, lr: 0.0002, tokens_per_second: 27036.7039, time_per_step: 37.8744
# Step 210: train_loss: 6.0585, norm: 1.8807, lr: 0.0002, tokens_per_second: 27010.4213, time_per_step: 37.9113
# Step 211: train_loss: 5.9284, norm: 2.5225, lr: 0.0002, tokens_per_second: 27036.7205, time_per_step: 37.8744
# Step 212: train_loss: 6.3494, norm: 2.8279, lr: 0.0002, tokens_per_second: 27065.1961, time_per_step: 37.8346
# Step 213: train_loss: 6.1576, norm: 2.6256, lr: 0.0002, tokens_per_second: 27055.2007, time_per_step: 37.8485
# Step 214: train_loss: 6.1085, norm: 2.3504, lr: 0.0002, tokens_per_second: 27076.3043, time_per_step: 37.8190
# Step 215: train_loss: 5.8750, norm: 1.8728, lr: 0.0002, tokens_per_second: 27077.0741, time_per_step: 37.8180
# Step 216: train_loss: 5.9272, norm: 2.9280, lr: 0.0002, tokens_per_second: 27095.9865, time_per_step: 37.7916
# Step 217: train_loss: 5.7208, norm: 2.7562, lr: 0.0002, tokens_per_second: 27070.1794, time_per_step: 37.8276
# Step 218: train_loss: 5.9739, norm: 2.5110, lr: 0.0002, tokens_per_second: 27072.0186, time_per_step: 37.8250
# Step 219: train_loss: 5.3386, norm: 2.4529, lr: 0.0002, tokens_per_second: 27061.7435, time_per_step: 37.8394
# Step 220: train_loss: 5.6160, norm: 3.2592, lr: 0.0002, tokens_per_second: 27058.4892, time_per_step: 37.8439
# Step 221: train_loss: 5.6733, norm: 2.0773, lr: 0.0002, tokens_per_second: 27036.2316, time_per_step: 37.8751
# Step 222: train_loss: 5.6028, norm: 1.7408, lr: 0.0002, tokens_per_second: 27092.0627, time_per_step: 37.7970
# Step 223: train_loss: 5.3270, norm: 2.3611, lr: 0.0002, tokens_per_second: 27085.9136, time_per_step: 37.8056
# Step 224: train_loss: 5.6698, norm: 1.7980, lr: 0.0002, tokens_per_second: 27057.8376, time_per_step: 37.8449
# Step 225: train_loss: 5.6584, norm: 2.0492, lr: 0.0002, tokens_per_second: 27066.9524, time_per_step: 37.8321
# Step 226: train_loss: 5.6859, norm: 2.0239, lr: 0.0002, tokens_per_second: 27056.6787, time_per_step: 37.8465
# Step 227: train_loss: 6.1730, norm: 2.3713, lr: 0.0002, tokens_per_second: 27062.6147, time_per_step: 37.8382
# Step 228: train_loss: 5.8575, norm: 1.7681, lr: 0.0002, tokens_per_second: 27025.2196, time_per_step: 37.8905
# Step 229: train_loss: 5.5677, norm: 2.2011, lr: 0.0002, tokens_per_second: 27079.9641, time_per_step: 37.8139
# Step 230: train_loss: 5.6212, norm: 1.7884, lr: 0.0002, tokens_per_second: 27033.5935, time_per_step: 37.8788
# Step 231: train_loss: 5.8124, norm: 2.1777, lr: 0.0002, tokens_per_second: 27034.0033, time_per_step: 37.8782
# Step 232: train_loss: 5.2752, norm: 1.8405, lr: 0.0002, tokens_per_second: 27063.7728, time_per_step: 37.8366
# Step 233: train_loss: 5.4905, norm: 2.3691, lr: 0.0002, tokens_per_second: 27076.8227, time_per_step: 37.8183
# Step 234: train_loss: 5.3912, norm: 2.0263, lr: 0.0002, tokens_per_second: 27069.6176, time_per_step: 37.8284
# Step 235: train_loss: 5.8377, norm: 1.7424, lr: 0.0002, tokens_per_second: 27071.6414, time_per_step: 37.8256
# Step 236: train_loss: 4.9526, norm: 1.9361, lr: 0.0002, tokens_per_second: 27006.2298, time_per_step: 37.9172
# Step 237: train_loss: 5.2532, norm: 1.7934, lr: 0.0002, tokens_per_second: 27072.3093, time_per_step: 37.8246
# Step 238: train_loss: 5.5256, norm: 1.6164, lr: 0.0002, tokens_per_second: 27080.2805, time_per_step: 37.8135
# Step 239: train_loss: 4.7654, norm: 2.3975, lr: 0.0002, tokens_per_second: 27097.3674, time_per_step: 37.7896
# Step 240: train_loss: 5.4448, norm: 1.6998, lr: 0.0002, tokens_per_second: 27076.0739, time_per_step: 37.8194
# Step 241: train_loss: 4.9744, norm: 1.9514, lr: 0.0002, tokens_per_second: 27061.0328, time_per_step: 37.8404
# Step 242: train_loss: 5.0331, norm: 2.2828, lr: 0.0002, tokens_per_second: 27061.6625, time_per_step: 37.8395
# Step 243: train_loss: 4.7954, norm: 1.7486, lr: 0.0002, tokens_per_second: 27068.2737, time_per_step: 37.8303
# Step 244: train_loss: 4.9548, norm: 1.9600, lr: 0.0002, tokens_per_second: 27077.3532, time_per_step: 37.8176
# Step 245: train_loss: 5.4183, norm: 1.5468, lr: 0.0002, tokens_per_second: 27079.5049, time_per_step: 37.8146
# Step 246: train_loss: 5.6804, norm: 1.8590, lr: 0.0002, tokens_per_second: 27053.3501, time_per_step: 37.8511
# Step 247: train_loss: 6.4076, norm: 1.7101, lr: 0.0002, tokens_per_second: 27074.9112, time_per_step: 37.8210
# Step 248: train_loss: 5.5714, norm: 2.1309, lr: 0.0002, tokens_per_second: 27071.5214, time_per_step: 37.8257
# Step 249: train_loss: 6.1865, norm: 1.9200, lr: 0.0002, tokens_per_second: 27093.0013, time_per_step: 37.7957
# Step 250: train_loss: 6.0959, norm: 2.0101, lr: 0.0002, tokens_per_second: 27084.5271, time_per_step: 37.8076
# Step 251: train_loss: 5.6103, norm: 1.7015, lr: 0.0002, tokens_per_second: 27023.1034, time_per_step: 37.8935
# Step 252: train_loss: 5.8722, norm: 1.8966, lr: 0.0002, tokens_per_second: 27056.3245, time_per_step: 37.8470
# Step 253: train_loss: 6.0661, norm: 2.6439, lr: 0.0002, tokens_per_second: 27033.2346, time_per_step: 37.8793
# Step 254: train_loss: 5.8729, norm: 2.0314, lr: 0.0002, tokens_per_second: 26807.5067, time_per_step: 38.1983
# Step 255: train_loss: 5.4256, norm: 2.6662, lr: 0.0002, tokens_per_second: 24687.1405, time_per_step: 41.4791
# Step 256: train_loss: 5.7405, norm: 1.5966, lr: 0.0002, tokens_per_second: 26969.5552, time_per_step: 37.9687
# Step 257: train_loss: 5.6180, norm: 2.2489, lr: 0.0002, tokens_per_second: 27021.3635, time_per_step: 37.8959
# Step 258: train_loss: 5.5001, norm: 1.8777, lr: 0.0002, tokens_per_second: 27037.7919, time_per_step: 37.8729
# Step 259: train_loss: 5.1712, norm: 2.6837, lr: 0.0002, tokens_per_second: 27068.8022, time_per_step: 37.8295
# Step 260: train_loss: 5.3916, norm: 1.6189, lr: 0.0002, tokens_per_second: 27027.0939, time_per_step: 37.8879
# Step 261: train_loss: 5.7637, norm: 1.6591, lr: 0.0002, tokens_per_second: 27081.5182, time_per_step: 37.8118
# Step 262: train_loss: 5.8218, norm: 2.0032, lr: 0.0002, tokens_per_second: 27021.2439, time_per_step: 37.8961
# Step 263: train_loss: 5.9715, norm: 1.9256, lr: 0.0002, tokens_per_second: 27007.1522, time_per_step: 37.9159
# Step 264: train_loss: 5.1180, norm: 1.9028, lr: 0.0002, tokens_per_second: 27014.3135, time_per_step: 37.9058
# Step 265: train_loss: 5.0132, norm: 1.8219, lr: 0.0002, tokens_per_second: 26906.1355, time_per_step: 38.0582
# Step 266: train_loss: 5.5796, norm: 1.8481, lr: 0.0002, tokens_per_second: 26994.7641, time_per_step: 37.9333
# Step 267: train_loss: 5.8859, norm: 2.5981, lr: 0.0002, tokens_per_second: 27061.7505, time_per_step: 37.8394
# Step 268: train_loss: 5.3719, norm: 3.3387, lr: 0.0002, tokens_per_second: 27023.6178, time_per_step: 37.8928
# Step 269: train_loss: 5.1823, norm: 1.6750, lr: 0.0002, tokens_per_second: 27081.2110, time_per_step: 37.8122
# Step 270: train_loss: 5.1243, norm: 1.6846, lr: 0.0002, tokens_per_second: 27070.0264, time_per_step: 37.8278
# Step 271: train_loss: 4.8582, norm: 1.7266, lr: 0.0002, tokens_per_second: 27075.5282, time_per_step: 37.8201
# Step 272: train_loss: 5.1010, norm: 2.1602, lr: 0.0002, tokens_per_second: 27043.7273, time_per_step: 37.8646
# Step 273: train_loss: 5.1067, norm: 1.6398, lr: 0.0002, tokens_per_second: 27050.6691, time_per_step: 37.8549
# Step 274: train_loss: 4.9847, norm: 1.6049, lr: 0.0002, tokens_per_second: 27068.5673, time_per_step: 37.8299
# Step 275: train_loss: 4.9497, norm: 1.6619, lr: 0.0002, tokens_per_second: 27066.2934, time_per_step: 37.8330
# Step 276: train_loss: 4.9732, norm: 2.2021, lr: 0.0002, tokens_per_second: 27075.1515, time_per_step: 37.8207
# Step 277: train_loss: 4.6883, norm: 1.6941, lr: 0.0002, tokens_per_second: 27046.9398, time_per_step: 37.8601
# Step 278: train_loss: 4.4108, norm: 1.8290, lr: 0.0002, tokens_per_second: 27024.6145, time_per_step: 37.8914
# Step 279: train_loss: 4.5885, norm: 1.6973, lr: 0.0002, tokens_per_second: 27064.9299, time_per_step: 37.8349
# Step 280: train_loss: 5.6691, norm: 2.0387, lr: 0.0002, tokens_per_second: 27063.5926, time_per_step: 37.8368
# Step 281: train_loss: 6.1608, norm: 1.9279, lr: 0.0002, tokens_per_second: 27080.8822, time_per_step: 37.8127
# Step 282: train_loss: 6.0942, norm: 2.5240, lr: 0.0002, tokens_per_second: 27050.7037, time_per_step: 37.8548
# Step 283: train_loss: 6.1357, norm: 2.0029, lr: 0.0002, tokens_per_second: 27047.6134, time_per_step: 37.8592
# Step 284: train_loss: 5.9262, norm: 2.2483, lr: 0.0002, tokens_per_second: 27043.0282, time_per_step: 37.8656
# Step 285: train_loss: 6.0193, norm: 2.2386, lr: 0.0002, tokens_per_second: 27075.9413, time_per_step: 37.8196
# Step 286: train_loss: 5.9601, norm: 1.8547, lr: 0.0002, tokens_per_second: 27086.4561, time_per_step: 37.8049
# Step 287: train_loss: 5.5448, norm: 1.8758, lr: 0.0002, tokens_per_second: 27065.2374, time_per_step: 37.8345
# Step 288: train_loss: 5.7256, norm: 2.7512, lr: 0.0002, tokens_per_second: 27085.5516, time_per_step: 37.8061
# Step 289: train_loss: 5.7584, norm: 2.0934, lr: 0.0002, tokens_per_second: 27041.2993, time_per_step: 37.8680
# Step 290: train_loss: 5.5935, norm: 2.4152, lr: 0.0002, tokens_per_second: 26642.1289, time_per_step: 38.4354
# Step 291: train_loss: 5.8559, norm: 2.2548, lr: 0.0003, tokens_per_second: 27074.7645, time_per_step: 37.8212
# Step 292: train_loss: 6.0984, norm: 4.8114, lr: 0.0003, tokens_per_second: 27059.3848, time_per_step: 37.8427
# Step 293: train_loss: 6.1116, norm: 5.1130, lr: 0.0003, tokens_per_second: 27068.8455, time_per_step: 37.8295
# Step 294: train_loss: 5.9527, norm: 2.4028, lr: 0.0003, tokens_per_second: 27078.1064, time_per_step: 37.8165
# Step 295: train_loss: 5.6998, norm: 2.1877, lr: 0.0003, tokens_per_second: 27076.3193, time_per_step: 37.8190
# Step 296: train_loss: 5.5149, norm: 1.7817, lr: 0.0003, tokens_per_second: 27043.5154, time_per_step: 37.8649
# Step 297: train_loss: 5.9248, norm: 2.2230, lr: 0.0003, tokens_per_second: 27069.9311, time_per_step: 37.8279
# Step 298: train_loss: 5.8042, norm: 1.9200, lr: 0.0003, tokens_per_second: 27034.7531, time_per_step: 37.8772
# Step 299: train_loss: 5.8587, norm: 1.7760, lr: 0.0003, tokens_per_second: 27056.5489, time_per_step: 37.8467
# Step 300: val_loss: 5.7812, val_time: 223.7156
# ---------------
# <|endoftext|>RD than all. What:
# It,
# IUS:
# And now?<|endoftext|>MI have your hand, but your rest;
# The state
# ---------------
# Step 300: train_loss: 5.5810, norm: 1.7606, lr: 0.0003, tokens_per_second: 26940.4503, time_per_step: 38.0098
# saving model to /home/user/gollem/results/experiments/gpt2/3_gpt2_124M_on_tinyshakespeare_with_cuda_on_H100/model_s300.pt
# model saved in 1.6358845867216587 seconds
# saving snapshot to /home/user/gollem/results/snapshots/snapshot.pt
# snapshot saved in 4.553916760254651 seconds
# Step 301: train_loss: 5.7134, norm: 1.6579, lr: 0.0003, tokens_per_second: 26637.3723, time_per_step: 38.4422
# Step 302: train_loss: 5.5968, norm: 2.2424, lr: 0.0003, tokens_per_second: 26962.9161, time_per_step: 37.9781
# Step 303: train_loss: 5.7522, norm: 2.3614, lr: 0.0003, tokens_per_second: 27030.3121, time_per_step: 37.8834
# Step 304: train_loss: 6.0077, norm: 1.8398, lr: 0.0003, tokens_per_second: 27053.7501, time_per_step: 37.8506
# Step 305: train_loss: 5.6765, norm: 2.7025, lr: 0.0003, tokens_per_second: 27070.4956, time_per_step: 37.8272
# Step 306: train_loss: 5.9876, norm: 1.9804, lr: 0.0003, tokens_per_second: 27084.7200, time_per_step: 37.8073
# Step 307: train_loss: 5.4932, norm: 2.9427, lr: 0.0003, tokens_per_second: 27074.1028, time_per_step: 37.8221
# Step 308: train_loss: 5.5205, norm: 2.4998, lr: 0.0003, tokens_per_second: 27062.7656, time_per_step: 37.8380
# Step 309: train_loss: 5.6247, norm: 2.2155, lr: 0.0003, tokens_per_second: 27043.1589, time_per_step: 37.8654
# Step 310: train_loss: 5.7446, norm: 1.8357, lr: 0.0003, tokens_per_second: 27074.9205, time_per_step: 37.8210
# Step 311: train_loss: 5.1903, norm: 2.3083, lr: 0.0003, tokens_per_second: 27080.8521, time_per_step: 37.8127
# Step 312: train_loss: 5.5262, norm: 2.2953, lr: 0.0003, tokens_per_second: 27107.8083, time_per_step: 37.7751
# Step 313: train_loss: 5.1244, norm: 1.5092, lr: 0.0003, tokens_per_second: 27061.6625, time_per_step: 37.8395
# Step 314: train_loss: 5.6472, norm: 1.7701, lr: 0.0003, tokens_per_second: 27069.7665, time_per_step: 37.8282
# Step 315: train_loss: 5.6880, norm: 2.1427, lr: 0.0003, tokens_per_second: 27093.4346, time_per_step: 37.7951
# Step 316: train_loss: 5.4338, norm: 2.4321, lr: 0.0003, tokens_per_second: 27081.3040, time_per_step: 37.8121
# Step 317: train_loss: 5.0449, norm: 2.2336, lr: 0.0003, tokens_per_second: 27078.7746, time_per_step: 37.8156
# Step 318: train_loss: 5.3246, norm: 1.8344, lr: 0.0003, tokens_per_second: 27054.5363, time_per_step: 37.8495
# Step 319: train_loss: 5.3007, norm: 1.8807, lr: 0.0003, tokens_per_second: 27012.4021, time_per_step: 37.9085
# Step 320: train_loss: 5.4965, norm: 1.9169, lr: 0.0003, tokens_per_second: 27073.4772, time_per_step: 37.8230
# Step 321: train_loss: 5.2075, norm: 2.8968, lr: 0.0003, tokens_per_second: 27086.6990, time_per_step: 37.8045
# Step 322: train_loss: 5.3020, norm: 2.0051, lr: 0.0003, tokens_per_second: 27098.5211, time_per_step: 37.7880
# Step 323: train_loss: 5.1604, norm: 1.7165, lr: 0.0003, tokens_per_second: 27051.7513, time_per_step: 37.8534
# Step 324: train_loss: 4.9754, norm: 1.9105, lr: 0.0003, tokens_per_second: 27074.8182, time_per_step: 37.8211
# Step 325: train_loss: 4.8434, norm: 1.6835, lr: 0.0003, tokens_per_second: 27038.7800, time_per_step: 37.8715
# Step 326: train_loss: 5.0576, norm: 1.7671, lr: 0.0003, tokens_per_second: 27072.2033, time_per_step: 37.8248
# Step 327: train_loss: 5.1587, norm: 1.5924, lr: 0.0003, tokens_per_second: 27076.7497, time_per_step: 37.8184
# Step 328: train_loss: 4.8085, norm: 1.6246, lr: 0.0003, tokens_per_second: 27079.9274, time_per_step: 37.8140
# Step 329: train_loss: 5.2076, norm: 1.4135, lr: 0.0003, tokens_per_second: 27051.7919, time_per_step: 37.8533
# Step 330: train_loss: 5.3626, norm: 1.4672, lr: 0.0003, tokens_per_second: 27055.5442, time_per_step: 37.8481
# Step 331: train_loss: 5.2008, norm: 1.4884, lr: 0.0003, tokens_per_second: 27070.3123, time_per_step: 37.8274
# Step 332: train_loss: 5.3656, norm: 1.4555, lr: 0.0003, tokens_per_second: 27093.2533, time_per_step: 37.7954
# Step 333: train_loss: 5.2281, norm: 2.0782, lr: 0.0003, tokens_per_second: 27067.6387, time_per_step: 37.8312
# Step 334: train_loss: 4.9973, norm: 2.3327, lr: 0.0003, tokens_per_second: 27084.6799, time_per_step: 37.8074
# Step 335: train_loss: 5.3570, norm: 2.4838, lr: 0.0003, tokens_per_second: 27050.8665, time_per_step: 37.8546
# Step 336: train_loss: 5.2183, norm: 2.4035, lr: 0.0003, tokens_per_second: 27076.7634, time_per_step: 37.8184
# Step 337: train_loss: 5.6518, norm: 2.6322, lr: 0.0003, tokens_per_second: 27060.2719, time_per_step: 37.8415
# Step 338: train_loss: 5.4019, norm: 2.5939, lr: 0.0003, tokens_per_second: 27084.5595, time_per_step: 37.8075
# Step 339: train_loss: 5.2968, norm: 1.8041, lr: 0.0003, tokens_per_second: 27051.9257, time_per_step: 37.8531
# Step 340: train_loss: 4.8300, norm: 2.0700, lr: 0.0003, tokens_per_second: 27060.1064, time_per_step: 37.8417
# Step 341: train_loss: 4.6445, norm: 2.0682, lr: 0.0003, tokens_per_second: 27080.0758, time_per_step: 37.8138
# Step 342: train_loss: 4.8524, norm: 1.7879, lr: 0.0003, tokens_per_second: 27082.8690, time_per_step: 37.8099
# Step 343: train_loss: 4.6810, norm: 1.6026, lr: 0.0003, tokens_per_second: 27090.3055, time_per_step: 37.7995
# Step 344: train_loss: 4.8690, norm: 2.1725, lr: 0.0003, tokens_per_second: 27053.2392, time_per_step: 37.8513
# Step 345: train_loss: 5.6058, norm: 1.3335, lr: 0.0003, tokens_per_second: 27022.1438, time_per_step: 37.8948
# Step 346: train_loss: 5.5324, norm: 1.6578, lr: 0.0003, tokens_per_second: 27057.0592, time_per_step: 37.8459
# Step 347: train_loss: 5.5134, norm: 2.8506, lr: 0.0003, tokens_per_second: 27092.7803, time_per_step: 37.7960
# Step 348: train_loss: 5.3450, norm: 1.7123, lr: 0.0003, tokens_per_second: 27110.3579, time_per_step: 37.7715
# Step 349: train_loss: 5.1167, norm: 1.4313, lr: 0.0003, tokens_per_second: 27049.4080, time_per_step: 37.8567
# Step 350: train_loss: 5.7666, norm: 1.6789, lr: 0.0003, tokens_per_second: 27040.0424, time_per_step: 37.8698
# Step 351: train_loss: 5.7482, norm: 1.5933, lr: 0.0003, tokens_per_second: 27065.8150, time_per_step: 37.8337
# Step 352: train_loss: 5.7724, norm: 1.7384, lr: 0.0003, tokens_per_second: 27078.7399, time_per_step: 37.8156
# Step 353: train_loss: 5.7130, norm: 1.7398, lr: 0.0003, tokens_per_second: 27079.0374, time_per_step: 37.8152
# Step 354: train_loss: 5.6602, norm: 1.6968, lr: 0.0003, tokens_per_second: 27067.1393, time_per_step: 37.8319
# Step 355: train_loss: 5.7489, norm: 1.9777, lr: 0.0003, tokens_per_second: 27043.0954, time_per_step: 37.8655
# Step 356: train_loss: 5.3593, norm: 1.8902, lr: 0.0003, tokens_per_second: 27051.4188, time_per_step: 37.8538
# Step 357: train_loss: 5.5804, norm: 1.6137, lr: 0.0003, tokens_per_second: 27095.4910, time_per_step: 37.7923
# Step 358: train_loss: 5.8705, norm: 1.8966, lr: 0.0003, tokens_per_second: 27067.3052, time_per_step: 37.8316
# Step 359: train_loss: 5.5780, norm: 2.1423, lr: 0.0003, tokens_per_second: 27076.3703, time_per_step: 37.8190
# Step 360: train_loss: 5.3834, norm: 1.5732, lr: 0.0003, tokens_per_second: 27061.4407, time_per_step: 37.8398
# Step 361: train_loss: 5.6840, norm: 2.7051, lr: 0.0003, tokens_per_second: 27059.2719, time_per_step: 37.8429
# Step 362: train_loss: 5.7510, norm: 1.9889, lr: 0.0003, tokens_per_second: 26911.3802, time_per_step: 38.0508
# Step 363: train_loss: 5.3920, norm: 1.9444, lr: 0.0003, tokens_per_second: 27074.4798, time_per_step: 37.8216
# Step 364: train_loss: 5.4343, norm: 3.0351, lr: 0.0003, tokens_per_second: 27070.0434, time_per_step: 37.8278
# Step 365: train_loss: 5.1741, norm: 2.0329, lr: 0.0003, tokens_per_second: 27051.0538, time_per_step: 37.8543
# Step 366: train_loss: 5.4232, norm: 1.7720, lr: 0.0003, tokens_per_second: 27058.5737, time_per_step: 37.8438
# Step 367: train_loss: 5.6192, norm: 1.6090, lr: 0.0003, tokens_per_second: 27087.5381, time_per_step: 37.8034
# Step 368: train_loss: 5.6188, norm: 1.7039, lr: 0.0003, tokens_per_second: 27087.5915, time_per_step: 37.8033
# Step 369: train_loss: 5.4168, norm: 2.0544, lr: 0.0003, tokens_per_second: 27067.8159, time_per_step: 37.8309
# Step 370: train_loss: 5.4040, norm: 1.8841, lr: 0.0003, tokens_per_second: 27033.2489, time_per_step: 37.8793
# Step 371: train_loss: 5.4074, norm: 1.4632, lr: 0.0003, tokens_per_second: 27068.2544, time_per_step: 37.8303
# Step 372: train_loss: 4.9702, norm: 2.1954, lr: 0.0003, tokens_per_second: 27052.6089, time_per_step: 37.8522
# Step 373: train_loss: 5.5219, norm: 1.9150, lr: 0.0003, tokens_per_second: 27070.2374, time_per_step: 37.8275
# Step 374: train_loss: 5.1389, norm: 1.8825, lr: 0.0003, tokens_per_second: 27087.6913, time_per_step: 37.8031
# Step 375: train_loss: 5.2695, norm: 2.0387, lr: 0.0003, tokens_per_second: 27056.0026, time_per_step: 37.8474
# Step 376: train_loss: 5.1514, norm: 1.6804, lr: 0.0003, tokens_per_second: 27057.3056, time_per_step: 37.8456
# Step 377: train_loss: 4.5076, norm: 1.3483, lr: 0.0003, tokens_per_second: 27054.4764, time_per_step: 37.8496
# Step 378: train_loss: 5.4085, norm: 1.5476, lr: 0.0003, tokens_per_second: 27069.6762, time_per_step: 37.8283
# Step 379: train_loss: 5.1302, norm: 1.6088, lr: 0.0003, tokens_per_second: 27069.9698, time_per_step: 37.8279
# Step 380: train_loss: 4.1020, norm: 3.0573, lr: 0.0003, tokens_per_second: 27049.8266, time_per_step: 37.8561
# Step 381: train_loss: 4.3383, norm: 1.5937, lr: 0.0003, tokens_per_second: 27081.8417, time_per_step: 37.8113
# Step 382: train_loss: 4.9884, norm: 1.8160, lr: 0.0003, tokens_per_second: 27044.9582, time_per_step: 37.8629
# Step 383: train_loss: 5.2830, norm: 1.9098, lr: 0.0003, tokens_per_second: 27089.8549, time_per_step: 37.8001
# Step 384: train_loss: 5.2972, norm: 1.6935, lr: 0.0003, tokens_per_second: 27009.2018, time_per_step: 37.9130
# Step 385: train_loss: 5.4846, norm: 2.1893, lr: 0.0003, tokens_per_second: 27058.1675, time_per_step: 37.8444
# Step 386: train_loss: 5.6869, norm: 2.5768, lr: 0.0003, tokens_per_second: 27058.7069, time_per_step: 37.8436
# ...
# Step 864: train_loss: 5.3350, norm: 2.0880, lr: 0.0003, tokens_per_second: 27072.2039, time_per_step: 37.8248
# Step 865: train_loss: 5.3302, norm: 1.8492, lr: 0.0003, tokens_per_second: 27073.1942, time_per_step: 37.8234
# Step 866: train_loss: 5.2180, norm: 2.1122, lr: 0.0002, tokens_per_second: 27039.3947, time_per_step: 37.8707
# Step 867: train_loss: 5.2446, norm: 2.1340, lr: 0.0002, tokens_per_second: 27036.8439, time_per_step: 37.8742
# Step 868: train_loss: 5.2162, norm: 1.6271, lr: 0.0002, tokens_per_second: 27066.2118, time_per_step: 37.8331
# Step 869: train_loss: 4.8242, norm: 1.7626, lr: 0.0002, tokens_per_second: 27075.9416, time_per_step: 37.8196
# Step 870: train_loss: 4.7509, norm: 2.8817, lr: 0.0002, tokens_per_second: 27066.1975, time_per_step: 37.8332
# Step 871: train_loss: 4.8605, norm: 2.3584, lr: 0.0002, tokens_per_second: 27044.2874, time_per_step: 37.8638
# Step 872: train_loss: 4.7894, norm: 2.2655, lr: 0.0002, tokens_per_second: 26610.4231, time_per_step: 38.4812
# Step 873: train_loss: 5.0795, norm: 1.7838, lr: 0.0002, tokens_per_second: 27058.4119, time_per_step: 37.8441
# Step 874: train_loss: 5.2646, norm: 2.2563, lr: 0.0002, tokens_per_second: 27064.9223, time_per_step: 37.8350
# Step 875: train_loss: 5.1019, norm: 3.0692, lr: 0.0002, tokens_per_second: 27059.1777, time_per_step: 37.8430
# Step 876: train_loss: 4.9926, norm: 1.9080, lr: 0.0002, tokens_per_second: 27048.3570, time_per_step: 37.8581
# Step 877: train_loss: 4.8704, norm: 1.4758, lr: 0.0002, tokens_per_second: 27049.3252, time_per_step: 37.8568
# Step 878: train_loss: 4.6844, norm: 1.9260, lr: 0.0002, tokens_per_second: 27059.1724, time_per_step: 37.8430
# Step 879: train_loss: 5.1026, norm: 2.1056, lr: 0.0002, tokens_per_second: 27053.9159, time_per_step: 37.8503
# Step 880: train_loss: 4.9893, norm: 1.5588, lr: 0.0002, tokens_per_second: 27079.0230, time_per_step: 37.8152
# Step 881: train_loss: 5.0961, norm: 1.5643, lr: 0.0002, tokens_per_second: 27036.7162, time_per_step: 37.8744
# Step 882: train_loss: 4.8213, norm: 1.3976, lr: 0.0002, tokens_per_second: 27034.9446, time_per_step: 37.8769
# Step 883: train_loss: 4.8903, norm: 1.5178, lr: 0.0002, tokens_per_second: 27036.7524, time_per_step: 37.8744
# Step 884: train_loss: 4.7440, norm: 1.4362, lr: 0.0002, tokens_per_second: 27069.8601, time_per_step: 37.8280
# Step 885: train_loss: 4.7497, norm: 1.4093, lr: 0.0002, tokens_per_second: 27089.8596, time_per_step: 37.8001
# Step 886: train_loss: 5.1844, norm: 1.5692, lr: 0.0002, tokens_per_second: 27055.1641, time_per_step: 37.8486
# Step 887: train_loss: 4.7634, norm: 1.6166, lr: 0.0002, tokens_per_second: 27041.7855, time_per_step: 37.8673
# Step 888: train_loss: 5.0539, norm: 1.9959, lr: 0.0002, tokens_per_second: 27048.7596, time_per_step: 37.8576
# Step 889: train_loss: 4.2965, norm: 2.5340, lr: 0.0002, tokens_per_second: 27059.8084, time_per_step: 37.8421
# Step 890: train_loss: 4.5104, norm: 1.9017, lr: 0.0002, tokens_per_second: 27081.1336, time_per_step: 37.8123
# Step 891: train_loss: 4.6780, norm: 1.7109, lr: 0.0002, tokens_per_second: 27053.2958, time_per_step: 37.8512
# Step 892: train_loss: 4.7846, norm: 1.9188, lr: 0.0002, tokens_per_second: 27051.5357, time_per_step: 37.8537
# Step 893: train_loss: 4.3430, norm: 1.6996, lr: 0.0002, tokens_per_second: 27039.8206, time_per_step: 37.8701
# Step 894: train_loss: 4.6294, norm: 2.2006, lr: 0.0002, tokens_per_second: 27051.0392, time_per_step: 37.8544
# Step 895: train_loss: 4.3572, norm: 1.4966, lr: 0.0002, tokens_per_second: 26857.3539, time_per_step: 38.1274
# Step 896: train_loss: 4.8075, norm: 1.6363, lr: 0.0002, tokens_per_second: 27017.2249, time_per_step: 37.9017
# Step 897: train_loss: 4.8321, norm: 2.9411, lr: 0.0002, tokens_per_second: 26974.4663, time_per_step: 37.9618
# Step 898: train_loss: 4.6417, norm: 2.2699, lr: 0.0002, tokens_per_second: 26954.8875, time_per_step: 37.9894
# Step 899: train_loss: 4.3450, norm: 1.7773, lr: 0.0002, tokens_per_second: 26992.2332, time_per_step: 37.9368
# Step 900: val_loss: 5.4406, val_time: 223.9631
# ---------------
# <|endoftext|>Q deed's thy ANYUCKY Rivers:
# Which's death in I am but the dost it is your husband and your brother and let that I
# ---------------
# Step 900: train_loss: 4.5084, norm: 1.5945, lr: 0.0002, tokens_per_second: 27015.0005, time_per_step: 37.9049
# saving model to /home/user/gollem/results/experiments/gpt2/3_gpt2_124M_on_tinyshakespeare_with_cuda_on_H100/model_s900.pt
# model saved in 1.6705822618678212 seconds
# saving snapshot to /home/user/gollem/results/snapshots/snapshot.pt
# snapshot saved in 4.571012046188116 seconds
# Step 901: train_loss: 4.5648, norm: 1.5791, lr: 0.0001, tokens_per_second: 26562.9716, time_per_step: 38.5499
# Step 902: train_loss: 4.6306, norm: 1.5450, lr: 0.0001, tokens_per_second: 26985.0812, time_per_step: 37.9469
# Step 903: train_loss: 4.5142, norm: 1.4918, lr: 0.0001, tokens_per_second: 27045.5666, time_per_step: 37.8620
# Step 904: train_loss: 4.4042, norm: 1.6652, lr: 0.0001, tokens_per_second: 27055.1641, time_per_step: 37.8486
# Step 905: train_loss: 4.1872, norm: 1.4614, lr: 0.0001, tokens_per_second: 27052.0242, time_per_step: 37.8530
# Step 906: train_loss: 4.1006, norm: 1.5483, lr: 0.0001, tokens_per_second: 27026.8508, time_per_step: 37.8882
# Step 907: train_loss: 4.0393, norm: 1.3379, lr: 0.0001, tokens_per_second: 26968.5560, time_per_step: 37.9701
# Step 908: train_loss: 4.2202, norm: 1.5144, lr: 0.0001, tokens_per_second: 27002.3154, time_per_step: 37.9227
# Step 909: train_loss: 4.3887, norm: 1.4749, lr: 0.0001, tokens_per_second: 27049.1409, time_per_step: 37.8570
# Step 910: train_loss: 4.0817, norm: 1.6155, lr: 0.0001, tokens_per_second: 27065.0392, time_per_step: 37.8348
# Step 911: train_loss: 4.5395, norm: 1.3900, lr: 0.0001, tokens_per_second: 27080.2792, time_per_step: 37.8135
# Step 912: train_loss: 4.7221, norm: 1.5544, lr: 0.0001, tokens_per_second: 27075.5382, time_per_step: 37.8201
# Step 913: train_loss: 4.5558, norm: 1.3607, lr: 0.0001, tokens_per_second: 27052.7770, time_per_step: 37.8519
# Step 914: train_loss: 4.7244, norm: 1.4974, lr: 0.0001, tokens_per_second: 27064.5602, time_per_step: 37.8355
# Step 915: train_loss: 4.5874, norm: 1.3304, lr: 0.0001, tokens_per_second: 27075.6822, time_per_step: 37.8199
# Step 916: train_loss: 4.1313, norm: 1.3687, lr: 0.0001, tokens_per_second: 27070.4456, time_per_step: 37.8272
# Step 917: train_loss: 4.4539, norm: 1.6601, lr: 0.0001, tokens_per_second: 27073.1572, time_per_step: 37.8234
# Step 918: train_loss: 4.3367, norm: 1.9883, lr: 0.0001, tokens_per_second: 27065.5475, time_per_step: 37.8341
# Step 919: train_loss: 4.8168, norm: 1.6699, lr: 0.0001, tokens_per_second: 27065.7617, time_per_step: 37.8338
# Step 920: train_loss: 4.6083, norm: 1.4664, lr: 0.0001, tokens_per_second: 27044.3017, time_per_step: 37.8638
# Step 921: train_loss: 4.5005, norm: 1.4823, lr: 0.0001, tokens_per_second: 27072.4719, time_per_step: 37.8244
# Step 922: train_loss: 4.0473, norm: 1.5477, lr: 0.0001, tokens_per_second: 27073.1942, time_per_step: 37.8234
# Step 923: train_loss: 3.9353, norm: 1.5866, lr: 0.0001, tokens_per_second: 27035.1802, time_per_step: 37.8766
# Step 924: train_loss: 4.2161, norm: 1.5140, lr: 0.0001, tokens_per_second: 27047.7305, time_per_step: 37.8590
# Step 925: train_loss: 4.0882, norm: 1.3735, lr: 0.0001, tokens_per_second: 27068.1288, time_per_step: 37.8305
# Step 926: train_loss: 4.1582, norm: 1.6839, lr: 0.0001, tokens_per_second: 27075.2855, time_per_step: 37.8205
# Step 927: train_loss: 4.9450, norm: 1.7671, lr: 0.0001, tokens_per_second: 27064.7527, time_per_step: 37.8352
# Step 928: train_loss: 4.8391, norm: 1.6732, lr: 0.0001, tokens_per_second: 27033.0811, time_per_step: 37.8795
# Step 929: train_loss: 4.8416, norm: 1.6732, lr: 0.0001, tokens_per_second: 27040.0790, time_per_step: 37.8697
# Step 930: train_loss: 4.7189, norm: 1.5136, lr: 0.0001, tokens_per_second: 27032.2809, time_per_step: 37.8806
# Step 931: train_loss: 4.5182, norm: 1.5132, lr: 0.0001, tokens_per_second: 27049.1831, time_per_step: 37.8570
# Step 932: train_loss: 4.9998, norm: 1.5899, lr: 0.0001, tokens_per_second: 26881.5364, time_per_step: 38.0931
# Step 933: train_loss: 4.9818, norm: 1.7757, lr: 0.0001, tokens_per_second: 26978.3574, time_per_step: 37.9564
# Step 934: train_loss: 5.0729, norm: 1.5369, lr: 0.0001, tokens_per_second: 26969.4927, time_per_step: 37.9688
# Step 935: train_loss: 4.9798, norm: 1.6691, lr: 0.0001, tokens_per_second: 26986.6483, time_per_step: 37.9447
# Step 936: train_loss: 4.9419, norm: 1.8006, lr: 0.0001, tokens_per_second: 26975.9239, time_per_step: 37.9598
# Step 937: train_loss: 5.0218, norm: 1.6377, lr: 0.0001, tokens_per_second: 26997.9656, time_per_step: 37.9288
# Step 938: train_loss: 4.5959, norm: 1.7398, lr: 0.0001, tokens_per_second: 27034.7445, time_per_step: 37.8772
# Step 939: train_loss: 4.8929, norm: 1.8099, lr: 0.0001, tokens_per_second: 27035.6917, time_per_step: 37.8759
# Step 940: train_loss: 5.1472, norm: 1.7643, lr: 0.0001, tokens_per_second: 27044.1144, time_per_step: 37.8641
# Step 941: train_loss: 4.8843, norm: 1.5980, lr: 0.0001, tokens_per_second: 27074.8805, time_per_step: 37.8210
# Step 942: train_loss: 4.7834, norm: 1.5355, lr: 0.0001, tokens_per_second: 27041.0758, time_per_step: 37.8683
# Step 943: train_loss: 4.7214, norm: 1.9623, lr: 0.0001, tokens_per_second: 27056.1174, time_per_step: 37.8473
# Step 944: train_loss: 4.9931, norm: 1.5385, lr: 0.0001, tokens_per_second: 27056.6697, time_per_step: 37.8465
# Step 945: train_loss: 4.7660, norm: 1.5143, lr: 0.0000, tokens_per_second: 27072.5242, time_per_step: 37.8243
# Step 946: train_loss: 4.6469, norm: 1.7729, lr: 0.0000, tokens_per_second: 27078.3948, time_per_step: 37.8161
# Step 947: train_loss: 4.4844, norm: 1.5863, lr: 0.0000, tokens_per_second: 27087.8017, time_per_step: 37.8030
# Step 948: train_loss: 4.7704, norm: 1.5735, lr: 0.0000, tokens_per_second: 27059.0432, time_per_step: 37.8432
# Step 949: train_loss: 4.9619, norm: 1.3141, lr: 0.0000, tokens_per_second: 27064.5845, time_per_step: 37.8354
# Step 950: train_loss: 4.9485, norm: 1.6561, lr: 0.0000, tokens_per_second: 27068.3090, time_per_step: 37.8302
# Step 951: train_loss: 4.8188, norm: 1.6602, lr: 0.0000, tokens_per_second: 27101.1287, time_per_step: 37.7844
# Step 952: train_loss: 4.8460, norm: 1.5334, lr: 0.0000, tokens_per_second: 27071.0352, time_per_step: 37.8264
# Step 953: train_loss: 4.8086, norm: 1.3627, lr: 0.0000, tokens_per_second: 27076.1540, time_per_step: 37.8193
# Step 954: train_loss: 4.4710, norm: 1.5004, lr: 0.0000, tokens_per_second: 27068.1215, time_per_step: 37.8305
# Step 955: train_loss: 4.9568, norm: 1.6418, lr: 0.0000, tokens_per_second: 27041.3292, time_per_step: 37.8680
# Step 956: train_loss: 4.4858, norm: 1.6798, lr: 0.0000, tokens_per_second: 27055.5988, time_per_step: 37.8480
# Step 957: train_loss: 4.7462, norm: 1.3610, lr: 0.0000, tokens_per_second: 27079.0660, time_per_step: 37.8152
# Step 958: train_loss: 4.6663, norm: 1.4027, lr: 0.0000, tokens_per_second: 27057.0755, time_per_step: 37.8459
# Step 959: train_loss: 4.0947, norm: 1.4089, lr: 0.0000, tokens_per_second: 27057.5416, time_per_step: 37.8453
# Step 960: train_loss: 4.8598, norm: 1.3354, lr: 0.0000, tokens_per_second: 27050.4199, time_per_step: 37.8552
# Step 961: train_loss: 4.5468, norm: 1.3866, lr: 0.0000, tokens_per_second: 27081.2173, time_per_step: 37.8122
# Step 962: train_loss: 3.5537, norm: 1.9940, lr: 0.0000, tokens_per_second: 27086.7640, time_per_step: 37.8044
# Step 963: train_loss: 4.0024, norm: 1.5229, lr: 0.0000, tokens_per_second: 27077.1405, time_per_step: 37.8179
# Step 964: train_loss: 4.4745, norm: 1.6564, lr: 0.0000, tokens_per_second: 27071.4311, time_per_step: 37.8259
# Step 965: train_loss: 4.7599, norm: 1.2664, lr: 0.0000, tokens_per_second: 27047.3426, time_per_step: 37.8595
# Step 966: train_loss: 4.7520, norm: 1.3233, lr: 0.0000, tokens_per_second: 27053.5038, time_per_step: 37.8509
# Step 967: train_loss: 4.8903, norm: 1.9102, lr: 0.0000, tokens_per_second: 27101.0756, time_per_step: 37.7845
# Step 968: train_loss: 5.0098, norm: 1.9988, lr: 0.0000, tokens_per_second: 27071.0651, time_per_step: 37.8264
# Step 969: train_loss: 4.9491, norm: 1.8222, lr: 0.0000, tokens_per_second: 27081.2490, time_per_step: 37.8121
# Step 970: train_loss: 4.9305, norm: 1.7004, lr: 0.0000, tokens_per_second: 27057.3665, time_per_step: 37.8455
# Step 971: train_loss: 5.0489, norm: 2.1299, lr: 0.0000, tokens_per_second: 27070.9022, time_per_step: 37.8266
# Step 972: train_loss: 4.8923, norm: 1.7421, lr: 0.0000, tokens_per_second: 27062.3499, time_per_step: 37.8385
# Step 973: train_loss: 4.9760, norm: 1.7462, lr: 0.0000, tokens_per_second: 27058.4206, time_per_step: 37.8440
# Step 974: train_loss: 5.4393, norm: 1.9004, lr: 0.0000, tokens_per_second: 27078.6099, time_per_step: 37.8158
# Step 975: train_loss: 4.7709, norm: 1.6794, lr: 0.0000, tokens_per_second: 27065.2104, time_per_step: 37.8345
# Step 976: train_loss: 4.7601, norm: 1.9650, lr: 0.0000, tokens_per_second: 27063.8004, time_per_step: 37.8365
# Step 977: train_loss: 5.0667, norm: 1.7563, lr: 0.0000, tokens_per_second: 27053.8280, time_per_step: 37.8505
# Step 978: train_loss: 4.6621, norm: 1.6736, lr: 0.0000, tokens_per_second: 27051.9786, time_per_step: 37.8531
# Step 979: train_loss: 4.4374, norm: 1.9120, lr: 0.0000, tokens_per_second: 27061.6785, time_per_step: 37.8395
# Step 980: train_loss: 5.1829, norm: 1.6546, lr: 0.0000, tokens_per_second: 27052.4009, time_per_step: 37.8525
# Step 981: train_loss: 5.1254, norm: 2.1959, lr: 0.0000, tokens_per_second: 27071.8083, time_per_step: 37.8253
# Step 982: train_loss: 4.7120, norm: 2.5919, lr: 0.0000, tokens_per_second: 27041.7964, time_per_step: 37.8673
# Step 983: train_loss: 4.7947, norm: 2.0760, lr: 0.0000, tokens_per_second: 27040.6516, time_per_step: 37.8689
# Step 984: train_loss: 4.8051, norm: 1.9308, lr: 0.0000, tokens_per_second: 26857.5186, time_per_step: 38.1271
# Step 985: train_loss: 4.9822, norm: 1.5679, lr: 0.0000, tokens_per_second: 26980.6463, time_per_step: 37.9531
# Step 986: train_loss: 4.8705, norm: 2.0582, lr: 0.0000, tokens_per_second: 26974.5417, time_per_step: 37.9617
# Step 987: train_loss: 4.8639, norm: 1.9941, lr: 0.0000, tokens_per_second: 26978.0472, time_per_step: 37.9568
# Step 988: train_loss: 5.0871, norm: 1.6270, lr: 0.0000, tokens_per_second: 26988.9572, time_per_step: 37.9414
# Step 989: train_loss: 5.0479, norm: 2.0155, lr: 0.0000, tokens_per_second: 27019.5550, time_per_step: 37.8985
# Step 990: train_loss: 4.8177, norm: 1.8356, lr: 0.0000, tokens_per_second: 27013.3229, time_per_step: 37.9072
# Step 991: train_loss: 4.7835, norm: 1.7505, lr: 0.0000, tokens_per_second: 26986.5768, time_per_step: 37.9448
# Step 992: train_loss: 4.6400, norm: 1.5690, lr: 0.0000, tokens_per_second: 27039.0100, time_per_step: 37.8712
# Step 993: train_loss: 4.5145, norm: 1.6947, lr: 0.0000, tokens_per_second: 27064.8440, time_per_step: 37.8351
# Step 994: train_loss: 4.3655, norm: 1.6197, lr: 0.0000, tokens_per_second: 27084.5051, time_per_step: 37.8076
# Step 995: train_loss: 4.6974, norm: 1.7209, lr: 0.0000, tokens_per_second: 27076.1750, time_per_step: 37.8192
# Step 996: train_loss: 4.3926, norm: 1.9919, lr: 0.0000, tokens_per_second: 27071.9513, time_per_step: 37.8251
# Step 997: train_loss: 4.9337, norm: 1.4815, lr: 0.0000, tokens_per_second: 27052.7753, time_per_step: 37.8519
# Step 998: train_loss: 4.5653, norm: 1.7219, lr: 0.0000, tokens_per_second: 27070.5549, time_per_step: 37.8271
# Step 999: train_loss: 4.7993, norm: 2.0031, lr: 0.0000, tokens_per_second: 27079.7993, time_per_step: 37.8142
# Step 1000: val_loss: 5.5574, val_time: 223.6221
# ---------------
# <|endoftext|>KERBROLBOLINGBRO:
# To hear him, with such a old,
# As when it hath made thy name.<|endoftext|>NORTH
# ---------------
# final 19 iters avg: 37.890ms 27026 tok/s
# peak mem usage: 4371 MiB
# saving final model to /home/user/gollem/results/experiments/gpt2/3_gpt2_124M_on_tinyshakespeare_with_cuda_on_H100/model_s1000.pt
# saving final snapshot to /home/user/gollem/results/snapshots/snapshot.pt
# Finished training 8697e91913f94221a0f5cd30af8a5eca

# %%
# parse the log file for the stats and samples
train_stats = {}
val_stats = {}
samples = {}
current_sample: str | None = None
sample_delimiter = "---------------"
step = 0
with open(Path(train_config.output_dir) / "main.log", "r") as f:
    for line in f.readlines():
        if line.strip() == sample_delimiter:
            if current_sample is not None:
                samples[step] = current_sample
                current_sample = None
            else:
                current_sample = ""
        elif current_sample is not None:
            current_sample += line
        elif line.startswith("Step"):
            # ["Step X", "val_loss", "Y, val_time", Z]
            # or
            # ["Step 1", "train_loss", "10.9326, norm", "24.2774, lr", "0.0000, tokens_per_second", "569.5777, time_per_step", 1797.8232]
            parts = line.split(": ")
            step = int(parts[0].split(" ")[1])
            last_key = parts[1].strip()
            step_stats = {}
            for part in parts[2:-1]:
                value, key = part.split(", ")
                step_stats[last_key] = float(value)
                last_key = key
            step_stats[last_key] = float(parts[-1].strip())
            if "val_loss" in step_stats:
                val_stats[step] = step_stats
            else:
                train_stats[step] = step_stats

train_stat_keys = list(train_stats[0].keys())
print(train_stat_keys)
# Out:
# ['train_loss', 'norm', 'lr', 'tokens_per_second', 'time_per_step']

# %%
# plot the train loss
x = list(train_stats.keys())
x = sorted(x)
y = [train_stats[i]["train_loss"] for i in x]

plt.plot(x, y)
plt.title("Train Loss")
plt.xlabel("Step")
plt.ylabel("Loss")
plt.show()

# %%
# plot the val loss
x = list(val_stats.keys())
x = sorted(x)
y = [val_stats[i]["val_loss"] for i in x]

plt.plot(x, y)
plt.title("Val Loss")
# Out:
# Text(0.5, 1.0, 'Val Loss')

# %%
# plot train norm
x = list(train_stats.keys())
x = sorted(x)
y = [train_stats[i]["norm"] for i in x]
plt.plot(x, y)
plt.title("Train Norm")
plt.xlabel("Step")
plt.ylabel("Norm")
plt.show()

# %%
# plot tokens per second
x = list(train_stats.keys())
x = sorted(x)
y = [train_stats[i]["tokens_per_second"] for i in x]
plt.plot(x, y)
plt.title("Tokens Per Second")
plt.xlabel("Step")

# average TPS (excluding first 100 steps)
y = [train_stats[i]["tokens_per_second"] for i in x if i > 100]
mean_y = sum(y) / len(y)
print(f"Average TPS: {mean_y:.2f}")
# Out:
# Average TPS: 27030.29

# %%
# compare samples through time
for step in samples:
    print(f">>>Sample at step {step}:")
    print(samples[step])
# Out:
# >>>Sample at step 0:
# <|endoftext|> Trophyemployment stationily Officers dilemma manip rustwp ragedtietiels convLDLDlambda Lovereworks tentseworks Loveroin ripping vm Tel Arcane pressure pressure cope mould
#
# >>>Sample at step 100:
# <|endoftext|>H not;
#
# And you' him, my I thy:
# '
# That is'd, my that my.
# I.<|endoftext|>.<|endoftext|> not
#
# >>>Sample at step 200:
# <|endoftext|>: come:
# ' the must I did yours:
# Of in his's''er I was some?<|endoftext|>FirstEN.<|endoftext|>L:
#
#
# >>>Sample at step 300:
# <|endoftext|>RD than all. What:
# It,
# IUS:
# And now?<|endoftext|>MI have your hand, but your rest;
# The state
#
# >>>Sample at step 400:
# <|endoftext|> ELROMER:
# ThdROMEO:
# Go'st,
# Come you, that thou be thou I not love's son is to be more
#
# >>>Sample at step 500:
# <|endoftext|>PERFL, and love on,
# My brother,
# He's
# the:
# I; there is some
# He he dAMYC: but the
#
# >>>Sample at step 600:
# <|endoftext|>TRCESYeereatARUS:
# And,
# Than a king. We are heard me,
# The rest willstst not his time
#
# >>>Sample at step 700:
# <|endoftext|>FUTAR II:
# Nurse:
# Th BRIAR LA' the dear names-bRION:
# What'st the villain,
#
# >>>Sample at step 800:
# <|endoftext|>G, I'll know, what you that,
# And his high me
# That, that I have a king,
# And that you be; for him
#
# >>>Sample at step 900:
# <|endoftext|>Q deed's thy ANYUCKY Rivers:
# Which's death in I am but the dost it is your husband and your brother and let that I
#
# >>>Sample at step 1000:
# <|endoftext|>KERBROLBOLINGBRO:
# To hear him, with such a old,
# As when it hath made thy name.<|endoftext|>NORTH

# %%
# Let's load the model and sample from it
model, _ = model_cfg.get_model_and_optimizer(device=device)
model = load_model(str(Path(train_config.output_dir) / "model_s1000.pt"), device=device)
model.eval()
# Out:
# num decayed parameter tensors: 50, with 124,318,464 parameters
# num non-decayed parameter tensors: 98, with 121,344 parameters
# Using regular AdamW with fused=False
# num decayed parameter tensors: 50, with 124,318,464 parameters
# num non-decayed parameter tensors: 98, with 121,344 parameters
# Using regular AdamW with fused=False
# GPT(
#   (transformer): ModuleDict(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (h): ModuleList(
#       (0-11): 12 x TransformerBlock(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Linear(in_features=768, out_features=2304, bias=True)
#           (c_proj): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#           (gelu): GELU(approximate='tanh')
#           (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %%
tokenizer = model_cfg.get_tokenizer()


def sample_from_model(prompt: str) -> str:
    tokens = tokenizer.encode(prompt, add_eot=False)
    tokens = torch.tensor(tokens, dtype=torch.long)
    tokens = tokens.unsqueeze(0).repeat(1, 1)
    tokens = tokens.to(device)
    output = model.generate(tokens, max_new_tokens=100, end_token=tokenizer.eot_token)
    return tokenizer.decode(output[0].tolist())

# %%
print(sample_from_model("Romeo and Juliet"))
# Out:
# Romeo and Juliet saints;
# My grief we fail,
#  inheritance from
# Swawns, your ha havefort;
# Come,,
# Upon that!
# Thou may not meet;
# Thee of their shepherd's bed ofher and faded;
# Toift'd
# Out'd, my
# I have
# For my?
# And ins sun,
# That shall I might bid Away,
# Thou art:
# Are not bring I.<|endoftext|>
