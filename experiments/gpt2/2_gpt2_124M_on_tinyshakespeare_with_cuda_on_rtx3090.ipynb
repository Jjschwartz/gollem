# %% [markdown]
# # Training GPT2 124M on Tiny shakespeare dataset on my laptop using CUDA on RTX 3090
#
# In this notebook, we train a GPT2 124M model on the Tiny Shakespeare dataset on my laptop without any optimizations except for using CUDA on RTX 3090.

# %%
from pathlib import Path

import torch
from matplotlib import pyplot as plt

from gollem.data import load_dataset
from gollem.models.gpt2.config import GPT2Config
from gollem.models.gpt2.config import get_gpt2_model_config
from gollem.train.config import TrainConfig
from gollem.train.core import run
from gollem.utils import get_base_dir_path
from gollem.models.model import load_model
from gollem.train.utils import get_hardware_info

# get available devices
hardware_info = get_hardware_info()
for key, value in hardware_info.items():
    print(f"{key}: {value}")

device = "cuda"
# Out:
# os: {'system': 'Linux', 'release': '5.4.0-166-generic', 'version': '#183-Ubuntu SMP Mon Oct 2 11:28:33 UTC 2023', 'machine': 'x86_64'}
# cpu: {'brand': 'x86_64', 'cores_physical': 32, 'cores_logical': 64}
# memory: {'total_gb': 503.74}
# gpu: {'name': 'NVIDIA GeForce RTX 3090', 'count': 8, 'capability': (8, 6), 'memory_total_gb': 23.69, 'memory_allocated_gb': 0.0}

# %%
# Create configs
model_cfg = get_gpt2_model_config("gpt2")
# remove optimizations
model_cfg = GPT2Config.override(
    model_cfg,
    **{
        "fused_adamw": False,
        "zero_optimizer": False,
        "flash": False,
        "activation_checkpointing": False,
        "compile": False,
        "from_pretrained": False,
        "use_kv_caching": False,
    },
)

dataset = load_dataset("tinyshakespeare", model_cfg.get_tokenizer())

train_config = TrainConfig(
    output_dir=str(
        get_base_dir_path()
        / "results"
        / "experiments"
        / "gpt2"
        / "2_gpt2_124M_on_tinyshakespeare_with_mps"
    ),
    batch_size=1,
    seq_len=1024,
    total_batch_size=1024,
    num_iterations=1000,
    val_loss_every=100,
    sample_every=100,
    save_every=100,
    snapshot_every=100,
    device=device,
    dtype="float32",
    tensorcores=False,
    use_wandb=False,
)
# Out:
# /home/user/gollem/gollem/data/datasets/tinyshakespeare/tiny_shakespeare.txt already exists, skipping download...
# writing 32,768 tokens to /home/user/gollem/gollem/data/datasets/tinyshakespeare/gpt2/tiny_shakespeare_val.bin (66,560 bytes) in dtype=<class 'numpy.uint16'>
# writing 298,039 tokens to /home/user/gollem/gollem/data/datasets/tinyshakespeare/gpt2/tiny_shakespeare_train.bin (597,102 bytes) in dtype=<class 'numpy.uint16'>

# %%
# change to False to avoid rerunning the training
if True:
    run(dataset, model_cfg, train_config)
# Out:
# Launching GPU0|0 in process group 1 using device cuda
# total desired batch size: 1024
# => calculated gradient accumulation steps: 1
# Starting new run 9cd980c97b96455c9ca04cd73876d5c4
#
# Config:
# {'dataset_config': {'name': 'tinyshakespeare',
#                     'train_data': [PosixPath('/home/user/gollem/gollem/data/datasets/tinyshakespeare/gpt2/tiny_shakespeare_train.bin')],
#                     'val_data': [PosixPath('/home/user/gollem/gollem/data/datasets/tinyshakespeare/gpt2/tiny_shakespeare_val.bin')]},
#  'device': 'cuda',
#  'device_type': 'cuda',
#  'model_config': {'activation_checkpointing': False,
#                   'betas': (0.9, 0.95),
#                   'compile': False,
#                   'd_mlp': 3072,
#                   'd_model': 768,
#                   'flash': False,
#                   'from_pretrained': False,
#                   'fused_adamw': False,
#                   'grad_clip': 1.0,
#                   'learning_rate': 0.0006,
#                   'learning_rate_decay_frac': 0.0,
#                   'ln_bias': True,
#                   'max_sample_batch_size': 1,
#                   'mlp_bias': True,
#                   'model_name': 'gpt2',
#                   'n_ctx': 1024,
#                   'n_head': 12,
#                   'n_layer': 12,
#                   'share_embd_params': True,
#                   'use_kv_caching': False,
#                   'vocab_size': 50257,
#                   'warmup_iters': 700,
#                   'weight_decay': 0.1,
#                   'zero_optimizer': False},
#  'pytorch_version': '2.5.1+cu121',
#  'train_config': {'batch_size': 1,
#                   'device': 'cuda',
#                   'dtype': 'float32',
#                   'grad_accum_steps': 1,
#                   'num_iterations': 1000,
#                   'output_dir': '/home/user/gollem/results/experiments/gpt2/2_gpt2_124M_on_tinyshakespeare_with_mps',
#                   'sample_every': 100,
#                   'save_every': 100,
#                   'seed': 42,
#                   'seq_len': 1024,
#                   'snapshot_every': 100,
#                   'tensorcores': False,
#                   'total_batch_size': 1024,
#                   'use_wandb': False,
#                   'val_loss_every': 100,
#                   'val_max_steps': 20}}
# num decayed parameter tensors: 50, with 124,318,464 parameters
# num non-decayed parameter tensors: 98, with 121,344 parameters
# Using regular AdamW with fused=False
# DataLoader: total number of tokens: 298,039 across 1 files
# DataLoader: total number of tokens: 32,768 across 1 files
# Starting training for 1000 iterations
# Step 0: val_loss: 11.0214, val_time: 880.8572
# ---------------
# <|endoftext|> Trophyemployment stationily Officers dilemma manip rustwp ragedtietiels convLDLDlambda Lovereworks tentseworks Loveroin ripping vm Tel Arcane pressure pressure cope mould
# ---------------
# Step 0: train_loss: 11.0052, norm: 25.3916, lr: 0.0000, tokens_per_second: 6450.8794, time_per_step: 158.7380
# Step 1: train_loss: 10.9326, norm: 24.2788, lr: 0.0000, tokens_per_second: 12100.3933, time_per_step: 84.6253
# Step 2: train_loss: 10.8366, norm: 26.1579, lr: 0.0000, tokens_per_second: 11963.0224, time_per_step: 85.5971
# Step 3: train_loss: 10.7297, norm: 22.9848, lr: 0.0000, tokens_per_second: 11972.6986, time_per_step: 85.5279
# Step 4: train_loss: 10.4854, norm: 20.5783, lr: 0.0000, tokens_per_second: 11988.3627, time_per_step: 85.4162
# Step 5: train_loss: 10.2162, norm: 17.6482, lr: 0.0000, tokens_per_second: 11924.6132, time_per_step: 85.8728
# Step 6: train_loss: 10.0158, norm: 15.1050, lr: 0.0000, tokens_per_second: 11911.8473, time_per_step: 85.9648
# Step 7: train_loss: 9.9201, norm: 11.6474, lr: 0.0000, tokens_per_second: 12007.7899, time_per_step: 85.2780
# Step 8: train_loss: 9.7919, norm: 10.1823, lr: 0.0000, tokens_per_second: 11998.4748, time_per_step: 85.3442
# Step 9: train_loss: 9.6718, norm: 9.4298, lr: 0.0000, tokens_per_second: 11928.9011, time_per_step: 85.8419
# Step 10: train_loss: 9.5652, norm: 8.2516, lr: 0.0000, tokens_per_second: 11990.7798, time_per_step: 85.3989
# Step 11: train_loss: 9.4614, norm: 7.1812, lr: 0.0000, tokens_per_second: 11905.6107, time_per_step: 86.0099
# Step 12: train_loss: 9.4482, norm: 6.7158, lr: 0.0000, tokens_per_second: 11984.2889, time_per_step: 85.4452
# Step 13: train_loss: 9.4690, norm: 7.0312, lr: 0.0000, tokens_per_second: 11950.3550, time_per_step: 85.6878
# Step 14: train_loss: 9.4448, norm: 6.1399, lr: 0.0000, tokens_per_second: 11984.7028, time_per_step: 85.4423
# Step 283: train_loss: 6.1357, norm: 2.0029, lr: 0.0002, tokens_per_second: 11751.6941, time_per_step: 87.1364
# Step 284: train_loss: 5.9262, norm: 2.2483, lr: 0.0002, tokens_per_second: 11791.9634, time_per_step: 86.8388
# Step 285: train_loss: 6.0193, norm: 2.2386, lr: 0.0002, tokens_per_second: 11757.2363, time_per_step: 87.0953
# Step 286: train_loss: 5.9601, norm: 1.8547, lr: 0.0002, tokens_per_second: 11716.4054, time_per_step: 87.3988
# Step 287: train_loss: 5.5448, norm: 1.8758, lr: 0.0002, tokens_per_second: 11765.9014, time_per_step: 87.0312
# Step 288: train_loss: 5.7256, norm: 2.7512, lr: 0.0002, tokens_per_second: 11749.8395, time_per_step: 87.1501
# Step 289: train_loss: 5.7584, norm: 2.0934, lr: 0.0002, tokens_per_second: 11714.6647, time_per_step: 87.4118
# Step 290: train_loss: 5.5935, norm: 2.4152, lr: 0.0002, tokens_per_second: 11710.7180, time_per_step: 87.4413
# Step 291: train_loss: 5.8559, norm: 2.2548, lr: 0.0003, tokens_per_second: 11731.6179, time_per_step: 87.2855
# Step 292: train_loss: 6.0984, norm: 4.8114, lr: 0.0003, tokens_per_second: 11776.8918, time_per_step: 86.9499
# Step 293: train_loss: 6.1116, norm: 5.1130, lr: 0.0003, tokens_per_second: 11744.0684, time_per_step: 87.1930
# Step 294: train_loss: 5.9527, norm: 2.4028, lr: 0.0003, tokens_per_second: 11691.3442, time_per_step: 87.5862
# Step 295: train_loss: 5.6998, norm: 2.1877, lr: 0.0003, tokens_per_second: 11805.8099, time_per_step: 86.7370
# Step 296: train_loss: 5.5149, norm: 1.7817, lr: 0.0003, tokens_per_second: 11723.5562, time_per_step: 87.3455
# Step 297: train_loss: 5.9248, norm: 2.2230, lr: 0.0003, tokens_per_second: 11719.5564, time_per_step: 87.3753
# Step 298: train_loss: 5.8042, norm: 1.9199, lr: 0.0003, tokens_per_second: 11765.4492, time_per_step: 87.0345
# Step 299: train_loss: 5.8587, norm: 1.7760, lr: 0.0003, tokens_per_second: 11739.9454, time_per_step: 87.2236
# Step 300: val_loss: 5.7812, val_time: 514.4429
# ---------------
# <|endoftext|>RD than all. What:
# It,
# IUS:
# And now?<|endoftext|>MI have your hand, but your rest;
# The state
# ---------------
# Step 300: train_loss: 5.5810, norm: 1.7606, lr: 0.0003, tokens_per_second: 11909.5909, time_per_step: 85.9811
# saving model to /home/user/gollem/results/experiments/gpt2/2_gpt2_124M_on_tinyshakespeare_with_mps/model_s300.pt
# model saved in 0.5785231590270996 seconds
# saving snapshot to /home/user/gollem/results/snapshots/snapshot.pt
# snapshot saved in 2.1561727449297905 seconds
# Step 301: train_loss: 5.7134, norm: 1.6579, lr: 0.0003, tokens_per_second: 11552.2936, time_per_step: 88.6404
# Step 302: train_loss: 5.5968, norm: 2.2424, lr: 0.0003, tokens_per_second: 11780.9429, time_per_step: 86.9200
# Step 303: train_loss: 5.7522, norm: 2.3615, lr: 0.0003, tokens_per_second: 11731.3114, time_per_step: 87.2878
# Step 304: train_loss: 6.0077, norm: 1.8398, lr: 0.0003, tokens_per_second: 11754.7948, time_per_step: 87.1134
# Step 966: train_loss: 4.7279, norm: 1.3118, lr: 0.0000, tokens_per_second: 11439.5815, time_per_step: 89.5138
# Step 967: train_loss: 4.8957, norm: 2.1109, lr: 0.0000, tokens_per_second: 11415.3652, time_per_step: 89.7037
# Step 968: train_loss: 5.0496, norm: 2.3195, lr: 0.0000, tokens_per_second: 11406.5515, time_per_step: 89.7730
# Step 969: train_loss: 4.9569, norm: 1.7481, lr: 0.0000, tokens_per_second: 11375.2451, time_per_step: 90.0200
# Step 970: train_loss: 4.9249, norm: 1.6219, lr: 0.0000, tokens_per_second: 11398.2817, time_per_step: 89.8381
# Step 971: train_loss: 5.0678, norm: 1.9718, lr: 0.0000, tokens_per_second: 11399.2923, time_per_step: 89.8301
# Step 972: train_loss: 4.8922, norm: 1.8376, lr: 0.0000, tokens_per_second: 11423.3408, time_per_step: 89.6410
# Step 973: train_loss: 5.0014, norm: 1.7066, lr: 0.0000, tokens_per_second: 11398.3280, time_per_step: 89.8377
# Step 974: train_loss: 5.4809, norm: 1.9945, lr: 0.0000, tokens_per_second: 11423.1243, time_per_step: 89.6427
# Step 975: train_loss: 4.7675, norm: 1.6822, lr: 0.0000, tokens_per_second: 11377.8056, time_per_step: 89.9998
# Step 976: train_loss: 4.7879, norm: 1.9881, lr: 0.0000, tokens_per_second: 11385.1902, time_per_step: 89.9414
# Step 977: train_loss: 5.0503, norm: 1.7178, lr: 0.0000, tokens_per_second: 11390.2372, time_per_step: 89.9016
# Step 978: train_loss: 4.6639, norm: 1.6634, lr: 0.0000, tokens_per_second: 11417.0512, time_per_step: 89.6904
# Step 979: train_loss: 4.4583, norm: 2.0020, lr: 0.0000, tokens_per_second: 11395.8651, time_per_step: 89.8572
# Step 980: train_loss: 5.1852, norm: 1.5729, lr: 0.0000, tokens_per_second: 11397.6909, time_per_step: 89.8428
# Step 981: train_loss: 5.1345, norm: 2.0841, lr: 0.0000, tokens_per_second: 11412.0439, time_per_step: 89.7298
# Step 982: train_loss: 4.6652, norm: 2.4570, lr: 0.0000, tokens_per_second: 11393.3834, time_per_step: 89.8767
# Step 983: train_loss: 4.7880, norm: 2.0160, lr: 0.0000, tokens_per_second: 11379.2262, time_per_step: 89.9885
# Step 984: train_loss: 4.7802, norm: 1.9037, lr: 0.0000, tokens_per_second: 11417.3490, time_per_step: 89.6881
# Step 985: train_loss: 4.9852, norm: 1.5795, lr: 0.0000, tokens_per_second: 11399.8795, time_per_step: 89.8255
# Step 986: train_loss: 4.8440, norm: 2.0245, lr: 0.0000, tokens_per_second: 11340.8105, time_per_step: 90.2934
# Step 987: train_loss: 4.8990, norm: 1.9230, lr: 0.0000, tokens_per_second: 11362.6019, time_per_step: 90.1202
# Step 988: train_loss: 5.1013, norm: 1.6224, lr: 0.0000, tokens_per_second: 11357.2912, time_per_step: 90.1623
# Step 989: train_loss: 5.0475, norm: 1.8574, lr: 0.0000, tokens_per_second: 11416.9943, time_per_step: 89.6909
# Step 990: train_loss: 4.8157, norm: 1.7008, lr: 0.0000, tokens_per_second: 11379.1988, time_per_step: 89.9888
# Step 991: train_loss: 4.7733, norm: 1.7056, lr: 0.0000, tokens_per_second: 11370.3139, time_per_step: 90.0591
# Step 992: train_loss: 4.6528, norm: 1.6328, lr: 0.0000, tokens_per_second: 11371.1916, time_per_step: 90.0521
# Step 993: train_loss: 4.5105, norm: 1.6865, lr: 0.0000, tokens_per_second: 11409.4301, time_per_step: 89.7503
# Step 994: train_loss: 4.3811, norm: 1.7430, lr: 0.0000, tokens_per_second: 11373.1874, time_per_step: 90.0363
# Step 995: train_loss: 4.6772, norm: 1.6772, lr: 0.0000, tokens_per_second: 11396.7893, time_per_step: 89.8499
# Step 996: train_loss: 4.4114, norm: 2.1139, lr: 0.0000, tokens_per_second: 11368.3689, time_per_step: 90.0745
# Step 997: train_loss: 4.9312, norm: 1.4479, lr: 0.0000, tokens_per_second: 11398.0719, time_per_step: 89.8398
# Step 998: train_loss: 4.5465, norm: 1.8502, lr: 0.0000, tokens_per_second: 11324.3393, time_per_step: 90.4247
# Step 999: train_loss: 4.7631, norm: 1.9620, lr: 0.0000, tokens_per_second: 11373.0171, time_per_step: 90.0377
# Step 1000: val_loss: 5.5480, val_time: 538.9799
# ---------------
# <|endoftext|>KINGERBIONAS:
# T:
# My father of him, with such so,
# And all this sweet of honour;
# But it well;
# ---------------
# final 19 iters avg: 89.973ms 11381 tok/s
# peak mem usage: 3285 MiB
# saving final model to /home/user/gollem/results/experiments/gpt2/2_gpt2_124M_on_tinyshakespeare_with_mps/model_s1000.pt
# saving final snapshot to /home/user/gollem/results/snapshots/snapshot.pt
# Finished training 9cd980c97b96455c9ca04cd73876d5c4

# %%
# parse the log file for the stats and samples
train_stats = {}
val_stats = {}
samples = {}
current_sample: str | None = None
sample_delimiter = "---------------"
step = 0
with open(Path(train_config.output_dir) / "main.log", "r") as f:
    for line in f.readlines():
        if line.strip() == sample_delimiter:
            if current_sample is not None:
                samples[step] = current_sample
                current_sample = None
            else:
                current_sample = ""
        elif current_sample is not None:
            current_sample += line
        elif line.startswith("Step"):
            # ["Step X", "val_loss", "Y, val_time", Z]
            # or
            # ["Step 1", "train_loss", "10.9326, norm", "24.2774, lr", "0.0000, tokens_per_second", "569.5777, time_per_step", 1797.8232]
            parts = line.split(": ")
            step = int(parts[0].split(" ")[1])
            last_key = parts[1].strip()
            step_stats = {}
            for part in parts[2:-1]:
                value, key = part.split(", ")
                step_stats[last_key] = float(value)
                last_key = key
            step_stats[last_key] = float(parts[-1].strip())
            if "val_loss" in step_stats:
                val_stats[step] = step_stats
            else:
                train_stats[step] = step_stats

train_stat_keys = list(train_stats[0].keys())
print(train_stat_keys)
# Out:
# ['train_loss', 'norm', 'lr', 'tokens_per_second', 'time_per_step']

# %%
# plot the train loss
x = list(train_stats.keys())
x = sorted(x)
y = [train_stats[i]["train_loss"] for i in x]

plt.plot(x, y)
plt.title("Train Loss")
plt.xlabel("Step")
plt.ylabel("Loss")
plt.show()

# %%
# plot the val loss
x = list(val_stats.keys())
x = sorted(x)
y = [val_stats[i]["val_loss"] for i in x]

plt.plot(x, y)
plt.title("Val Loss")
# Out:
# Text(0.5, 1.0, 'Val Loss')

# %%
# plot train norm
x = list(train_stats.keys())
x = sorted(x)
y = [train_stats[i]["norm"] for i in x]
plt.plot(x, y)
plt.title("Train Norm")
plt.xlabel("Step")
plt.ylabel("Norm")
plt.show()

# %%
# plot tokens per second
x = list(train_stats.keys())
x = sorted(x)
y = [train_stats[i]["tokens_per_second"] for i in x]
plt.plot(x, y)
plt.title("Tokens Per Second")
plt.xlabel("Step")

# average TPS (excluding first 100 steps)
y = [train_stats[i]["tokens_per_second"] for i in x if i > 100]
mean_y = sum(y) / len(y)
print(f"Average TPS: {mean_y:.2f}")
# Out:
# Average TPS: 11672.51

# %%
# compare samples through time
for step in samples:
    print(f">>>Sample at step {step}:")
    print(samples[step])
# Out:
# >>>Sample at step 0:
# <|endoftext|> Trophyemployment stationily Officers dilemma manip rustwp ragedtietiels convLDLDlambda Lovereworks tentseworks Loveroin ripping vm Tel Arcane pressure pressure cope mould
#
# >>>Sample at step 100:
# <|endoftext|>H not;
#
# And you' him, my I thy:
# '
# That is'd, my that my.
# I.<|endoftext|>.<|endoftext|> not
#
# >>>Sample at step 200:
# <|endoftext|>: come:
# ' the must I did yours:
# Of in his's''er I was some?<|endoftext|>FirstEN.<|endoftext|>L:
#
#
# >>>Sample at step 300:
# <|endoftext|>RD than all. What:
# It,
# IUS:
# And now?<|endoftext|>MI have your hand, but your rest;
# The state
#
# >>>Sample at step 400:
# <|endoftext|> ELROMER:
# ThdROMEO:
# Go'st,
# Come you, that thou be thou I not love's son is to be more
#
# >>>Sample at step 500:
# <|endoftext|>PERFL, and love on,
# My brother,
# He's
# the:
# I; there is some
# He he dAMYC: but the
#
# >>>Sample at step 600:
# <|endoftext|>TRCESYLakARUS:
# And,
# Than a king. We are heard me,
# The rest willstst of his time
#
# >>>Sample at step 700:
# <|endoftext|>BBARea:'areUTIO:
# But thou should:
# And,
# O, sir,
# A man,
# A kind, love
#
# >>>Sample at step 800:
# <|endoftext|>EL a lord,
# The daughter; that,
# And his
# That,
# For my honour,
# The
# If make
# A:
# I will
#
# >>>Sample at step 900:
# <|endoftext|> of's?, I shall I am all the man to the rest in I amINGS:
# This it for your hands and your brother and well that I
#
# >>>Sample at step 1000:
# <|endoftext|>KINGERBIONAS:
# T:
# My father of him, with such so,
# And all this sweet of honour;
# But it well;

# %%
# Let's load the model and sample from it
model, _ = model_cfg.get_model_and_optimizer(device=device)
model = load_model(str(Path(train_config.output_dir) / "model_s1000.pt"), device=device)
model.eval()
# Out:
# num decayed parameter tensors: 50, with 124,318,464 parameters
# num non-decayed parameter tensors: 98, with 121,344 parameters
# Using regular AdamW with fused=False
# num decayed parameter tensors: 50, with 124,318,464 parameters
# num non-decayed parameter tensors: 98, with 121,344 parameters
# Using regular AdamW with fused=False
# GPT(
#   (transformer): ModuleDict(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (h): ModuleList(
#       (0-11): 12 x TransformerBlock(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Linear(in_features=768, out_features=2304, bias=True)
#           (c_proj): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#           (gelu): GELU(approximate='tanh')
#           (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %%
tokenizer = model_cfg.get_tokenizer()


def sample_from_model(prompt: str) -> str:
    tokens = tokenizer.encode(prompt, add_eot=False)
    tokens = torch.tensor(tokens, dtype=torch.long)
    tokens = tokens.unsqueeze(0).repeat(1, 1)
    tokens = tokens.to(device)
    output = model.generate(tokens, max_new_tokens=100, end_token=tokenizer.eot_token)
    return tokenizer.decode(output[0].tolist())

# %%
print(sample_from_model("Romeo and Juliet"))
# Out:
# Romeo and Juliet saints go'd defagark, I mean in grief
# Swawn to--What, havefort;
# Come, that the Tartaryies, that the Ram direered;
# The king's seat's possession easier ofher and faded;
# To art thou
# Out morning, thou
# Or both
# For my?
# And awhile,
# See the last I might bid Away,
# Thou art:
# Are not bring I must you to you, or exercise
# Like sorrow in forty
