# %% [markdown]
# # Training GPT2 124M on Tiny shakespeare dataset on my laptop using CUDA on RTX 3090
#
# In this notebook, we train a GPT2 124M model on the Tiny Shakespeare dataset on my laptop without any optimizations except for using CUDA on RTX 3090.

# %%
from pathlib import Path

import torch
from matplotlib import pyplot as plt

from gollem.data import load_dataset
from gollem.models.gpt2.config import GPT2Config
from gollem.models.gpt2.config import get_gpt2_model_config
from gollem.train.config import TrainConfig
from gollem.train.core import run
from gollem.utils import get_base_dir_path
from gollem.models.model import load_model
from gollem.train.utils import get_hardware_info

# get available devices
hardware_info = get_hardware_info()
for key, value in hardware_info.items():
    print(f"{key}: {value}")

device = "cuda"
# Out:
# /home/user/gollem/gollem/models/gpt2/model.py:18: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import ZeroRedundancyOptimizer
# os: {'system': 'Linux', 'release': '5.4.0-166-generic', 'version': '#183-Ubuntu SMP Mon Oct 2 11:28:33 UTC 2023', 'machine': 'x86_64'}
# cpu: {'brand': 'x86_64', 'cores_physical': 32, 'cores_logical': 64}
# memory: {'total_gb': 503.74}
# gpu: {'name': 'NVIDIA GeForce RTX 3090', 'count': 8, 'capability': (8, 6), 'memory_total_gb': 23.69, 'memory_allocated_gb': 0.0}

# %%
# Create configs
model_cfg = get_gpt2_model_config("gpt2")
# remove optimizations
model_cfg = GPT2Config.override(
    model_cfg,
    **{
        "fused_adamw": False,
        "zero_optimizer": False,
        "flash": False,
        "activation_checkpointing": False,
        "compile": False,
        "from_pretrained": False,
        "use_kv_caching": False,
    },
)

dataset = load_dataset("tinyshakespeare", model_cfg.get_tokenizer())

train_config = TrainConfig(
    output_dir=str(
        get_base_dir_path()
        / "results"
        / "experiments"
        / "gpt2"
        / "2_gpt2_124M_on_tinyshakespeare_with_cuda_on_rtx3090"
    ),
    batch_size=1,
    seq_len=1024,
    total_batch_size=1024,
    num_iterations=1000,
    val_loss_every=100,
    sample_every=100,
    save_every=100,
    snapshot_every=100,
    device=device,
    dtype="float32",
    tensorcores=False,
    use_wandb=True,
)
# Out:
# /home/user/gollem/gollem/data/datasets/tinyshakespeare/tiny_shakespeare.txt already exists, skipping download...
# Tokenized data already exists, skipping tokenization...

# %%
# change to False to avoid rerunning the training
if True:
    run(dataset, model_cfg, train_config)
# Out:
# Launching GPU0|0 in process group 1 using device cuda
# total desired batch size: 1024
# => calculated gradient accumulation steps: 1
# Starting new run 09bc5555106240e2ae0f4072c2aa87c8
# wandb: Currently logged in as: jjschwartz. Use `wandb login --relogin` to force relogin
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Tracking run with wandb version 0.19.2
# Run data is saved locally in <code>/home/user/gollem/experiments/gpt2/wandb/run-20250412_164002-09bc5555106240e2ae0f4072c2aa87c8</code>
# Syncing run <strong><a href='https://wandb.ai/jjschwartz/gollem/runs/09bc5555106240e2ae0f4072c2aa87c8' target="_blank">gpt2_tinyshakespeare</a></strong> to <a href='https://wandb.ai/jjschwartz/gollem' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/jjschwartz/gollem' target="_blank">https://wandb.ai/jjschwartz/gollem</a>
#  View run at <a href='https://wandb.ai/jjschwartz/gollem/runs/09bc5555106240e2ae0f4072c2aa87c8' target="_blank">https://wandb.ai/jjschwartz/gollem/runs/09bc5555106240e2ae0f4072c2aa87c8</a>
# Config:
# {'dataset_config': {'name': 'tinyshakespeare',
#                     'train_data': [PosixPath('/home/user/gollem/gollem/data/datasets/tinyshakespeare/gpt2/tiny_shakespeare_val.bin')],
#                     'val_data': [PosixPath('/home/user/gollem/gollem/data/datasets/tinyshakespeare/gpt2/tiny_shakespeare_train.bin')]},
#  'device': 'cuda',
#  'device_type': 'cuda',
#  'model_config': {'activation_checkpointing': False,
#                   'betas': (0.9, 0.95),
#                   'compile': False,
#                   'd_mlp': 3072,
#                   'd_model': 768,
#                   'flash': False,
#                   'from_pretrained': False,
#                   'fused_adamw': False,
#                   'grad_clip': 1.0,
#                   'learning_rate': 0.0006,
#                   'learning_rate_decay_frac': 0.0,
#                   'ln_bias': True,
#                   'max_sample_batch_size': 1,
#                   'mlp_bias': True,
#                   'model_name': 'gpt2',
#                   'n_ctx': 1024,
#                   'n_head': 12,
#                   'n_layer': 12,
#                   'share_embd_params': True,
#                   'use_kv_caching': False,
#                   'vocab_size': 50257,
#                   'warmup_iters': 700,
#                   'weight_decay': 0.1,
#                   'zero_optimizer': False},
#  'pytorch_version': '2.5.1+cu121',
#  'train_config': {'batch_size': 1,
#                   'device': 'cuda',
#                   'dtype': 'float32',
#                   'grad_accum_steps': 1,
#                   'num_iterations': 1000,
#                   'output_dir': '/home/user/gollem/results/experiments/gpt2/2_gpt2_124M_on_tinyshakespeare_with_cuda_on_rtx3090',
#                   'sample_every': 100,
#                   'save_every': 100,
#                   'seed': 42,
#                   'seq_len': 1024,
#                   'snapshot_every': 100,
#                   'tensorcores': False,
#                   'total_batch_size': 1024,
#                   'use_wandb': True,
#                   'val_loss_every': 100,
#                   'val_max_steps': 20}}
# num decayed parameter tensors: 50, with 124,318,464 parameters
# num non-decayed parameter tensors: 98, with 121,344 parameters
# Using regular AdamW with fused=False
# DataLoader: total number of tokens: 298,039 across 1 files
# DataLoader: total number of tokens: 32,768 across 1 files
# Starting training for 1000 iterations
# Step 0: val_loss: 11.0214, val_time: 942.4183
# ---------------
# <|endoftext|> Trophyemployment stationily Officers dilemma manip rustwp ragedtietiels convLDLDlambda Lovereworks tentseworks Loveroin ripping vm Tel Arcane pressure pressure cope mould
# ---------------
# Step 0: train_loss: 11.0052, norm: 25.3916, lr: 0.0000, tokens_per_second: 6047.7599, time_per_step: 169.3189
# Step 1: train_loss: 10.9326, norm: 24.2788, lr: 0.0000, tokens_per_second: 11954.1863, time_per_step: 85.6604
# Step 2: train_loss: 10.8366, norm: 26.1579, lr: 0.0000, tokens_per_second: 11983.9326, time_per_step: 85.4477
# Step 3: train_loss: 10.7297, norm: 22.9848, lr: 0.0000, tokens_per_second: 11963.0130, time_per_step: 85.5972
# Step 4: train_loss: 10.4854, norm: 20.5783, lr: 0.0000, tokens_per_second: 11978.1172, time_per_step: 85.4892
# Step 5: train_loss: 10.2162, norm: 17.6482, lr: 0.0000, tokens_per_second: 11971.2637, time_per_step: 85.5382
# Step 6: train_loss: 10.0158, norm: 15.1050, lr: 0.0000, tokens_per_second: 11989.8383, time_per_step: 85.4057
# Step 7: train_loss: 9.9201, norm: 11.6474, lr: 0.0000, tokens_per_second: 11943.8321, time_per_step: 85.7346
# Step 8: train_loss: 9.7919, norm: 10.1823, lr: 0.0000, tokens_per_second: 11980.7401, time_per_step: 85.4705
# Step 251: train_loss: 5.6103, norm: 1.7015, lr: 0.0002, tokens_per_second: 11743.0720, time_per_step: 87.2004
# Step 252: train_loss: 5.8722, norm: 1.8966, lr: 0.0002, tokens_per_second: 11802.3883, time_per_step: 86.7621
# Step 253: train_loss: 6.0661, norm: 2.6439, lr: 0.0002, tokens_per_second: 11762.0056, time_per_step: 87.0600
# Step 254: train_loss: 5.8729, norm: 2.0314, lr: 0.0002, tokens_per_second: 11762.3489, time_per_step: 87.0574
# Step 255: train_loss: 5.4256, norm: 2.6662, lr: 0.0002, tokens_per_second: 11808.4238, time_per_step: 86.7178
# Step 256: train_loss: 5.7405, norm: 1.5966, lr: 0.0002, tokens_per_second: 11779.1113, time_per_step: 86.9336
# Step 257: train_loss: 5.6180, norm: 2.2489, lr: 0.0002, tokens_per_second: 11779.1426, time_per_step: 86.9333
# Step 258: train_loss: 5.5001, norm: 1.8777, lr: 0.0002, tokens_per_second: 11762.7526, time_per_step: 87.0545
# Step 259: train_loss: 5.1712, norm: 2.6837, lr: 0.0002, tokens_per_second: 11723.7442, time_per_step: 87.3441
# Step 260: train_loss: 5.3916, norm: 1.6189, lr: 0.0002, tokens_per_second: 11805.0545, time_per_step: 86.7425
# Step 261: train_loss: 5.7637, norm: 1.6591, lr: 0.0002, tokens_per_second: 11692.2861, time_per_step: 87.5791
# Step 262: train_loss: 5.8218, norm: 2.0032, lr: 0.0002, tokens_per_second: 11771.6678, time_per_step: 86.9885
# Step 263: train_loss: 5.9715, norm: 1.9256, lr: 0.0002, tokens_per_second: 11802.1491, time_per_step: 86.7639
# Step 264: train_loss: 5.1180, norm: 1.9028, lr: 0.0002, tokens_per_second: 11774.5379, time_per_step: 86.9673
# Step 265: train_loss: 5.0132, norm: 1.8219, lr: 0.0002, tokens_per_second: 11813.8420, time_per_step: 86.6780
# Step 266: train_loss: 5.5796, norm: 1.8481, lr: 0.0002, tokens_per_second: 11771.1112, time_per_step: 86.9926
# Step 267: train_loss: 5.8859, norm: 2.5981, lr: 0.0002, tokens_per_second: 11683.7579, time_per_step: 87.6430
# Step 268: train_loss: 5.3719, norm: 3.3387, lr: 0.0002, tokens_per_second: 11769.1346, time_per_step: 87.0072
# Step 269: train_loss: 5.1823, norm: 1.6750, lr: 0.0002, tokens_per_second: 11767.2442, time_per_step: 87.0212
# Step 270: train_loss: 5.1243, norm: 1.6846, lr: 0.0002, tokens_per_second: 11738.3010, time_per_step: 87.2358
# Step 271: train_loss: 4.8582, norm: 1.7266, lr: 0.0002, tokens_per_second: 11775.1684, time_per_step: 86.9627
# Step 272: train_loss: 5.1010, norm: 2.1602, lr: 0.0002, tokens_per_second: 11769.6899, time_per_step: 87.0031
# Step 273: train_loss: 5.1067, norm: 1.6398, lr: 0.0002, tokens_per_second: 11821.0523, time_per_step: 86.6251
# Step 274: train_loss: 4.9847, norm: 1.6049, lr: 0.0002, tokens_per_second: 11768.9441, time_per_step: 87.0087
to /home/user/gollem/results/experiments/gpt2/2_gpt2_124M_on_tinyshakespeare_with_cuda_on_rtx3090/model_s300.pt
# model saved in 0.6115990281105042 seconds
# saving snapshot to /home/user/gollem/results/snapshots/snapshot.pt
# snapshot saved in 2.2256650403141975 seconds
# Step 301: train_loss: 5.7134, norm: 1.6579, lr: 0.0003, tokens_per_second: 11538.4402, time_per_step: 88.7468
# Step 302: train_loss: 5.5968, norm: 2.2424, lr: 0.0003, tokens_per_second: 11698.0433, time_per_step: 87.5360
# Step 303: train_loss: 5.7522, norm: 2.3615, lr: 0.0003, tokens_per_second: 11804.6215, time_per_step: 86.7457
# Step 304: train_loss: 6.0077, norm: 1.8398, lr: 0.0003, tokens_per_second: 11742.4650, time_per_step: 87.2049
# Step 305: train_loss: 5.6765, norm: 2.7025, lr: 0.0003, tokens_per_second: 11715.7282, time_per_step: 87.4039
# Step 306: train_loss: 5.9876, norm: 1.9804, lr: 0.0003, tokens_per_second: 11753.8780, time_per_step: 87.1202
# Step 307: train_loss: 5.4932, norm: 2.9427, lr: 0.0003, tokens_per_second: 11686.9630, time_per_step: 87.6190
# Step 308: train_loss: 5.5205, norm: 2.4998, lr: 0.0003, tokens_per_second: 11787.6833, time_per_step: 86.8703
# Step 309: train_loss: 5.6247, norm: 2.2155, lr: 0.0003, tokens_per_second: 11759.4776, time_per_step: 87.0787
# Step 310: train_loss: 5.7446, norm: 1.8357, lr: 0.0003, tokens_per_second: 11741.3013, time_per_step: 87.2135
# Step 311: train_loss: 5.1903, norm: 2.3083, lr: 0.0003, tokens_per_second: 11747.8901, time_per_step: 87.1646
# Step 312: train_loss: 5.5262, norm: 2.2953, lr: 0.0003, tokens_per_second: 11645.9359, time_per_step: 87.9277
# Step 313: train_loss: 5.1244, norm: 1.5092, lr: 0.0003, tokens_per_second: 11763.8903, time_per_step: 87.0460
# Step 314: train_loss: 5.6472, norm: 1.7701, lr: 0.0003, tokens_per_second: 11749.6406, time_per_step: 87.1516
# Step 315: train_loss: 5.6880, norm: 2.1427, lr: 0.0003, tokens_per_second: 11723.9052, time_per_step: 87.3429
# Step 316: train_loss: 5.4338, norm: 2.4321, lr: 0.0003, tokens_per_second: 11776.2672, time_per_step: 86.9545
# Step 317: train_loss: 5.0449, norm: 2.2336, lr: 0.0003, tokens_per_second: 11746.6289, time_per_step: 87.1739
# Step 318: train_loss: 5.3246, norm: 1.8344, lr: 0.0003, tokens_per_second: 11740.0487, time_per_step: 87.2228
# Step 319: train_loss: 5.3007, norm: 1.8807, lr: 0.0003, tokens_per_second: 11738.3812, time_per_step: 87.2352
# Step 320: train_loss: 5.4965, norm: 1.9169, lr: 0.0003, tokens_per_second: 11721.6714, time_per_step: 87.3596
# Step 321: train_loss: 5.2075, norm: 2.8968, lr: 0.0003, tokens_per_second: 11756.5454, time_per_step: 87.1004
# Step 943: train_loss: 4.7272, norm: 1.9460, lr: 0.0001, tokens_per_second: 11450.0706, time_per_step: 89.4318
# Step 944: train_loss: 4.9459, norm: 1.6526, lr: 0.0001, tokens_per_second: 11443.7678, time_per_step: 89.4810
# Step 945: train_loss: 4.7477, norm: 1.5085, lr: 0.0000, tokens_per_second: 11435.5173, time_per_step: 89.5456
# Step 946: train_loss: 4.6115, norm: 2.0298, lr: 0.0000, tokens_per_second: 11404.8960, time_per_step: 89.7860
# Step 947: train_loss: 4.5070, norm: 1.8193, lr: 0.0000, tokens_per_second: 11439.6053, time_per_step: 89.5136
# Step 948: train_loss: 4.7109, norm: 1.3963, lr: 0.0000, tokens_per_second: 11414.6939, time_per_step: 89.7089
# Step 949: train_loss: 4.9361, norm: 1.3987, lr: 0.0000, tokens_per_second: 11423.6418, time_per_step: 89.6387
# Step 950: train_loss: 4.9276, norm: 1.7713, lr: 0.0000, tokens_per_second: 11462.7095, time_per_step: 89.3332
# Step 951: train_loss: 4.8137, norm: 1.7653, lr: 0.0000, tokens_per_second: 11445.7539, time_per_step: 89.4655
# Step 952: train_loss: 4.8212, norm: 1.6457, lr: 0.0000, tokens_per_second: 11453.2538, time_per_step: 89.4069
# Step 953: train_loss: 4.7900, norm: 1.3552, lr: 0.0000, tokens_per_second: 11396.2308, time_per_step: 89.8543
# Step 954: train_loss: 4.4635, norm: 1.5512, lr: 0.0000, tokens_per_second: 11451.6095, time_per_step: 89.4197
# Step 955: train_loss: 4.9013, norm: 1.6196, lr: 0.0000, tokens_per_second: 11418.3621, time_per_step: 89.6801
# Step 956: train_loss: 4.4619, norm: 1.6315, lr: 0.0000, tokens_per_second: 11418.6789, time_per_step: 89.6776
# Step 957: train_loss: 4.7605, norm: 1.3339, lr: 0.0000, tokens_per_second: 11413.7261, time_per_step: 89.7165
# Step 958: train_loss: 4.6752, norm: 1.4279, lr: 0.0000, tokens_per_second: 11336.4907, time_per_step: 90.3278
# Step 959: train_loss: 4.0968, norm: 1.4049, lr: 0.0000, tokens_per_second: 11404.9585, time_per_step: 89.7855
# Step 960: train_loss: 4.8693, norm: 1.4170, lr: 0.0000, tokens_per_second: 11373.4284, time_per_step: 90.0344
# Step 961: train_loss: 4.5602, norm: 1.3550, lr: 0.0000, tokens_per_second: 11429.2960, time_per_step: 89.5943
# Step 962: train_loss: 3.5385, norm: 1.9465, lr: 0.0000, tokens_per_second: 11371.6282, time_per_step: 90.0487
# Step 963: train_loss: 3.9898, norm: 1.5296, lr: 0.0000, tokens_per_second: 11415.1860, time_per_step: 89.7051
# Step 964: train_loss: 4.4502, norm: 1.6214, lr: 0.0000, tokens_per_second: 11342.1966, time_per_step: 90.2823
# Step 965: train_loss: 4.7665, norm: 1.3189, lr: 0.0000, tokens_per_second: 11401.6139, time_per_step: 89.8118
# Step 966: train_loss: 4.7279, norm: 1.3118, lr: 0.0000, tokens_per_second: 11353.6594, time_per_step: 90.1912
# Step 967: train_loss: 4.8957, norm: 2.1109, lr: 0.0000, tokens_per_second: 11377.1510, time_per_step: 90.0050
# Step 968: train_loss: 5.0496, norm: 2.3195, lr: 0.0000, tokens_per_second: 11322.0714, time_per_step: 90.4428
# Step 969: train_loss: 4.9569, norm: 1.7481, lr: 0.0000, tokens_per_second: 11399.7934, time_per_step: 89.8262
# Step 970: train_loss: 4.9249, norm: 1.6219, lr: 0.0000, tokens_per_second: 11352.3774, time_per_step: 90.2014
# Step 971: train_loss: 5.0678, norm: 1.9718, lr: 0.0000, tokens_per_second: 11367.9693, time_per_step: 90.0777
# Step 972: train_loss: 4.8922, norm: 1.8376, lr: 0.0000, tokens_per_second: 11321.9334, time_per_step: 90.4439
# Step 973: train_loss: 5.0014, norm: 1.7066, lr: 0.0000, tokens_per_second: 11351.6620, time_per_step: 90.2071
# Step 974: train_loss: 5.4809, norm: 1.9945, lr: 0.0000, tokens_per_second: 11376.5097, time_per_step: 90.0100
# Step 975: train_loss: 4.7675, norm: 1.6822, lr: 0.0000, tokens_per_second: 11353.7757, time_per_step: 90.1903
# Step 976: train_loss: 4.7879, norm: 1.9881, lr: 0.0000, tokens_per_second: 11404.7455, time_per_step: 89.7872
# Step 977: train_loss: 5.0503, norm: 1.7178, lr: 0.0000, tokens_per_second: 11362.6526, time_per_step: 90.1198
# Step 978: train_loss: 4.6639, norm: 1.6634, lr: 0.0000, tokens_per_second: 11382.5199, time_per_step: 89.9625
# Step 979: train_loss: 4.4583, norm: 2.0020, lr: 0.0000, tokens_per_second: 11387.4806, time_per_step: 89.9233
# Step 980: train_loss: 5.1852, norm: 1.5729, lr: 0.0000, tokens_per_second: 11404.8222, time_per_step: 89.7866
# Step 981: train_loss: 5.1345, norm: 2.0841, lr: 0.0000, tokens_per_second: 11339.5202, time_per_step: 90.3036
# Step 982: train_loss: 4.6652, norm: 2.4570, lr: 0.0000, tokens_per_second: 11357.9125, time_per_step: 90.1574
# Step 983: train_loss: 4.7880, norm: 2.0160, lr: 0.0000, tokens_per_second: 11308.7346, time_per_step: 90.5495
# Step 984: train_loss: 4.7802, norm: 1.9037, lr: 0.0000, tokens_per_second: 11331.2183, time_per_step: 90.3698
# Step 985: train_loss: 4.9852, norm: 1.5795, lr: 0.0000, tokens_per_second: 11326.8787, time_per_step: 90.4044
# Step 986: train_loss: 4.8440, norm: 2.0245, lr: 0.0000, tokens_per_second: 11346.8627, time_per_step: 90.2452
# Step 987: train_loss: 4.8990, norm: 1.9230, lr: 0.0000, tokens_per_second: 11329.7780, time_per_step: 90.3813
# Step 988: train_loss: 5.1013, norm: 1.6224, lr: 0.0000, tokens_per_second: 11315.3730, time_per_step: 90.4964
# Step 989: train_loss: 5.0475, norm: 1.8574, lr: 0.0000, tokens_per_second: 11353.2055, time_per_step: 90.1948
# Step 990: train_loss: 4.8157, norm: 1.7008, lr: 0.0000, tokens_per_second: 11356.2402, time_per_step: 90.1707
# Step 991: train_loss: 4.7733, norm: 1.7056, lr: 0.0000, tokens_per_second: 11382.1805, time_per_step: 89.9652
# Step 992: train_loss: 4.6528, norm: 1.6328, lr: 0.0000, tokens_per_second: 11311.2252, time_per_step: 90.5295
# Step 993: train_loss: 4.5105, norm: 1.6865, lr: 0.0000, tokens_per_second: 11341.5414, time_per_step: 90.2876
# Step 994: train_loss: 4.3811, norm: 1.7430, lr: 0.0000, tokens_per_second: 11280.9392, time_per_step: 90.7726
# Step 995: train_loss: 4.6772, norm: 1.6772, lr: 0.0000, tokens_per_second: 11350.4330, time_per_step: 90.2168
# Step 996: train_loss: 4.4114, norm: 2.1139, lr: 0.0000, tokens_per_second: 11320.2035, time_per_step: 90.4577
# Step 997: train_loss: 4.9312, norm: 1.4479, lr: 0.0000, tokens_per_second: 11346.8889, time_per_step: 90.2450
# Step 998: train_loss: 4.5465, norm: 1.8502, lr: 0.0000, tokens_per_second: 11303.6052, time_per_step: 90.5906
# Step 999: train_loss: 4.7631, norm: 1.9620, lr: 0.0000, tokens_per_second: 11284.1837, time_per_step: 90.7465
# Step 1000: val_loss: 5.5480, val_time: 541.6977
# ---------------
# <|endoftext|>KINGERBIONAS:
# T:
# My father of him, with such so,
# And all this sweet of honour;
# But it well;
# ---------------
# final 19 iters avg: 90.373ms 11331 tok/s
# peak mem usage: 3285 MiB
# saving final model to /home/user/gollem/results/experiments/gpt2/2_gpt2_124M_on_tinyshakespeare_with_cuda_on_rtx3090/model_s1000.pt
# saving final snapshot to /home/user/gollem/results/snapshots/snapshot.pt
# Finished training 09bc5555106240e2ae0f4072c2aa87c8

# %%
# parse the log file for the stats and samples
train_stats = {}
val_stats = {}
samples = {}
current_sample: str | None = None
sample_delimiter = "---------------"
step = 0
with open(Path(train_config.output_dir) / "main.log", "r") as f:
    for line in f.readlines():
        if line.strip() == sample_delimiter:
            if current_sample is not None:
                samples[step] = current_sample
                current_sample = None
            else:
                current_sample = ""
        elif current_sample is not None:
            current_sample += line
        elif line.startswith("Step"):
            # ["Step X", "val_loss", "Y, val_time", Z]
            # or
            # ["Step 1", "train_loss", "10.9326, norm", "24.2774, lr", "0.0000, tokens_per_second", "569.5777, time_per_step", 1797.8232]
            parts = line.split(": ")
            step = int(parts[0].split(" ")[1])
            last_key = parts[1].strip()
            step_stats = {}
            for part in parts[2:-1]:
                value, key = part.split(", ")
                step_stats[last_key] = float(value)
                last_key = key
            step_stats[last_key] = float(parts[-1].strip())
            if "val_loss" in step_stats:
                val_stats[step] = step_stats
            else:
                train_stats[step] = step_stats

train_stat_keys = list(train_stats[0].keys())
print(train_stat_keys)
# Out:
# ['train_loss', 'norm', 'lr', 'tokens_per_second', 'time_per_step']

# %%
# plot the train loss
x = list(train_stats.keys())
x = sorted(x)
y = [train_stats[i]["train_loss"] for i in x]

plt.plot(x, y)
plt.title("Train Loss")
plt.xlabel("Step")
plt.ylabel("Loss")
plt.show()

# %%
# plot the val loss
x = list(val_stats.keys())
x = sorted(x)
y = [val_stats[i]["val_loss"] for i in x]

plt.plot(x, y)
plt.title("Val Loss")
# Out:
# Text(0.5, 1.0, 'Val Loss')

# %%
# plot train norm
x = list(train_stats.keys())
x = sorted(x)
y = [train_stats[i]["norm"] for i in x]
plt.plot(x, y)
plt.title("Train Norm")
plt.xlabel("Step")
plt.ylabel("Norm")
plt.show()

# %%
# plot tokens per second
x = list(train_stats.keys())
x = sorted(x)
y = [train_stats[i]["tokens_per_second"] for i in x]
plt.plot(x, y)
plt.title("Tokens Per Second")
plt.xlabel("Step")

# average TPS (excluding first 100 steps)
y = [train_stats[i]["tokens_per_second"] for i in x if i > 100]
mean_y = sum(y) / len(y)
print(f"Average TPS: {mean_y:.2f}")
# Out:
# Average TPS: 11676.59

# %%
# compare samples through time
for step in samples:
    print(f">>>Sample at step {step}:")
    print(samples[step])
# Out:
# >>>Sample at step 0:
# <|endoftext|> Trophyemployment stationily Officers dilemma manip rustwp ragedtietiels convLDLDlambda Lovereworks tentseworks Loveroin ripping vm Tel Arcane pressure pressure cope mould
#
# >>>Sample at step 100:
# <|endoftext|>H not;
#
# And you' him, my I thy:
# '
# That is'd, my that my.
# I.<|endoftext|>.<|endoftext|> not
#
# >>>Sample at step 200:
# <|endoftext|>: come:
# ' the must I did yours:
# Of in his's''er I was some?<|endoftext|>FirstEN.<|endoftext|>L:
#
#
# >>>Sample at step 300:
# <|endoftext|>RD than all. What:
# It,
# IUS:
# And now?<|endoftext|>MI have your hand, but your rest;
# The state
#
# >>>Sample at step 400:
# <|endoftext|> ELROMER:
# ThdROMEO:
# Go'st,
# Come you, that thou be thou I not love's son is to be more
#
# >>>Sample at step 500:
# <|endoftext|>PERFL, and love on,
# My brother,
# He's
# the:
# I; there is some
# He he dAMYC: but the
#
# >>>Sample at step 600:
# <|endoftext|>TRCESYLakARUS:
# And,
# Than a king. We are heard me,
# The rest willstst of his time
#
# >>>Sample at step 700:
# <|endoftext|>BBARea:'areUTIO:
# But thou should:
# And,
# O, sir,
# A man,
# A kind, love
#
# >>>Sample at step 800:
# <|endoftext|>EL a lord,
# The daughter; that,
# And his
# That,
# For my honour,
# The
# If make
# A:
# I will
#
# >>>Sample at step 900:
# <|endoftext|> of's?, I shall I am all the man to the rest in I amINGS:
# This it for your hands and your brother and well that I
#
# >>>Sample at step 1000:
# <|endoftext|>KINGERBIONAS:
# T:
# My father of him, with such so,
# And all this sweet of honour;
# But it well;

# %%
# Let's load the model and sample from it
model, _ = model_cfg.get_model_and_optimizer(device=device)
model = load_model(str(Path(train_config.output_dir) / "model_s1000.pt"), device=device)
model.eval()
# Out:
# num decayed parameter tensors: 50, with 124,318,464 parameters
# num non-decayed parameter tensors: 98, with 121,344 parameters
# Using regular AdamW with fused=False
# num decayed parameter tensors: 50, with 124,318,464 parameters
# num non-decayed parameter tensors: 98, with 121,344 parameters
# Using regular AdamW with fused=False
# GPT(
#   (transformer): ModuleDict(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (h): ModuleList(
#       (0-11): 12 x TransformerBlock(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Linear(in_features=768, out_features=2304, bias=True)
#           (c_proj): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#           (gelu): GELU(approximate='tanh')
#           (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %%
tokenizer = model_cfg.get_tokenizer()


def sample_from_model(prompt: str) -> str:
    tokens = tokenizer.encode(prompt, add_eot=False)
    tokens = torch.tensor(tokens, dtype=torch.long)
    tokens = tokens.unsqueeze(0).repeat(1, 1)
    tokens = tokens.to(device)
    output = model.generate(tokens, max_new_tokens=100, end_token=tokenizer.eot_token)
    return tokenizer.decode(output[0].tolist())

# %%
print(sample_from_model("Romeo and Juliet"))
# Out:
# Romeo and Juliet saints go'd defagark, I mean in grief
# Swawn to--What, havefort;
# Come, that the Tartaryies, that the Ram direered;
# The king's seat's possession easier ofher and faded;
# To art thou
# Out morning, thou
# Or both
# For my?
# And awhile,
# See the last I might bid Away,
# Thou art:
# Are not bring I must you to you, or exercise
# Like sorrow in forty
